# %% [markdown]
# # Force Validation Examples Archive
#
# This notebook is a result-saved promotion archive for `examples/force_validation`.
# It keeps theory, source inventory, result payloads, and placement policy in one
# human-readable surface while the adjacent JSON remains the durable debug record.
#
# ## Theory and Scope
#
# - This notebook is the topic-specific source/result archive for examples/force_validation.
# - It preserves full source, hashes, adjacent JSON payloads, and result media hashes before any pruning decision.
# - Validation-class scripts remain executable in examples until explicit validation_test gates or reusable src APIs exist.
#
# ## Placement Policy
#
# Docs-first topic archive for examples/force_validation. Keep scripts until protected docs, panel, package, and validation_test references have been migrated to docs, src, panels, or validation_test.
#
# ## Synchronization
#
# The durable archive is `force_validation_examples_archive_results.json`. It stores full source, SHA-256 hashes,
# existing result JSON payloads, media hashes, runtime metadata, and the promotion
# lane for every script in this batch.

# %%
from pathlib import Path
import json
from IPython.display import Markdown, display

archive_path = Path('force_validation_examples_archive_results.json')
if not archive_path.exists():
    archive_path = Path('docs/force_validation/force_validation_examples_archive_results.json')
data = json.loads(archive_path.read_text(encoding='utf-8'))
counts = data['counts']
print(f"topic={data['topic']}")
print(f"python_scripts={counts['python_scripts']}")
print(f"topic_json_files={counts['topic_json_files']}")
print(f"media_files={counts['media_files']}")
print(f"promotion_lane={data['promotion_lane']}")
# Out:
# topic=force_validation
# python_scripts=6
# topic_json_files=6
# media_files=0
# promotion_lane=topic_docs_first_archive

# %% [markdown]
# ## Script Inventory
# Generated from the synchronized JSON archive.

# %%
header = '| # | script | lines | json refs | docstring |\n|---:|---|---:|---:|---|'
body = []
for i, rec in enumerate(data['records'], 1):
    doc = (rec.get('docstring_first_line') or '').replace('|', '\\|')
    body.append(f"| {i} | `{rec['path']}` | {rec['line_count']} | {len(rec.get('attached_json', []))} | {doc} |")
display(Markdown('\n'.join([header] + body)))
# Out:
# | # | script | lines | json refs | docstring |
# |---:|---|---:|---:|---|
# | 1 | `examples/force_validation/validation_coenergy_torque_table_consistency.py` | 130 | 1 | Validation-class coenergy/torque angle-table consistency check. |
# | 2 | `examples/force_validation/validation_maxwell_contour_segment_balance.py` | 106 | 1 | Validation-class 2D Maxwell stress contour balance example. |
# | 3 | `examples/force_validation/validation_parallel_wire_virtual_work_force.py` | 143 | 1 | Validation-class two-wire Lorentz/virtual-work force identity. |
# | 4 | `examples/force_validation/validation_torque_waveform_comparison.py` | 153 | 1 | Validation-class periodic torque waveform comparison. |
# | 5 | `examples/force_validation/validation_torque_waveform_health.py` | 149 | 1 | Validation-class torque waveform harmonic health example. |
# | 6 | `examples/force_validation/validation_virtual_work_force_sweep_audit.py` | 145 | 1 | Validation-class virtual-work force sweep audit. |

# %% [markdown]
# ## Integrity Checks

# %%
assert counts['python_scripts'] == len(data['records'])
assert all(len(rec['sha256']) == 64 for rec in data['records'])
assert all(rec.get('source') for rec in data['records'])
print('archive integrity: ok')
# Out:
# archive integrity: ok

# %% [markdown]
# ## Result Payloads and Media

# %%
rows = data.get('topic_json_files', [])
if rows:
    header = '| # | json | sha256 | keys |\n|---:|---|---|---|'
    body = []
    for i, row in enumerate(rows, 1):
        payload = row.get('payload')
        keys = ', '.join(list(payload.keys())[:8]) if isinstance(payload, dict) else type(payload).__name__
        body.append(f"| {i} | `{row['path']}` | `{row['sha256'][:12]}` | {keys.replace('|', '\\|')} |")
    display(Markdown('\n'.join([header] + body)))
else:
    print('no existing JSON payloads found')

media = data.get('media_files', [])
print(f"media artifacts indexed: {len(media)}")
# Out:
# | # | json | sha256 | keys |
# |---:|---|---|---|
# | 1 | `examples/force_validation/validation_coenergy_torque_table_consistency_summary.json` | `c714b6bc1c1e` | angles_rad, checks, coenergy_J, consistency, kind, learning_theme, torque_Nm, validation_class |
# | 2 | `examples/force_validation/validation_maxwell_contour_segment_balance_summary.json` | `833915f7f016` | balance, checks, contour_vertices, kind, learning_theme, uniform_B_T, validation_class |
# | 3 | `examples/force_validation/validation_parallel_wire_virtual_work_force_summary.json` | `acd0a7090fd0` | cases, checks, force_learning, kind, validation_class |
# | 4 | `examples/force_validation/validation_torque_waveform_comparison_summary.json` | `d550969a1d39` | checks, comparison, errors, kind, learning_theme, validation_class |
# | 5 | `examples/force_validation/validation_torque_waveform_health_summary.json` | `964d76a6cd3e` | checks, errors, health, kind, learning_theme, validation_class |
# | 6 | `examples/force_validation/validation_virtual_work_force_sweep_audit_summary.json` | `e0f27417484b` | analytic_radial_force_N_per_m, checks, coenergy_J_per_m, current1_A, current2_A, force_learning, kind, reference_separation_m |
# media artifacts indexed: 0
