# %% [markdown]
# # Equivalence Source Examples Archive
#
# This notebook is a result-saved promotion archive for `examples/equivalence_source`.
# It keeps theory, source inventory, result payloads, and placement policy in one
# human-readable surface while the adjacent JSON remains the durable debug record.
#
# ## Theory and Scope
#
# - This notebook is the topic-specific source/result archive for examples/equivalence_source.
# - It preserves full source, hashes, adjacent JSON payloads, and result media hashes before any pruning decision.
# - Validation-class scripts remain executable in examples until explicit validation_test gates or reusable src APIs exist.
#
# ## Placement Policy
#
# Docs-first topic archive for examples/equivalence_source. Keep scripts until protected docs, panel, package, and validation_test references have been migrated to docs, src, panels, or validation_test.
#
# ## Synchronization
#
# The durable archive is `equivalence_source_examples_archive_results.json`. It stores full source, SHA-256 hashes,
# existing result JSON payloads, media hashes, runtime metadata, and the promotion
# lane for every script in this batch.

# %%
from pathlib import Path
import json
from IPython.display import Markdown, display

archive_path = Path('equivalence_source_examples_archive_results.json')
if not archive_path.exists():
    archive_path = Path('docs/equivalence_source/equivalence_source_examples_archive_results.json')
data = json.loads(archive_path.read_text(encoding='utf-8'))
counts = data['counts']
print(f"topic={data['topic']}")
print(f"python_scripts={counts['python_scripts']}")
print(f"topic_json_files={counts['topic_json_files']}")
print(f"media_files={counts['media_files']}")
print(f"promotion_lane={data['promotion_lane']}")
# Out:
# topic=equivalence_source
# python_scripts=5
# topic_json_files=6
# media_files=0
# promotion_lane=topic_docs_first_archive

# %% [markdown]
# ## Script Inventory
# Generated from the synchronized JSON archive.

# %%
header = '| # | script | lines | json refs | docstring |\n|---:|---|---:|---:|---|'
body = []
for i, rec in enumerate(data['records'], 1):
    doc = (rec.get('docstring_first_line') or '').replace('|', '\\|')
    body.append(f"| {i} | `{rec['path']}` | {rec['line_count']} | {len(rec.get('attached_json', []))} | {doc} |")
display(Markdown('\n'.join([header] + body)))
# Out:
# | # | script | lines | json refs | docstring |
# |---:|---|---:|---:|---|
# | 1 | `examples/equivalence_source/bench_static.py` | 149 | 0 | Phase A benchmark: C++ static kernel vs Python fallback. |
# | 2 | `examples/equivalence_source/null_field_property.py` | 207 | 0 | Null-field property check -- the defining test of the equivalence theorem. |
# | 3 | `examples/equivalence_source/phase1_static_coil.py` | 223 | 0 | Phase 1 -- equivalence-theorem reconstruction vs Biot-Savart (static). |
# | 4 | `examples/equivalence_source/phase2_wpt_harmonic.py` | 230 | 0 | Phase 2 -- equivalence-theorem reconstruction at 1 MHz (time-harmonic). |
# | 5 | `examples/equivalence_source/phase3_e2e_cubit_to_sol.py` | 464 | 0 | Phase 3 -- end-to-end: Cubit .jou -> .vol -> CLI -> CF -> .sol. |

# %% [markdown]
# ## Integrity Checks

# %%
assert counts['python_scripts'] == len(data['records'])
assert all(len(rec['sha256']) == 64 for rec in data['records'])
assert all(rec.get('source') for rec in data['records'])
print('archive integrity: ok')
# Out:
# archive integrity: ok

# %% [markdown]
# ## Result Payloads and Media

# %%
rows = data.get('topic_json_files', [])
if rows:
    header = '| # | json | sha256 | keys |\n|---:|---|---|---|'
    body = []
    for i, row in enumerate(rows, 1):
        payload = row.get('payload')
        keys = ', '.join(list(payload.keys())[:8]) if isinstance(payload, dict) else type(payload).__name__
        body.append(f"| {i} | `{row['path']}` | `{row['sha256'][:12]}` | {keys.replace('|', '\\|')} |")
    display(Markdown('\n'.join([header] + body)))
else:
    print('no existing JSON payloads found')

media = data.get('media_files', [])
print(f"media artifacts indexed: {len(media)}")
# Out:
# | # | json | sha256 | keys |
# |---:|---|---|---|
# | 1 | `examples/equivalence_source/phase1_artifact.nfs.json` | `a974d64fc8b0` | version, omega, metadata, centroids, normals, areas, H_re, H_im |
# | 2 | `examples/equivalence_source/results_bench_static.json` | `95f822587299` | phase, description, acceptance, results |
# | 3 | `examples/equivalence_source/results_null_field.json` | `d3c7800704c0` | test, R_surface_m, n_panels, m_vec_Am2, exterior, interior, overall_passed, wall_time_ext_s |
# | 4 | `examples/equivalence_source/results_phase1.json` | `07e2d9a7e58d` | phase, description, source, extraction, reconstruction, obs_results |
# | 5 | `examples/equivalence_source/results_phase2.json` | `c308bfbb8bb0` | phase, description, source, extraction, reconstruction, obs_results |
# | 6 | `examples/equivalence_source/results_phase3.json` | `62b8dbe32036` | phase, description, mesh_source_kind, source, extraction, cli_result, projection, verification |
# media artifacts indexed: 0
