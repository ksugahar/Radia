# %% [markdown]
# # Open-boundary example archive
#
# This notebook is a result-saved docs promotion of example Python scripts.
# It intentionally pairs Markdown theory with executable inventory cells and an adjacent JSON debug record.
#
# ## Theory and placement
# - This one-script archive ties the lightweight open-boundary usage example to the docs notebook layer.
# - The formulation surface is the exact DtN/CLN boundary operator for scalar exterior problems, with Kelvin-aware material variants covered elsewhere in docs.
# - The example remains as a tiny runnable API smoke while the notebook/JSON pair stores the durable rendered record.
#
# ## Placement policy
# KEEP: small canonical demo for shipped radia.open_boundary; docs/open_boundary/open_boundary_demo.ipynb remains the richer result-bearing showcase.
#
# ## Synchronization policy
# The durable archive is `open_boundary_examples_archive_results.json`. It stores full source, source SHA-256, existing result JSON payloads, runtime metadata, and the promotion lane for every script in this batch.

# %%
from pathlib import Path
import json
from IPython.display import Markdown, display

archive_path = Path('open_boundary_examples_archive_results.json')
if not archive_path.exists():
    archive_path = Path('docs/open_boundary/open_boundary_examples_archive_results.json')
data = json.loads(archive_path.read_text(encoding='utf-8'))
counts = data['counts']
print(f"topic={data['topic']}")
print(f"python_scripts={counts['python_scripts']}")
print(f"attached_json_refs={counts['attached_json_refs']}")
print(f"topic_json_files={counts['topic_json_files']}")
print(f"promotion_lane={data['promotion_lane']}")
# Out:
# topic=open_boundary
# python_scripts=1
# attached_json_refs=0
# topic_json_files=0
# promotion_lane=keep_example_docs_showcase

# %% [markdown]
# ## Script inventory
# The table below is generated from the synchronized JSON archive, not handwritten.

# %%
rows = data['records']
header = '| # | script | lines | json refs | docstring |\n|---:|---|---:|---:|---|'
body = []
for i, rec in enumerate(rows, 1):
    doc = (rec.get('docstring_first_line') or '').replace('|', '\|')
    body.append(f"| {i} | `{rec['path']}` | {rec['line_count']} | {len(rec.get('attached_json', []))} | {doc} |")
display(Markdown('\n'.join([header] + body)))
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\|'
# <>:5: SyntaxWarning: invalid escape sequence '\|'
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_34148\501459127.py:5: SyntaxWarning: invalid escape sequence '\|'
#   doc = (rec.get('docstring_first_line') or '').replace('|', '\|')
# | # | script | lines | json refs | docstring |
# |---:|---|---:|---:|---|
# | 1 | `examples/open_boundary/demo_dtn_cln_usage.py` | 76 | 0 | demo_dtn_cln_usage.py -- using radia.open_boundary (the Zs-DtN-CLN open boundary) |

# %% [markdown]
# ## Integrity checks
# These assertions make the notebook fail if the JSON/source pairing loses coverage.

# %%
assert counts['python_scripts'] == len(data['records'])
assert all(len(rec['sha256']) == 64 for rec in data['records'])
assert all(rec.get('source') for rec in data['records'])
print('archive integrity: ok')
# Out:
# archive integrity: ok

# %% [markdown]
# ## Result payload index
# Existing per-script JSON results remain in the archive so future debugging can compare old numbers with reruns.

# %%
json_rows = data.get('topic_json_files', [])
if json_rows:
    header = '| # | json | sha256 | keys |\n|---:|---|---|---|'
    body = []
    for i, row in enumerate(json_rows, 1):
        payload = row.get('payload')
        keys = ', '.join(list(payload.keys())[:8]) if isinstance(payload, dict) else type(payload).__name__
        body.append(f"| {i} | `{row['path']}` | `{row['sha256'][:12]}` | {keys.replace('|', '\|')} |")
    display(Markdown('\n'.join([header] + body)))
else:
    print('no existing per-script JSON payloads found')
# Out:
# no existing per-script JSON payloads found
# <>:8: SyntaxWarning: invalid escape sequence '\|'
# <>:8: SyntaxWarning: invalid escape sequence '\|'
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_34148\415818180.py:8: SyntaxWarning: invalid escape sequence '\|'
#   body.append(f"| {i} | `{row['path']}` | `{row['sha256'][:12]}` | {keys.replace('|', '\|')} |")
