# %% [markdown]
# # Cubit Mesh Export Examples Archive
#
# This notebook is a result-saved promotion archive for `docs/cubit_mesh_export`.
# It keeps theory, source inventory, result payloads, and placement policy in one
# human-readable surface while the adjacent JSON remains the durable debug record.
#
# ## Theory and Scope
#
# - This notebook is the topic-specific source/result archive for docs/cubit_mesh_export.
# - It preserves full source, hashes, adjacent JSON payloads, and result media hashes before any pruning decision.
# - Validation-class scripts remain executable in examples until explicit validation_test gates or reusable src APIs exist.
#
# ## Placement Policy
#
# Docs-first topic archive for docs/cubit_mesh_export. Keep scripts until protected docs, panel, package, and validation_test references have been migrated to docs, src, panels, or validation_test.
#
# ## Synchronization
#
# The durable archive is `cubit_mesh_export_examples_archive_results.json`. It stores full source, SHA-256 hashes,
# existing result JSON payloads, media hashes, runtime metadata, and the promotion
# lane for every script in this batch.

# %%
from pathlib import Path
import json
from IPython.display import Markdown, display

archive_path = Path('cubit_mesh_export_examples_archive_results.json')
if not archive_path.exists():
    archive_path = Path('docs/cubit_mesh_export/cubit_mesh_export_examples_archive_results.json')
data = json.loads(archive_path.read_text(encoding='utf-8'))
counts = data['counts']
print(f"topic={data['topic']}")
print(f"python_scripts={counts['python_scripts']}")
print(f"topic_json_files={counts['topic_json_files']}")
print(f"media_files={counts['media_files']}")
print(f"promotion_lane={data['promotion_lane']}")
# Out:
# topic=cubit_mesh_export
# python_scripts=25
# topic_json_files=20
# media_files=0
# promotion_lane=topic_docs_first_archive

# %% [markdown]
# ## Script Inventory
# Generated from the synchronized JSON archive.

# %%
header = '| # | script | lines | json refs | docstring |\n|---:|---|---:|---:|---|'
body = []
for i, rec in enumerate(data['records'], 1):
    doc = (rec.get('docstring_first_line') or '').replace('|', '\\|')
    body.append(f"| {i} | `{rec['path']}` | {rec['line_count']} | {len(rec.get('attached_json', []))} | {doc} |")
display(Markdown('\n'.join([header] + body)))
# Out:
# | # | script | lines | json refs | docstring |
# |---:|---|---:|---:|---|
# | 1 | `docs/cubit_mesh_export/gmsh/gmsh_export_example.py` | 52 | 0 | Gmsh Export Example |
# | 2 | `docs/cubit_mesh_export/hex_sphere_highorder/hex_sphere_curved_ngsolve.py` | 61 | 0 | High-order CURVED HEX mesh in NGSolve -- the cubit-mesh-export capability. |
# | 3 | `docs/cubit_mesh_export/hex_sphere_highorder/hex_sphere_poisson_solve.py` | 59 | 0 | Solve a PDE on the curved high-order HEX mesh -- not just integrate it. |
# | 4 | `docs/cubit_mesh_export/nastran/nastran_export_example.py` | 88 | 0 | Nastran Export Example |
# | 5 | `docs/cubit_mesh_export/other_formats/cubit_mesh_export_2d_geo_lukas_format.py` | 78 | 0 |  |
# | 6 | `docs/cubit_mesh_export/other_formats/cubit_mesh_export_3d_cdb.py` | 143 | 0 |  |
# | 7 | `docs/cubit_mesh_export/other_formats/cubit_mesh_export_3d_freefem_mesh.py` | 60 | 0 |  |
# | 8 | `validation_test/cubit_mesh_export/validation_p1_surface_triangle_element_summary.py` | 114 | 1 | Validation-class P1 surface-triangle element teaching block. |
# | 9 | `validation_test/cubit_mesh_export/validation_vol_boundary_condition_assignment.py` | 190 | 1 | Validation-class boundary-condition assignment audit for tri/tet .vol meshes. |
# | 10 | `validation_test/cubit_mesh_export/validation_vol_boundary_edge_inventory.py` | 175 | 1 | Validation-class Netgen .vol boundary-local edge inventory. |
# | 11 | `validation_test/cubit_mesh_export/validation_vol_boundary_inventory.py` | 216 | 1 | Validation-class Netgen .vol named-boundary inventory checks. |
# | 12 | `validation_test/cubit_mesh_export/validation_vol_boundary_normal_vectors.py` | 226 | 1 | Validation-class `.vol` boundary normal/vector-area rows. |
# | 13 | `validation_test/cubit_mesh_export/validation_vol_boundary_oriented_edges.py` | 137 | 1 | Validation-class Netgen .vol boundary oriented-edge table. |
# | 14 | `validation_test/cubit_mesh_export/validation_vol_boundary_pressure_force.py` | 134 | 1 | Validation-class `.vol` boundary pressure-to-force rows. |
# | 15 | `validation_test/cubit_mesh_export/validation_vol_boundary_pressure_moment.py` | 190 | 1 | Validation-class `.vol` boundary pressure force/moment rows. |
# | 16 | `validation_test/cubit_mesh_export/validation_vol_boundary_pressure_resultant.py` | 145 | 1 | Validation-class `.vol` boundary pressure resultant summary. |
# | 17 | `validation_test/cubit_mesh_export/validation_vol_boundary_tet_face_incidence.py` | 159 | 1 | Validation-class `.vol` boundary-to-tetrahedron face incidence. |
# | 18 | `validation_test/cubit_mesh_export/validation_vol_boundary_traction_moment.py` | 180 | 1 | Validation-class `.vol` boundary vector-traction force/moment rows. |
# | 19 | `validation_test/cubit_mesh_export/validation_vol_fem_bem_topology.py` | 219 | 1 | Validation-class Netgen .vol FEM/BEM topology checks. |
# | 20 | `validation_test/cubit_mesh_export/validation_vol_material_interface.py` | 223 | 1 | Validation-class Netgen .vol material/interface inventory example. |
# | 21 | `validation_test/cubit_mesh_export/validation_vol_mesh_health.py` | 202 | 1 | Validation-class Netgen .vol mesh health example. |
# | 22 | `validation_test/cubit_mesh_export/validation_vol_p1_trace_matrix.py` | 144 | 1 | Validation-class P1 FEM/BEM trace matrix from a tri/tet .vol mesh. |
# | 23 | `validation_test/cubit_mesh_export/validation_vol_surface_closure.py` | 155 | 1 | Validation-class Netgen .vol surface-closure checks for FEM/BEM intake. |
# | 24 | `validation_test/cubit_mesh_export/validation_vol_surface_triangle_quality.py` | 208 | 1 | Validation-class Netgen .vol surface triangle quality example. |
# | 25 | `validation_test/cubit_mesh_export/validation_vol_tet_quality.py` | 199 | 1 | Validation-class Netgen .vol tetrahedron quality example. |

# %% [markdown]
# ## Integrity Checks

# %%
assert counts['python_scripts'] == len(data['records'])
assert all(len(rec['sha256']) == 64 for rec in data['records'])
assert all(rec.get('source') for rec in data['records'])
print('archive integrity: ok')
# Out:
# archive integrity: ok

# %% [markdown]
# ## Result Payloads and Media

# %%
rows = data.get('topic_json_files', [])
if rows:
    header = '| # | json | sha256 | keys |\n|---:|---|---|---|'
    body = []
    for i, row in enumerate(rows, 1):
        payload = row.get('payload')
        keys = ', '.join(list(payload.keys())[:8]) if isinstance(payload, dict) else type(payload).__name__
        body.append(f"| {i} | `{row['path']}` | `{row['sha256'][:12]}` | {keys.replace('|', '\\|')} |")
    display(Markdown('\n'.join([header] + body)))
else:
    print('no existing JSON payloads found')

media = data.get('media_files', [])
print(f"media artifacts indexed: {len(media)}")
# Out:
# | # | json | sha256 | keys |
# |---:|---|---|---|
# | 1 | `docs/cubit_mesh_export/netgen/3turnCoil.vol.json` | `595cf6aec4fc` | materials, boundaries, edges, n_elements, n_points, order, export_time_s |
# | 2 | `docs/cubit_mesh_export/netgen/3turnCoil_unite.vol.json` | `08b1af3d84e7` | materials, boundaries, edges, n_elements, n_points, order, export_time_s |
# | 3 | `validation_test/cubit_mesh_export/validation_p1_surface_triangle_element_summary.json` | `6b6f36c01e37` | checks, element_summary, kind, learning_theme, validation_class |
# | 4 | `validation_test/cubit_mesh_export/validation_vol_boundary_condition_assignment_summary.json` | `4677f9b32c5b` | checks, clean_assignment, kind, learning_theme, mesh_summary, missing_assignment, typo_assignment, validation_class |
# | 5 | `validation_test/cubit_mesh_export/validation_vol_boundary_edge_inventory_summary.json` | `9cf0130f1b04` | checks, inventory, kind, learning_theme, validation_class |
# | 6 | `validation_test/cubit_mesh_export/validation_vol_boundary_inventory_summary.json` | `86fa7e339b84` | checks, problem, records, validation_class |
# | 7 | `validation_test/cubit_mesh_export/validation_vol_boundary_normal_vectors_summary.json` | `396d7e4f9358` | kind, validation_class, force_learning, checks, records |
# | 8 | `validation_test/cubit_mesh_export/validation_vol_boundary_oriented_edges_summary.json` | `4bab3c1c17e5` | checks, edge_summary, kind, learning_theme, validation_class |
# | 9 | `validation_test/cubit_mesh_export/validation_vol_boundary_pressure_force_summary.json` | `a75c271ae334` | kind, validation_class, force_learning, checks, records |
# | 10 | `validation_test/cubit_mesh_export/validation_vol_boundary_pressure_moment_summary.json` | `ae38df2ad2e8` | kind, validation_class, force_learning, checks, records |
# | 11 | `validation_test/cubit_mesh_export/validation_vol_boundary_pressure_resultant_summary.json` | `4c44c55bcf1c` | kind, validation_class, force_learning, checks, records |
# | 12 | `validation_test/cubit_mesh_export/validation_vol_boundary_tet_face_incidence_summary.json` | `5fcad57892d2` | checks, incidence_summary, kind, mesh_summary, validation_class |
# | 13 | `validation_test/cubit_mesh_export/validation_vol_boundary_traction_moment_summary.json` | `fce361a00244` | kind, validation_class, force_learning, checks, records |
# | 14 | `validation_test/cubit_mesh_export/validation_vol_fem_bem_topology_summary.json` | `190629647209` | checks, problem, records, validation_class |
# | 15 | `validation_test/cubit_mesh_export/validation_vol_material_interface_summary.json` | `bc249805c375` | built_in, kind, validation_class |
# | 16 | `validation_test/cubit_mesh_export/validation_vol_mesh_health_summary.json` | `efacfad23f35` | kind, validation_class, gate, lesson, builtin_cases, checks |
# | 17 | `validation_test/cubit_mesh_export/validation_vol_p1_trace_matrix_summary.json` | `e8443baf15be` | checks, kind, learning_theme, mesh_summary, trace_matrix, validation_class |
# | 18 | `validation_test/cubit_mesh_export/validation_vol_surface_closure_summary.json` | `9b71f2c4f4aa` | checks, problem, records |
# | 19 | `validation_test/cubit_mesh_export/validation_vol_surface_triangle_quality_summary.json` | `a1339869ee70` | kind, validation_class, quality_definition, release_learning, builtin_cases, checks |
# | 20 | `validation_test/cubit_mesh_export/validation_vol_tet_quality_summary.json` | `47bec591420d` | kind, validation_class, quality_definition, builtin_cases, checks |
# media artifacts indexed: 0
