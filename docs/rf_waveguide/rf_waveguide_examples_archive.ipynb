# %% [markdown]
# # Rf Waveguide Examples Archive
#
# This notebook is a result-saved promotion archive for `examples/rf_waveguide`.
# It keeps theory, source inventory, result payloads, and placement policy in one
# human-readable surface while the adjacent JSON remains the durable debug record.
#
# ## Theory and Scope
#
# - This notebook is the topic-specific source/result archive for examples/rf_waveguide.
# - It preserves full source, hashes, adjacent JSON payloads, and result media hashes before any pruning decision.
# - Validation-class scripts remain executable in examples until explicit validation_test gates or reusable src APIs exist.
#
# ## Placement Policy
#
# Docs-first topic archive for examples/rf_waveguide. Keep scripts until protected docs, panel, package, and validation_test references have been migrated to docs, src, panels, or validation_test.
#
# ## Synchronization
#
# The durable archive is `rf_waveguide_examples_archive_results.json`. It stores full source, SHA-256 hashes,
# existing result JSON payloads, media hashes, runtime metadata, and the promotion
# lane for every script in this batch.

# %%
from pathlib import Path
import json
from IPython.display import Markdown, display

archive_path = Path('rf_waveguide_examples_archive_results.json')
if not archive_path.exists():
    archive_path = Path('docs/rf_waveguide/rf_waveguide_examples_archive_results.json')
data = json.loads(archive_path.read_text(encoding='utf-8'))
counts = data['counts']
print(f"topic={data['topic']}")
print(f"python_scripts={counts['python_scripts']}")
print(f"topic_json_files={counts['topic_json_files']}")
print(f"media_files={counts['media_files']}")
print(f"promotion_lane={data['promotion_lane']}")
# Out:
# topic=rf_waveguide
# python_scripts=17
# topic_json_files=17
# media_files=0
# promotion_lane=topic_docs_first_archive

# %% [markdown]
# ## Script Inventory
# Generated from the synchronized JSON archive.

# %%
header = '| # | script | lines | json refs | docstring |\n|---:|---|---:|---:|---|'
body = []
for i, rec in enumerate(data['records'], 1):
    doc = (rec.get('docstring_first_line') or '').replace('|', '\\|')
    body.append(f"| {i} | `{rec['path']}` | {rec['line_count']} | {len(rec.get('attached_json', []))} | {doc} |")
display(Markdown('\n'.join([header] + body)))
# Out:
# | # | script | lines | json refs | docstring |
# |---:|---|---:|---:|---|
# | 1 | `examples/rf_waveguide/validation_circular_waveguide_mode_sweep.py` | 167 | 1 | Validation-class circular-waveguide cutoff and band sweep. |
# | 2 | `examples/rf_waveguide/validation_oblique_radiation_pressure.py` | 151 | 1 | Validation-class oblique-incidence radiation pressure. |
# | 3 | `examples/rf_waveguide/validation_one_port_reflection_momentum_force.py` | 128 | 1 | Validation-class one-port reflection momentum force. |
# | 4 | `examples/rf_waveguide/validation_one_port_reflection_sweep_force.py` | 160 | 1 | Validation-class one-port reflection sweep momentum force. |
# | 5 | `examples/rf_waveguide/validation_poynting_patch_force_vector.py` | 149 | 1 | Validation-class vector radiation force from a Poynting vector. |
# | 6 | `examples/rf_waveguide/validation_radiation_pressure_poynting.py` | 151 | 1 | Validation-class RF radiation pressure from Poynting power. |
# | 7 | `examples/rf_waveguide/validation_scattering_radiation_force.py` | 122 | 1 | Validation-class radiation force from normal-incidence scattering powers. |
# | 8 | `examples/rf_waveguide/validation_tem_line_geometry_sweep.py` | 221 | 1 | Validation-class TEM transmission-line geometry sweep. |
# | 9 | `examples/rf_waveguide/validation_time_harmonic_maxwell_stress.py` | 128 | 1 | Validation-class time-harmonic Maxwell stress identities. |
# | 10 | `examples/rf_waveguide/validation_two_port_scattering_momentum_force.py` | 112 | 1 | Validation-class two-port scattering momentum force. |
# | 11 | `examples/rf_waveguide/validation_two_port_scattering_sweep_force.py` | 152 | 1 | Validation-class two-port scattering sweep momentum force. |
# | 12 | `examples/rf_waveguide/validation_two_port_sparameter_health.py` | 136 | 1 | Validation-class two-port S-parameter sweep health example. |
# | 13 | `examples/rf_waveguide/validation_waveguide_conductor_loss.py` | 195 | 1 | Validation-class rectangular-waveguide conductor-loss sweep. |
# | 14 | `examples/rf_waveguide/validation_waveguide_mode_table_sweep.py` | 177 | 1 | Validation-class rectangular-waveguide mode-table sweep. |
# | 15 | `examples/rf_waveguide/validation_waveguide_multisection_filter.py` | 193 | 1 | Validation-class rectangular-waveguide multi-section filter example. |
# | 16 | `examples/rf_waveguide/validation_waveguide_te10_port_normalization.py` | 109 | 1 | Validation-class TE10 rectangular-waveguide port normalization. |
# | 17 | `examples/rf_waveguide/validation_waveguide_vna_calibration.py` | 167 | 1 | Validation-class rectangular-waveguide VNA calibration example. |

# %% [markdown]
# ## Integrity Checks

# %%
assert counts['python_scripts'] == len(data['records'])
assert all(len(rec['sha256']) == 64 for rec in data['records'])
assert all(rec.get('source') for rec in data['records'])
print('archive integrity: ok')
# Out:
# archive integrity: ok

# %% [markdown]
# ## Result Payloads and Media

# %%
rows = data.get('topic_json_files', [])
if rows:
    header = '| # | json | sha256 | keys |\n|---:|---|---|---|'
    body = []
    for i, row in enumerate(rows, 1):
        payload = row.get('payload')
        keys = ', '.join(list(payload.keys())[:8]) if isinstance(payload, dict) else type(payload).__name__
        body.append(f"| {i} | `{row['path']}` | `{row['sha256'][:12]}` | {keys.replace('|', '\\|')} |")
    display(Markdown('\n'.join([header] + body)))
else:
    print('no existing JSON payloads found')

media = data.get('media_files', [])
print(f"media artifacts indexed: {len(media)}")
# Out:
# | # | json | sha256 | keys |
# |---:|---|---|---|
# | 1 | `examples/rf_waveguide/validation_circular_waveguide_mode_sweep_summary.json` | `4c71b91b39b3` | kind, validation_class, radius_m, mode_table, band_summaries, checks |
# | 2 | `examples/rf_waveguide/validation_oblique_radiation_pressure_summary.json` | `675de7847c31` | area_m2, checks, intensity_W_per_m2, kind, rows, speed_m_per_s, validation_class |
# | 3 | `examples/rf_waveguide/validation_one_port_reflection_momentum_force_summary.json` | `250f3babd54b` | checks, force_learning, incident_direction, incident_power_W, kind, p_over_c_N, rows, validation_class |
# | 4 | `examples/rf_waveguide/validation_one_port_reflection_sweep_force_summary.json` | `7caaaa201b5b` | checks, errors, force_learning, input, kind, passivity_probe, sweep, validation_class |
# | 5 | `examples/rf_waveguide/validation_poynting_patch_force_vector_summary.json` | `2fa5ff36d293` | cases, checks, force_learning, kind, parameters, validation_class |
# | 6 | `examples/rf_waveguide/validation_radiation_pressure_poynting_summary.json` | `f6ade4b6c7b3` | kind, validation_class, guide, rows, checks |
# | 7 | `examples/rf_waveguide/validation_scattering_radiation_force_summary.json` | `da9f62a72ad5` | checks, force_learning, incident_power_W, kind, rows, validation_class |
# | 8 | `examples/rf_waveguide/validation_tem_line_geometry_sweep_summary.json` | `1d4c4cbcb5c2` | kind, validation_class, coax_eps_r, coax_rows, two_wire_rows, microstrip_rows, image_symmetry_rows, checks |
# | 9 | `examples/rf_waveguide/validation_time_harmonic_maxwell_stress_summary.json` | `0d292bf08942` | kind, validation_class, convention, area_m2, peak_summary, rms_summary, circular_stress_tensor_Pa, checks |
# | 10 | `examples/rf_waveguide/validation_two_port_scattering_momentum_force_summary.json` | `dade67af1ed3` | kind, power_incident_W, p_over_c_N, cases |
# | 11 | `examples/rf_waveguide/validation_two_port_scattering_sweep_force_summary.json` | `8b1a038aefb4` | checks, kind, passivity_probe, rf_learning, sweep, validation_class |
# | 12 | `examples/rf_waveguide/validation_two_port_sparameter_health_summary.json` | `94d8a9b33e00` | active_probe, checks, health, kind, nonreciprocal_probe, rf_learning, validation_class |
# | 13 | `examples/rf_waveguide/validation_waveguide_conductor_loss_summary.json` | `5955f122a222` | kind, validation_class, guide, material, frequency_rows, length_rows, conductivity_rows, checks |
# | 14 | `examples/rf_waveguide/validation_waveguide_mode_table_sweep_summary.json` | `7e7c8d431025` | kind, validation_class, guide, mode_table, frequency_rows, checks |
# | 15 | `examples/rf_waveguide/validation_waveguide_multisection_filter_summary.json` | `063f20517553` | kind, validation_class, width_a_m, center_frequency_hz, quarter_slab, bragg_sections, frequency_rows, checks |
# | 16 | `examples/rf_waveguide/validation_waveguide_te10_port_normalization_summary.json` | `246cacaab95f` | kind, validation_class, guide, rows, checks |
# | 17 | `examples/rf_waveguide/validation_waveguide_vna_calibration_summary.json` | `0d7ef27e6581` | kind, validation_class, guide, offset_short, dispersion_rows, dielectric_slab_10ghz |
# media artifacts indexed: 0
