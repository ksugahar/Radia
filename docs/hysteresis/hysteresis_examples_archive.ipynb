# %% [markdown]
# # Hysteresis Examples Archive
#
# This notebook is a result-saved promotion archive for `examples/hysteresis`.
# It keeps theory, source inventory, result payloads, and placement policy in one
# human-readable surface while the adjacent JSON remains the durable debug record.
#
# ## Theory and Scope
#
# - This notebook is the topic-specific source/result archive for examples/hysteresis.
# - It preserves full source, hashes, adjacent JSON payloads, and result media hashes before any pruning decision.
# - Validation-class scripts remain executable in examples until explicit validation_test gates or reusable src APIs exist.
#
# ## Placement Policy
#
# Docs-first topic archive for examples/hysteresis. Keep scripts until protected docs, panel, package, and validation_test references have been migrated to docs, src, panels, or validation_test.
#
# ## Synchronization
#
# The durable archive is `hysteresis_examples_archive_results.json`. It stores full source, SHA-256 hashes,
# existing result JSON payloads, media hashes, runtime metadata, and the promotion
# lane for every script in this batch.

# %%
from pathlib import Path
import json
from IPython.display import Markdown, display

archive_path = Path('hysteresis_examples_archive_results.json')
if not archive_path.exists():
    archive_path = Path('docs/hysteresis/hysteresis_examples_archive_results.json')
data = json.loads(archive_path.read_text(encoding='utf-8'))
counts = data['counts']
print(f"topic={data['topic']}")
print(f"python_scripts={counts['python_scripts']}")
print(f"topic_json_files={counts['topic_json_files']}")
print(f"media_files={counts['media_files']}")
print(f"promotion_lane={data['promotion_lane']}")
# Out:
# topic=hysteresis
# python_scripts=8
# topic_json_files=0
# media_files=13
# promotion_lane=topic_docs_first_archive

# %% [markdown]
# ## Script Inventory
# Generated from the synchronized JSON archive.

# %%
header = '| # | script | lines | json refs | docstring |\n|---:|---|---:|---:|---|'
body = []
for i, rec in enumerate(data['records'], 1):
    doc = (rec.get('docstring_first_line') or '').replace('|', '\\|')
    body.append(f"| {i} | `{rec['path']}` | {rec['line_count']} | {len(rec.get('attached_json', []))} | {doc} |")
display(Markdown('\n'.join([header] + body)))
# Out:
# | # | script | lines | json refs | docstring |
# |---:|---|---:|---:|---|
# | 1 | `examples/hysteresis/bqm_model.py` | 1087 | 0 | Bergqvist Quadruplet Model (BQM) - Table-based implementation. |
# | 2 | `examples/hysteresis/play_vs_energy/compare_play_vs_energy.py` | 202 | 0 | B-input Play vs B-input Energy (rev/irrev separation) on Potter-Schmulian. |
# | 3 | `examples/hysteresis/regenerate_binput_play_fixture.py` | 88 | 0 | Regenerate binput_play_fixture.npz with the FIXED build_shape_functions. |
# | 4 | `examples/hysteresis/verify_bqm_table.py` | 580 | 0 | Verify BQM Python implementation against MATLAB results. |
# | 5 | `examples/hysteresis/verify_coenergy_feasibility.py` | 354 | 0 | Verify feasibility of coenergy model for B-input play model. |
# | 6 | `examples/hysteresis/verify_cpp_hysteresis.py` | 352 | 0 | Verification of C++ energy-based hysteresis material with real B-input data. |
# | 7 | `examples/hysteresis/verify_cpp_play_model.py` | 370 | 0 | Verify C++ Play hysteresis material against Python reference. |
# | 8 | `examples/hysteresis/verify_play_to_energy.py` | 306 | 0 | Verify B-input Play model from Potter-Schmulian data (Step 3). |

# %% [markdown]
# ## Integrity Checks

# %%
assert counts['python_scripts'] == len(data['records'])
assert all(len(rec['sha256']) == 64 for rec in data['records'])
assert all(rec.get('source') for rec in data['records'])
print('archive integrity: ok')
# Out:
# archive integrity: ok

# %% [markdown]
# ## Result Payloads and Media

# %%
rows = data.get('topic_json_files', [])
if rows:
    header = '| # | json | sha256 | keys |\n|---:|---|---|---|'
    body = []
    for i, row in enumerate(rows, 1):
        payload = row.get('payload')
        keys = ', '.join(list(payload.keys())[:8]) if isinstance(payload, dict) else type(payload).__name__
        body.append(f"| {i} | `{row['path']}` | `{row['sha256'][:12]}` | {keys.replace('|', '\\|')} |")
    display(Markdown('\n'.join([header] + body)))
else:
    print('no existing JSON payloads found')

media = data.get('media_files', [])
print(f"media artifacts indexed: {len(media)}")
# Out:
# no existing JSON payloads found
# media artifacts indexed: 13
