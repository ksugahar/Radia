# %% [markdown]
# # Stream-Function Examples Catalog
#
# The stream-function examples already have theory, regularization, and deformation notebooks. This catalog tracks the remaining scripts under `examples/stream_function` after the verify/cohomology/bench validation lane was promoted to `validation_test/stream_function`.

# %%
from pathlib import Path
import json
NOTEBOOK_DIR = Path.cwd()
if not (NOTEBOOK_DIR / 'examples_catalog_results.json').exists():
    NOTEBOOK_DIR = Path('docs/stream_function').resolve()
archive = json.loads((NOTEBOOK_DIR / 'examples_catalog_results.json').read_text(encoding='utf-8'))
print(json.dumps(archive['summary'], ensure_ascii=False, indent=2))
# Out:
# {
#   "script_count": 26,
#   "artifact_count": 45,
#   "lane_counts": {
#     "docs_fusion_showcase": 3,
#     "docs_helper_or_tooling": 1,
#     "docs_regularization_showcase": 7,
#     "docs_showcase_candidate": 8,
#     "docs_showcase_plus_src_api_review": 2,
#     "docs_theory_showcase": 5
#   },
#   "subdir_counts": {
#     ".": 26
#   },
#   "protected_script_count": 26,
#   "promoted_validation_lane": "verify/cohomology/bench scripts moved to validation_test/stream_function"
# }

# %% [markdown]
# ## Reading the lanes
#
# `docs_*` lanes are human-facing notebook/showcase candidates; `validation_*` lanes need runnable checks under `validation_test/`; `src_api_*` lanes contain reusable behavior that should stop living as loose examples. The verify/cohomology/bench validation lane has already moved.

# %%
from IPython.display import Markdown, display
from collections import Counter
records = archive['records']
lane_counts = Counter(r['lane'] for r in records)
assert sum(lane_counts.values()) == archive['summary']['script_count']
display(Markdown('''## Migration lanes

| lane | count |
| --- | --- |
| docs_fusion_showcase | 3 |
| docs_helper_or_tooling | 1 |
| docs_regularization_showcase | 7 |
| docs_showcase_candidate | 8 |
| docs_showcase_plus_src_api_review | 2 |
| docs_theory_showcase | 5 |'''))
display(Markdown('''## Subdirectories

| subdir | python_files |
| --- | --- |
| . | 26 |'''))
# Out:
# ## Migration lanes
#
# | lane | count |
# | --- | --- |
# | docs_fusion_showcase | 3 |
# | docs_helper_or_tooling | 1 |
# | docs_regularization_showcase | 7 |
# | docs_showcase_candidate | 8 |
# | docs_showcase_plus_src_api_review | 2 |
# | docs_theory_showcase | 5 |
# ## Subdirectories
#
# | subdir | python_files |
# | --- | --- |
# | . | 26 |

# %%
display(Markdown('''## Python inventory

| path | lane | refs | artifacts | lines | sha256 | summary |
| --- | --- | --- | --- | --- | --- | --- |
| examples/stream_function/demo_active_shield.py | docs_showcase_candidate | 2 | 2 | 275 | 77562a9eecc2 | Active-shielding demo: primary + shield gradient coil (Turner 1986). Designs a Gz gradient |
| examples/stream_function/demo_cmaes_magnet_design.py | docs_showcase_candidate | 3 | 1 | 138 | 4f35a66b3289 | CMA-ES magnetization-direction design (the nonlinear counterpart of TSVD). The (ACA+)+TSVD |
| examples/stream_function/demo_coil_design_gx.py | docs_showcase_candidate | 2 | 1 | 294 | 7b620bf3bd2f | Transverse gradient (Gx) coil design via the stream function method. The HARD 2D companion |
| examples/stream_function/demo_coil_design_gz.py | docs_showcase_candidate | 1 | 1 | 211 | dd032a0ede7b | Cylindrical z-gradient (Gz) coil design via the stream function method. End-to-end demonst |
| examples/stream_function/demo_coil_field_synthesis.py | docs_showcase_candidate | 1 | 1 | 123 | d65cc11f5bf6 | Coil field synthesis with the (ACA+)+TSVD least-norm solver. Stream-function-style coil de |
| examples/stream_function/demo_fmm_biot_savart.py | docs_showcase_candidate | 1 | 2 | 503 | 7c8646412a45 | FMM Biot-Savart benchmark: ngsolve.bem.BiotSavartCF vs LinearForm matrix path. Compares tw |
| examples/stream_function/demo_magnet_array.py | docs_showcase_candidate | 1 | 1 | 96 | 44147b87f563 | Same (ACA+)+TSVD solver on a permanent-magnet array (magnetic material). This is the SAME  |
| examples/stream_function/demo_pareto_cylinder.py | docs_regularization_showcase | 3 | 0 | 139 | ae334adc78e4 | Cylinder Gx fingerprint: (homogeneity, peak-J) Pareto front via folded Tikhonov + ACA+TSVD |
| examples/stream_function/demo_pareto_cylinder_deform.py | docs_regularization_showcase | 3 | 0 | 229 | db99d2b0cb07 | Cylinder sheet-metal (bankin-ho / 板金) on the (homogeneity, peak-J) Pareto front: IN-SURFAC |
| examples/stream_function/demo_pareto_deform.py | docs_regularization_showcase | 3 | 0 | 211 | 41c4e434fce3 | Sheet-metal (bankin-ho / 板金) deformation pushes the (homogeneity, peak-J) Pareto front. Th |
| examples/stream_function/demo_pareto_geometry_nsga.py | docs_regularization_showcase | 3 | 0 | 188 | 1526cb8a28cf | Push the (homogeneity, peak-J) Pareto front with the GEOMETRY lever, and trace the joint f |
| examples/stream_function/demo_pareto_tikhonov_aca.py | docs_regularization_showcase | 3 | 0 | 313 | 8a197bafa2d4 | Pareto optimisation via folded Tikhonov + ACA+TSVD. ONE ACA+TSVD factorisation of the Biot |
| examples/stream_function/demo_planar_uniform_coil.py | docs_theory_showcase | 2 | 1 | 464 | a36cd4eed86b | SF -> planar uniform-Bz coil (the easy end of single-stroke complexity). Source surface: s |
| examples/stream_function/demo_planar_uniform_fem_psi.py | docs_theory_showcase | 6 | 2 | 818 | 521b5ee8ec61 | SF coil design with psi as direct H1 FE unknown on a surface mesh. Same problem as demo_pl |
| examples/stream_function/demo_planar_uniform_fem_psi_aca.py | docs_theory_showcase | 1 | 2 | 260 | 32781de2810d | SF coil design: H1 FE psi + Radia (ACA+)+TSVD via HACApK. Same target as ``demo_planar_uni |
| examples/stream_function/demo_planar_uniform_fem_psi_advanced.py | docs_theory_showcase | 8 | 1 | 1052 | dc12a01c7386 | SF coil design: H1 FE psi + advanced regularization + surface deformation. Extends ``demo_ |
| examples/stream_function/demo_reg_hyperparam_aca.py | docs_regularization_showcase | 5 | 0 | 342 | d88f8aceec7b | Optimise the REGULARISATION SHAPE (not the geometry) via Optuna, with the ACA+TSVD factori |
| examples/stream_function/demo_regcoil_fusion.py | docs_fusion_showcase | 4 | 6 | 620 | a8ae7bd0003b | mini-REGCOIL / NESCOIL: a fusion coil-design (stellarator Stage-2) demo. The stream-functi |
| examples/stream_function/demo_regcoil_fusion_advanced.py | docs_fusion_showcase | 3 | 6 | 462 | 030a19b6553f | Advanced fusion coil design -- coil force / stress, a REAL VMEC equilibrium, and a FOCUS-s |
| examples/stream_function/demo_regcoil_parity_deliverable.py | docs_fusion_showcase | 4 | 0 | 125 | 359104d1e550 | demo_regcoil_parity_deliverable.py -- (a) of "surpass NESCOIL/REGCOIL". REGCOIL/NESCOIL/FO |
| examples/stream_function/demo_regularized_aca.py | docs_regularization_showcase | 6 | 1 | 274 | bc37fbe0b55d | All 5 SF regularisations routed through the cached ``RegularizedTSVD``. Demonstrates the r |
| examples/stream_function/demo_sf_to_peec_gx.py | docs_showcase_plus_src_api_review | 6 | 1 | 1674 | 17115867e6b2 | End-to-end workflow: SF -> single-stroke fingerprint coil -> CAD -> PEEC -> field (Gx). Tr |
| examples/stream_function/demo_sf_to_peec_gz.py | docs_showcase_plus_src_api_review | 2 | 1 | 251 | 278cc019d77b | End-to-end workflow: stream function -> single-stroke CAD coil -> PEEC -> field. Closes th |
| examples/stream_function/demo_shim_coil_purity.py | docs_showcase_candidate | 3 | 2 | 252 | 4f750ad95260 | Shim-coil harmonic PURITY demo (spherical-harmonic target + decomposition). Designs SF sur |
| examples/stream_function/demo_sphere_fe_direct.py | docs_theory_showcase | 4 | 1 | 337 | f96cf3ffeadf | FE-direct order-3 stream-function coil design on an ARBITRARY (curved) former. This is the |
| examples/stream_function/view_sf_coil_gx_gmsh.py | docs_helper_or_tooling | 4 | 0 | 481 | d76ab7924f1e | Open the Gx fingerprint coil structure in GMSH for visualisation. Three modes: --mode cont |'''))
# Out:
# ## Python inventory
#
# | path | lane | refs | artifacts | lines | sha256 | summary |
# | --- | --- | --- | --- | --- | --- | --- |
# | examples/stream_function/demo_active_shield.py | docs_showcase_candidate | 2 | 2 | 275 | 77562a9eecc2 | Active-shielding demo: primary + shield gradient coil (Turner 1986). Designs a Gz gradient |
# | examples/stream_function/demo_cmaes_magnet_design.py | docs_showcase_candidate | 3 | 1 | 138 | 4f35a66b3289 | CMA-ES magnetization-direction design (the nonlinear counterpart of TSVD). The (ACA+)+TSVD |
# | examples/stream_function/demo_coil_design_gx.py | docs_showcase_candidate | 2 | 1 | 294 | 7b620bf3bd2f | Transverse gradient (Gx) coil design via the stream function method. The HARD 2D companion |
# | examples/stream_function/demo_coil_design_gz.py | docs_showcase_candidate | 1 | 1 | 211 | dd032a0ede7b | Cylindrical z-gradient (Gz) coil design via the stream function method. End-to-end demonst |
# ...

# %%
display(Markdown('''## Protected references

| script | refs | first_ref | lane |
| --- | --- | --- | --- |
| examples/stream_function/demo_active_shield.py | 2 | src/radia.egg-info/SOURCES.txt:876 | docs_showcase_candidate |
| examples/stream_function/demo_cmaes_magnet_design.py | 3 | docs/stream_function.md:218 | docs_showcase_candidate |
| examples/stream_function/demo_coil_design_gx.py | 2 | docs/stream_function/single_stroke.md:133 | docs_showcase_candidate |
| examples/stream_function/demo_coil_design_gz.py | 1 | src/radia.egg-info/SOURCES.txt:879 | docs_showcase_candidate |
| examples/stream_function/demo_coil_field_synthesis.py | 1 | src/radia.egg-info/SOURCES.txt:880 | docs_showcase_candidate |
| examples/stream_function/demo_fmm_biot_savart.py | 1 | src/radia.egg-info/SOURCES.txt:881 | docs_showcase_candidate |
| examples/stream_function/demo_magnet_array.py | 1 | src/radia.egg-info/SOURCES.txt:882 | docs_showcase_candidate |
| examples/stream_function/demo_pareto_cylinder.py | 3 | docs/stream_function/regularization.md:554 | docs_regularization_showcase |
| examples/stream_function/demo_pareto_cylinder_deform.py | 3 | docs/stream_function/regularization.md:515 | docs_regularization_showcase |
| examples/stream_function/demo_pareto_deform.py | 3 | docs/stream_function/regularization.md:498 | docs_regularization_showcase |
| examples/stream_function/demo_pareto_geometry_nsga.py | 3 | docs/stream_function/regularization.md:544 | docs_regularization_showcase |
| examples/stream_function/demo_pareto_tikhonov_aca.py | 3 | docs/stream_function/regularization.md:565 | docs_regularization_showcase |
| examples/stream_function/demo_planar_uniform_coil.py | 2 | docs/stream_function/README.md:79 | docs_theory_showcase |
| examples/stream_function/demo_planar_uniform_fem_psi.py | 6 | docs/stream_function/README.md:82 | docs_theory_showcase |
| examples/stream_function/demo_planar_uniform_fem_psi_aca.py | 1 | src/radia.egg-info/SOURCES.txt:890 | docs_theory_showcase |
| examples/stream_function/demo_planar_uniform_fem_psi_advanced.py | 8 | docs/stream_function/deformation.md:20 | docs_theory_showcase |
| examples/stream_function/demo_reg_hyperparam_aca.py | 5 | docs/stream_function/README.md:104 | docs_regularization_showcase |
| examples/stream_function/demo_regcoil_fusion.py | 4 | docs/stream_function/fusion.md:26 | docs_fusion_showcase |
| examples/stream_function/demo_regcoil_fusion_advanced.py | 3 | docs/stream_function/fusion.md:27 | docs_fusion_showcase |
| examples/stream_function/demo_regcoil_parity_deliverable.py | 4 | docs/stream_function/fusion.md:101 | docs_fusion_showcase |
| examples/stream_function/demo_regularized_aca.py | 6 | docs/stream_function/api.md:113 | docs_regularization_showcase |
| examples/stream_function/demo_sf_to_peec_gx.py | 6 | docs/stream_function/README.md:76 | docs_showcase_plus_src_api_review |
| examples/stream_function/demo_sf_to_peec_gz.py | 2 | docs/stream_function/README.md:73 | docs_showcase_plus_src_api_review |
| examples/stream_function/demo_shim_coil_purity.py | 3 | docs/stream_function/panel.md:84 | docs_showcase_candidate |
| examples/stream_function/demo_sphere_fe_direct.py | 4 | docs/stream_function/README.md:112 | docs_theory_showcase |
| examples/stream_function/view_sf_coil_gx_gmsh.py | 4 | docs/stream_function/single_stroke.md:549 | docs_helper_or_tooling |'''))
# Out:
# ## Protected references
#
# | script | refs | first_ref | lane |
# | --- | --- | --- | --- |
# | examples/stream_function/demo_active_shield.py | 2 | src/radia.egg-info/SOURCES.txt:876 | docs_showcase_candidate |
# | examples/stream_function/demo_cmaes_magnet_design.py | 3 | docs/stream_function.md:218 | docs_showcase_candidate |
# | examples/stream_function/demo_coil_design_gx.py | 2 | docs/stream_function/single_stroke.md:133 | docs_showcase_candidate |
# | examples/stream_function/demo_coil_design_gz.py | 1 | src/radia.egg-info/SOURCES.txt:879 | docs_showcase_candidate |
# | examples/stream_function/demo_coil_field_synthesis.py | 1 | src/radia.egg-info/SOURCES.txt:880 | docs_showcase_candidate |
# | examples/stream_function/demo_fmm_biot_savart.py | 1 | src/radia.egg-info/SOURCES.txt:881 | docs_showcase_candidate |
# | examples/stream_function/demo_magnet_array.py | 1 | src/radia.egg-info/SOURCES.txt:882 | docs_showcase_candidate |
# ...

# %%
current_paths = {r['path'] for r in archive['records']}
assert archive['summary']['script_count'] == len(current_paths)
assert all(r['source']['text'] for r in archive['records'])
assert archive['generated_at_utc']
print('loaded 26 remaining scripts from examples/stream_function
archived 10132 source lines
hashed 45 result/media artifacts
protected scripts: 26
promoted validation lane: validation_test/stream_function
')
# Out:
# loaded 26 remaining scripts from examples/stream_function
# archived 10132 source lines
# hashed 45 result/media artifacts
# protected scripts: 26
# promoted validation lane: validation_test/stream_function
