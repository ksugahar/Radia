# %% [markdown]
# # IH ESIM Benchmark Examples Archive
#
# This notebook is a result-saved promotion archive for `examples/ih_esim_benchmark`.
# It keeps theory, source inventory, result payloads, and placement policy in one
# human-readable surface while the adjacent JSON remains the durable debug record.
#
# ## Theory and Scope
#
# - This archive preserves the IH ESIM benchmark scripts, source hashes, committed JSON, and result media used by the rendered ESIM showcase notebook.
#
# ## Placement Policy
#
# Result-bearing docs source archive for examples/ih_esim_benchmark; keep executable corpus protected until references and result figures are deliberately migrated.
#
# ## Synchronization
#
# The durable archive is `ih_esim_benchmark_examples_archive_results.json`. It stores full source, SHA-256 hashes,
# existing result JSON payloads, media hashes, runtime metadata, and the promotion
# lane for every script in this batch.

# %%
from pathlib import Path
import json
from IPython.display import Markdown, display

archive_path = Path('ih_esim_benchmark_examples_archive_results.json')
if not archive_path.exists():
    archive_path = Path('docs\\ih_esim_benchmark/ih_esim_benchmark_examples_archive_results.json')
data = json.loads(archive_path.read_text(encoding='utf-8'))
counts = data['counts']
print(f"topic={data['topic']}")
print(f"python_scripts={counts['python_scripts']}")
print(f"topic_json_files={counts['topic_json_files']}")
print(f"media_files={counts['media_files']}")
print(f"promotion_lane={data['promotion_lane']}")
# Out:
# topic=ih_esim_benchmark
# python_scripts=10
# topic_json_files=111
# media_files=16
# promotion_lane=docs-archive

# %% [markdown]
# ## Script Inventory
# Generated from the synchronized JSON archive.

# %%
header = '| # | script | lines | json refs | docstring |\n|---:|---|---:|---:|---|'
body = []
for i, rec in enumerate(data['records'], 1):
    doc = (rec.get('docstring_first_line') or '').replace('|', '\\|')
    body.append(f"| {i} | `{rec['path']}` | {rec['line_count']} | {len(rec.get('attached_json', []))} | {doc} |")
display(Markdown('\n'.join([header] + body)))
# Out:
# | # | script | lines | json refs | docstring |
# |---:|---|---:|---:|---|
# | 1 | `examples/ih_esim_benchmark/analytical_bessel_baseline.py` | 113 | 0 | Linear-mu cylinder analytical baseline for ESIM cell verification. |
# | 2 | `examples/ih_esim_benchmark/benchmark.py` | 299 | 0 | ESIM Karl benchmark — 3 production paths × frequency sweep. |
# | 3 | `examples/ih_esim_benchmark/plot.py` | 132 | 0 | Plot benchmark.py results.json -- P_wp, L, wall-time vs frequency. |
# | 4 | `examples/ih_esim_benchmark/plot_cell_envelope.py` | 151 | 0 | Nonlinear cell-solver envelope (validation tier ii). |
# | 5 | `examples/ih_esim_benchmark/plot_digest_figure.py` | 285 | 0 | Digest 2-panel figure: (a) per-element-vs-uniform P_wp gap heatmap |
# | 6 | `examples/ih_esim_benchmark/plot_karl_history.py` | 144 | 0 | Karl iteration convergence diagnostic. |
# | 7 | `examples/ih_esim_benchmark/plot_sweep_heatmap.py` | 188 | 0 | Per-element-vs-scalar P_wp gap heatmap, (f, I_port) sweep. |
# | 8 | `examples/ih_esim_benchmark/plot_zs_per_dof_map.py` | 164 | 0 | Per-DOF Z_s + \|H_t\| map (3-panel hotspot visualisation). |
# | 9 | `examples/ih_esim_benchmark/save_per_panel_sols.py` | 84 | 0 | Persist the per-DOF \|H_t\| and Z_s of an ESIM per-panel run as |
# | 10 | `examples/ih_esim_benchmark/sweep_f_I.py` | 169 | 0 | IH per-element ESIM (f, I_port) dense sweep. |

# %% [markdown]
# ## Integrity Checks

# %%
assert counts['python_scripts'] == len(data['records'])
assert all(len(rec['sha256']) == 64 for rec in data['records'])
assert all(rec.get('source') for rec in data['records'])
print('archive integrity: ok')
# Out:
# archive integrity: ok

# %% [markdown]
# ## Result Payloads and Media

# %%
rows = data.get('topic_json_files', [])
if rows:
    header = '| # | json | sha256 | keys |\n|---:|---|---|---|'
    body = []
    for i, row in enumerate(rows, 1):
        payload = row.get('payload')
        keys = ', '.join(list(payload.keys())[:8]) if isinstance(payload, dict) else type(payload).__name__
        body.append(f"| {i} | `{row['path']}` | `{row['sha256'][:12]}` | {keys.replace('|', '\\|')} |")
    display(Markdown('\n'.join([header] + body)))
else:
    print('no existing JSON payloads found')

media = data.get('media_files', [])
print(f"media artifacts indexed: {len(media)}")
# Out:
# | # | json | sha256 | keys |
# |---:|---|---|---|
# | 1 | `examples/ih_esim_benchmark/results.json` | `a6603f043dd8` | timestamp, hostname, radia_version, problem, frequencies_Hz, paths, sweep |
# | 2 | `examples/ih_esim_benchmark/sweep_data_dense/I100_f100k_per_panel.json` | `01fc8dc21795` | status, method, coil_solver_used, frequency_hz, current_A, L_coil_nH, R_coil_mOhm, t_coil_topology_s |
# | 3 | `examples/ih_esim_benchmark/sweep_data_dense/I100_f100k_scalar.json` | `35d0d2e5426e` | status, method, coil_solver_used, frequency_hz, current_A, L_coil_nH, R_coil_mOhm, t_coil_topology_s |
# | 4 | `examples/ih_esim_benchmark/sweep_data_dense/I100_f10k_per_panel.json` | `cf9be9dfe58d` | status, method, coil_solver_used, frequency_hz, current_A, L_coil_nH, R_coil_mOhm, t_coil_topology_s |
# | 5 | `examples/ih_esim_benchmark/sweep_data_dense/I100_f10k_scalar.json` | `93a9802ae6d7` | status, method, coil_solver_used, frequency_hz, current_A, L_coil_nH, R_coil_mOhm, t_coil_topology_s |
# | 6 | `examples/ih_esim_benchmark/sweep_data_dense/I100_f200k_per_panel.json` | `394616cacb4d` | status, method, coil_solver_used, frequency_hz, current_A, L_coil_nH, R_coil_mOhm, t_coil_topology_s |
# | 7 | `examples/ih_esim_benchmark/sweep_data_dense/I100_f200k_scalar.json` | `664869060e06` | status, method, coil_solver_used, frequency_hz, current_A, L_coil_nH, R_coil_mOhm, t_coil_topology_s |
# | 8 | `examples/ih_esim_benchmark/sweep_data_dense/I100_f20k_per_panel.json` | `e3ab3dcc24d1` | status, method, coil_solver_used, frequency_hz, current_A, L_coil_nH, R_coil_mOhm, t_coil_topology_s |
# | 9 | `examples/ih_esim_benchmark/sweep_data_dense/I100_f20k_scalar.json` | `859b140ac372` | status, method, coil_solver_used, frequency_hz, current_A, L_coil_nH, R_coil_mOhm, t_coil_topology_s |
# | 10 | `examples/ih_esim_benchmark/sweep_data_dense/I100_f500k_per_panel.json` | `34f9587babe3` | status, method, coil_solver_used, frequency_hz, current_A, L_coil_nH, R_coil_mOhm, t_coil_topology_s |
# | 11 | `examples/ih_esim_benchmark/sweep_data_dense/I100_f500k_scalar.json` | `385f742819c3` | status, method, coil_solver_used, frequency_hz, current_A, L_coil_nH, R_coil_mOhm, t_coil_topology_s |
# | 12 | `examples/ih_esim_benchmark/sweep_data_dense/I100_f50k_per_panel.json` | `99049ad52aa2` | status, method, coil_solver_used, frequency_hz, current_A, L_coil_nH, R_coil_mOhm, t_coil_topology_s |
# | 13 | `examples/ih_esim_benchmark/sweep_data_dense/I100_f50k_scalar.json` | `606915c772c5` | status, method, coil_solver_used, frequency_hz, current_A, L_coil_nH, R_coil_mOhm, t_coil_topology_s |
# | 14 | `examples/ih_esim_benchmark/sweep_data_dense/I10_f100k_per_panel.json` | `52fc3d39b6b7` | status, method, coil_solver_used, frequency_hz, current_A, L_coil_nH, R_coil_mOhm, t_coil_topology_s |
# | 15 | `examples/ih_esim_benchmark/sweep_data_dense/I10_f100k_scalar.json` | `e379fa6529d4` | status, method, coil_solver_used, frequency_hz, current_A, L_coil_nH, R_coil_mOhm, t_coil_topology_s |
# | 16 | `examples/ih_esim_benchmark/sweep_data_dense/I10_f10k_per_panel.json` | `10a277077786` | status, method, coil_solver_used, frequency_hz, current_A, L_coil_nH, R_coil_mOhm, t_coil_topology_s |
# | 17 | `examples/ih_esim_benchmark/sweep_data_dense/I10_f10k_scalar.json` | `8381c1042e76` | status, method, coil_solver_used, frequency_hz, current_A, L_coil_nH, R_coil_mOhm, t_coil_topology_s |
# | 18 | `examples/ih_esim_benchmark/sweep_data_dense/I10_f200k_per_panel.json` | `94af91df2c39` | status, method, coil_solver_used, frequency_hz, current_A, L_coil_nH, R_coil_mOhm, t_coil_topology_s |
# | 19 | `examples/ih_esim_benchmark/sweep_data_dense/I10_f200k_scalar.json` | `ac1d0c8a753f` | status, method, coil_solver_used, frequency_hz, current_A, L_coil_nH, R_coil_mOhm, t_coil_topology_s |
# | 20 | `examples/ih_esim_benchmark/sweep_data_dense/I10_f20k_per_panel.json` | `beb375f9c0c2` | status, method, coil_solver_used, frequency_hz, current_A, L_coil_nH, R_coil_mOhm, t_coil_topology_s |
# | 21 | `examples/ih_esim_benchmark/sweep_data_dense/I10_f20k_scalar.json` | `69b56f557770` | status, method, coil_solver_used, frequency_hz, current_A, L_coil_nH, R_coil_mOhm, t_coil_topology_s |
# | 22 | `examples/ih_esim_benchmark/sweep_data_dense/I10_f500k_per_panel.json` | `6cea3606c0d8` | status, method, coil_solver_used, frequency_hz, current_A, L_coil_nH, R_coil_mOhm, t_coil_topology_s |
# | 23 | `examples/ih_esim_benchmark/sweep_data_dense/I10_f500k_scalar.json` | `8416cd0791ea` | status, method, coil_solver_used, frequency_hz, current_A, L_coil_nH, R_coil_mOhm, t_coil_topology_s |
# | 24 | `examples/ih_esim_benchmark/sweep_data_dense/I10_f50k_per_panel.json` | `e3e3869c16e2` | status, method, coil_solver_used, frequency_hz, current_A, L_coil_nH, R_coil_mOhm, t_coil_topology_s |
# | 25 | `examples/ih_esim_benchmark/sweep_data_dense/I10_f50k_scalar.json` | `6e5ad916a720` | status, method, coil_solver_used, frequency_hz, current_A, L_coil_nH, R_coil_mOhm, t_coil_topology_s |
# | 26 | `examples/ih_esim_benchmark/sweep_data_dense/I1_f100k_per_panel.json` | `4472c781ad79` | status, method, coil_solver_used, frequency_hz, current_A, L_coil_nH, R_coil_mOhm, t_coil_topology_s |
# | 27 | `examples/ih_esim_benchmark/sweep_data_dense/I1_f100k_scalar.json` | `f4646b840016` | status, method, coil_solver_used, frequency_hz, current_A, L_coil_nH, R_coil_mOhm, t_coil_topology_s |
# | 28 | `examples/ih_esim_benchmark/sweep_data_dense/I1_f10k_per_panel.json` | `a5c4fd90cd50` | status, method, coil_solver_used, frequency_hz, current_A, L_coil_nH, R_coil_mOhm, t_coil_topology_s |
# | 29 | `examples/ih_esim_benchmark/sweep_data_dense/I1_f10k_scalar.json` | `ab0335a88f51` | status, method, coil_solver_used, frequency_hz, current_A, L_coil_nH, R_coil_mOhm, t_coil_topology_s |
# | 30 | `examples/ih_esim_benchmark/sweep_data_dense/I1_f200k_per_panel.json` | `b25549fdcaa1` | status, method, coil_solver_used, frequency_hz, current_A, L_coil_nH, R_coil_mOhm, t_coil_topology_s |
# | 31 | `examples/ih_esim_benchmark/sweep_data_dense/I1_f200k_scalar.json` | `3add071e29c5` | status, method, coil_solver_used, frequency_hz, current_A, L_coil_nH, R_coil_mOhm, t_coil_topology_s |
# | 32 | `examples/ih_esim_benchmark/sweep_data_dense/I1_f20k_per_panel.json` | `da066b5a5f6b` | status, method, coil_solver_used, frequency_hz, current_A, L_coil_nH, R_coil_mOhm, t_coil_topology_s |
# | 33 | `examples/ih_esim_benchmark/sweep_data_dense/I1_f20k_scalar.json` | `85804a96f545` | status, method, coil_solver_used, frequency_hz, current_A, L_coil_nH, R_coil_mOhm, t_coil_topology_s |
# | 34 | `examples/ih_esim_benchmark/sweep_data_dense/I1_f500k_per_panel.json` | `f6318e895a4b` | status, method, coil_solver_used, frequency_hz, current_A, L_coil_nH, R_coil_mOhm, t_coil_topology_s |
# | 35 | `examples/ih_esim_benchmark/sweep_data_dense/I1_f500k_scalar.json` | `2df43e68ba4a` | status, method, coil_solver_used, frequency_hz, current_A, L_coil_nH, R_coil_mOhm, t_coil_topology_s |
# | 36 | `examples/ih_esim_benchmark/sweep_data_dense/I1_f50k_per_panel.json` | `d535cb71ad8f` | status, method, coil_solver_used, frequency_hz, current_A, L_coil_nH, R_coil_mOhm, t_coil_topology_s |
# | 37 | `examples/ih_esim_benchmark/sweep_data_dense/I1_f50k_scalar.json` | `639a18ba2672` | status, method, coil_solver_used, frequency_hz, current_A, L_coil_nH, R_coil_mOhm, t_coil_topology_s |
# | 38 | `examples/ih_esim_benchmark/sweep_data_dense/I200_f100k_per_panel.json` | `2649cfab8403` | status, method, coil_solver_used, frequency_hz, current_A, L_coil_nH, R_coil_mOhm, t_coil_topology_s |
# | 39 | `examples/ih_esim_benchmark/sweep_data_dense/I200_f100k_scalar.json` | `417b10c89752` | status, method, coil_solver_used, frequency_hz, current_A, L_coil_nH, R_coil_mOhm, t_coil_topology_s |
# | 40 | `examples/ih_esim_benchmark/sweep_data_dense/I200_f10k_per_panel.json` | `87095c239663` | status, method, coil_solver_used, frequency_hz, current_A, L_coil_nH, R_coil_mOhm, t_coil_topology_s |
# | 41 | `examples/ih_esim_benchmark/sweep_data_dense/I200_f10k_scalar.json` | `28b49bfd28e7` | status, method, coil_solver_used, frequency_hz, current_A, L_coil_nH, R_coil_mOhm, t_coil_topology_s |
# | 42 | `examples/ih_esim_benchmark/sweep_data_dense/I200_f200k_per_panel.json` | `e22dce33de47` | status, method, coil_solver_used, frequency_hz, current_A, L_coil_nH, R_coil_mOhm, t_coil_topology_s |
# | 43 | `examples/ih_esim_benchmark/sweep_data_dense/I200_f200k_scalar.json` | `639ba2e9a7a3` | status, method, coil_solver_used, frequency_hz, current_A, L_coil_nH, R_coil_mOhm, t_coil_topology_s |
# | 44 | `examples/ih_esim_benchmark/sweep_data_dense/I200_f20k_per_panel.json` | `050c2bd22d56` | status, method, coil_solver_used, frequency_hz, current_A, L_coil_nH, R_coil_mOhm, t_coil_topology_s |
# | 45 | `examples/ih_esim_benchmark/sweep_data_dense/I200_f20k_scalar.json` | `6899134cbd04` | status, method, coil_solver_used, frequency_hz, current_A, L_coil_nH, R_coil_mOhm, t_coil_topology_s |
# | 46 | `examples/ih_esim_benchmark/sweep_data_dense/I200_f500k_per_panel.json` | `1bfae0b233c5` | status, method, coil_solver_used, frequency_hz, current_A, L_coil_nH, R_coil_mOhm, t_coil_topology_s |
# | 47 | `examples/ih_esim_benchmark/sweep_data_dense/I200_f500k_scalar.json` | `b9a7b04f2c51` | status, method, coil_solver_used, frequency_hz, current_A, L_coil_nH, R_coil_mOhm, t_coil_topology_s |
# | 48 | `examples/ih_esim_benchmark/sweep_data_dense/I200_f50k_per_panel.json` | `717919df4038` | status, method, coil_solver_used, frequency_hz, current_A, L_coil_nH, R_coil_mOhm, t_coil_topology_s |
# | 49 | `examples/ih_esim_benchmark/sweep_data_dense/I200_f50k_scalar.json` | `807bfd69fdeb` | status, method, coil_solver_used, frequency_hz, current_A, L_coil_nH, R_coil_mOhm, t_coil_topology_s |
# | 50 | `examples/ih_esim_benchmark/sweep_data_dense/I20_f100k_per_panel.json` | `187d6953fa7e` | status, method, coil_solver_used, frequency_hz, current_A, L_coil_nH, R_coil_mOhm, t_coil_topology_s |
# | 51 | `examples/ih_esim_benchmark/sweep_data_dense/I20_f100k_scalar.json` | `9146af5ccf9d` | status, method, coil_solver_used, frequency_hz, current_A, L_coil_nH, R_coil_mOhm, t_coil_topology_s |
# | 52 | `examples/ih_esim_benchmark/sweep_data_dense/I20_f10k_per_panel.json` | `917a88381bbf` | status, method, coil_solver_used, frequency_hz, current_A, L_coil_nH, R_coil_mOhm, t_coil_topology_s |
# | 53 | `examples/ih_esim_benchmark/sweep_data_dense/I20_f10k_scalar.json` | `3441aca0d86a` | status, method, coil_solver_used, frequency_hz, current_A, L_coil_nH, R_coil_mOhm, t_coil_topology_s |
# | 54 | `examples/ih_esim_benchmark/sweep_data_dense/I20_f200k_per_panel.json` | `f030c77c01e0` | status, method, coil_solver_used, frequency_hz, current_A, L_coil_nH, R_coil_mOhm, t_coil_topology_s |
# | 55 | `examples/ih_esim_benchmark/sweep_data_dense/I20_f200k_scalar.json` | `74c6ab6b4eec` | status, method, coil_solver_used, frequency_hz, current_A, L_coil_nH, R_coil_mOhm, t_coil_topology_s |
# | 56 | `examples/ih_esim_benchmark/sweep_data_dense/I20_f20k_per_panel.json` | `5a0b6ecf00f0` | status, method, coil_solver_used, frequency_hz, current_A, L_coil_nH, R_coil_mOhm, t_coil_topology_s |
# | 57 | `examples/ih_esim_benchmark/sweep_data_dense/I20_f20k_scalar.json` | `68dc25bf27b8` | status, method, coil_solver_used, frequency_hz, current_A, L_coil_nH, R_coil_mOhm, t_coil_topology_s |
# | 58 | `examples/ih_esim_benchmark/sweep_data_dense/I20_f500k_per_panel.json` | `8082b035af97` | status, method, coil_solver_used, frequency_hz, current_A, L_coil_nH, R_coil_mOhm, t_coil_topology_s |
# | 59 | `examples/ih_esim_benchmark/sweep_data_dense/I20_f500k_scalar.json` | `60d039f7ecce` | status, method, coil_solver_used, frequency_hz, current_A, L_coil_nH, R_coil_mOhm, t_coil_topology_s |
# | 60 | `examples/ih_esim_benchmark/sweep_data_dense/I20_f50k_per_panel.json` | `c249dcdd2177` | status, method, coil_solver_used, frequency_hz, current_A, L_coil_nH, R_coil_mOhm, t_coil_topology_s |
# | 61 | `examples/ih_esim_benchmark/sweep_data_dense/I20_f50k_scalar.json` | `0a519e0aca28` | status, method, coil_solver_used, frequency_hz, current_A, L_coil_nH, R_coil_mOhm, t_coil_topology_s |
# | 62 | `examples/ih_esim_benchmark/sweep_data_dense/I2_f100k_per_panel.json` | `072ad0d4d3bf` | status, method, coil_solver_used, frequency_hz, current_A, L_coil_nH, R_coil_mOhm, t_coil_topology_s |
# | 63 | `examples/ih_esim_benchmark/sweep_data_dense/I2_f100k_scalar.json` | `14266d48ccc0` | status, method, coil_solver_used, frequency_hz, current_A, L_coil_nH, R_coil_mOhm, t_coil_topology_s |
# | 64 | `examples/ih_esim_benchmark/sweep_data_dense/I2_f10k_per_panel.json` | `922ec5f4540e` | status, method, coil_solver_used, frequency_hz, current_A, L_coil_nH, R_coil_mOhm, t_coil_topology_s |
# | 65 | `examples/ih_esim_benchmark/sweep_data_dense/I2_f10k_scalar.json` | `77c52a38a7ed` | status, method, coil_solver_used, frequency_hz, current_A, L_coil_nH, R_coil_mOhm, t_coil_topology_s |
# | 66 | `examples/ih_esim_benchmark/sweep_data_dense/I2_f200k_per_panel.json` | `040bd0933266` | status, method, coil_solver_used, frequency_hz, current_A, L_coil_nH, R_coil_mOhm, t_coil_topology_s |
# | 67 | `examples/ih_esim_benchmark/sweep_data_dense/I2_f200k_scalar.json` | `bc5ade3129da` | status, method, coil_solver_used, frequency_hz, current_A, L_coil_nH, R_coil_mOhm, t_coil_topology_s |
# | 68 | `examples/ih_esim_benchmark/sweep_data_dense/I2_f20k_per_panel.json` | `9564264775f0` | status, method, coil_solver_used, frequency_hz, current_A, L_coil_nH, R_coil_mOhm, t_coil_topology_s |
# | 69 | `examples/ih_esim_benchmark/sweep_data_dense/I2_f20k_scalar.json` | `1e5034302e78` | status, method, coil_solver_used, frequency_hz, current_A, L_coil_nH, R_coil_mOhm, t_coil_topology_s |
# | 70 | `examples/ih_esim_benchmark/sweep_data_dense/I2_f500k_per_panel.json` | `5115d5cea32f` | status, method, coil_solver_used, frequency_hz, current_A, L_coil_nH, R_coil_mOhm, t_coil_topology_s |
# | 71 | `examples/ih_esim_benchmark/sweep_data_dense/I2_f500k_scalar.json` | `7c5ca1828c86` | status, method, coil_solver_used, frequency_hz, current_A, L_coil_nH, R_coil_mOhm, t_coil_topology_s |
# | 72 | `examples/ih_esim_benchmark/sweep_data_dense/I2_f50k_per_panel.json` | `a84eda5acf02` | status, method, coil_solver_used, frequency_hz, current_A, L_coil_nH, R_coil_mOhm, t_coil_topology_s |
# | 73 | `examples/ih_esim_benchmark/sweep_data_dense/I2_f50k_scalar.json` | `b7e5bff7f6a1` | status, method, coil_solver_used, frequency_hz, current_A, L_coil_nH, R_coil_mOhm, t_coil_topology_s |
# | 74 | `examples/ih_esim_benchmark/sweep_data_dense/I500_f100k_per_panel.json` | `04bf023b48fd` | status, method, coil_solver_used, frequency_hz, current_A, L_coil_nH, R_coil_mOhm, t_coil_topology_s |
# | 75 | `examples/ih_esim_benchmark/sweep_data_dense/I500_f100k_scalar.json` | `66c7325618a3` | status, method, coil_solver_used, frequency_hz, current_A, L_coil_nH, R_coil_mOhm, t_coil_topology_s |
# | 76 | `examples/ih_esim_benchmark/sweep_data_dense/I500_f10k_per_panel.json` | `ab0a3e560ff7` | status, method, coil_solver_used, frequency_hz, current_A, L_coil_nH, R_coil_mOhm, t_coil_topology_s |
# | 77 | `examples/ih_esim_benchmark/sweep_data_dense/I500_f10k_scalar.json` | `84428b1a7293` | status, method, coil_solver_used, frequency_hz, current_A, L_coil_nH, R_coil_mOhm, t_coil_topology_s |
# | 78 | `examples/ih_esim_benchmark/sweep_data_dense/I500_f10k_Zs_side_field.json` | `fd6a4debb340` | case, source_mesh, note, R_mm, theta_deg, z_mm, Z_s_mOhm |
# | 79 | `examples/ih_esim_benchmark/sweep_data_dense/I500_f200k_per_panel.json` | `b78ae9106960` | status, method, coil_solver_used, frequency_hz, current_A, L_coil_nH, R_coil_mOhm, t_coil_topology_s |
# | 80 | `examples/ih_esim_benchmark/sweep_data_dense/I500_f200k_scalar.json` | `ab7e9fe727e2` | status, method, coil_solver_used, frequency_hz, current_A, L_coil_nH, R_coil_mOhm, t_coil_topology_s |
# | 81 | `examples/ih_esim_benchmark/sweep_data_dense/I500_f20k_per_panel.json` | `ce4148882403` | status, method, coil_solver_used, frequency_hz, current_A, L_coil_nH, R_coil_mOhm, t_coil_topology_s |
# | 82 | `examples/ih_esim_benchmark/sweep_data_dense/I500_f20k_scalar.json` | `168d1d82014c` | status, method, coil_solver_used, frequency_hz, current_A, L_coil_nH, R_coil_mOhm, t_coil_topology_s |
# | 83 | `examples/ih_esim_benchmark/sweep_data_dense/I500_f500k_per_panel.json` | `e5eda8d6543d` | status, method, coil_solver_used, frequency_hz, current_A, L_coil_nH, R_coil_mOhm, t_coil_topology_s |
# | 84 | `examples/ih_esim_benchmark/sweep_data_dense/I500_f500k_scalar.json` | `3007b6b0b60f` | status, method, coil_solver_used, frequency_hz, current_A, L_coil_nH, R_coil_mOhm, t_coil_topology_s |
# | 85 | `examples/ih_esim_benchmark/sweep_data_dense/I500_f50k_per_panel.json` | `03f036596c84` | status, method, coil_solver_used, frequency_hz, current_A, L_coil_nH, R_coil_mOhm, t_coil_topology_s |
# | 86 | `examples/ih_esim_benchmark/sweep_data_dense/I500_f50k_scalar.json` | `4d834145cd52` | status, method, coil_solver_used, frequency_hz, current_A, L_coil_nH, R_coil_mOhm, t_coil_topology_s |
# | 87 | `examples/ih_esim_benchmark/sweep_data_dense/I50_f100k_per_panel.json` | `d0b385efd361` | status, method, coil_solver_used, frequency_hz, current_A, L_coil_nH, R_coil_mOhm, t_coil_topology_s |
# | 88 | `examples/ih_esim_benchmark/sweep_data_dense/I50_f100k_scalar.json` | `0efcffc45ece` | status, method, coil_solver_used, frequency_hz, current_A, L_coil_nH, R_coil_mOhm, t_coil_topology_s |
# | 89 | `examples/ih_esim_benchmark/sweep_data_dense/I50_f10k_per_panel.json` | `1137f3d9a0db` | status, method, coil_solver_used, frequency_hz, current_A, L_coil_nH, R_coil_mOhm, t_coil_topology_s |
# | 90 | `examples/ih_esim_benchmark/sweep_data_dense/I50_f10k_scalar.json` | `9f8a6fbbcf47` | status, method, coil_solver_used, frequency_hz, current_A, L_coil_nH, R_coil_mOhm, t_coil_topology_s |
# | 91 | `examples/ih_esim_benchmark/sweep_data_dense/I50_f200k_per_panel.json` | `a0921d0ac51d` | status, method, coil_solver_used, frequency_hz, current_A, L_coil_nH, R_coil_mOhm, t_coil_topology_s |
# | 92 | `examples/ih_esim_benchmark/sweep_data_dense/I50_f200k_scalar.json` | `7711ab3d98f7` | status, method, coil_solver_used, frequency_hz, current_A, L_coil_nH, R_coil_mOhm, t_coil_topology_s |
# | 93 | `examples/ih_esim_benchmark/sweep_data_dense/I50_f20k_per_panel.json` | `02187af8a4fb` | status, method, coil_solver_used, frequency_hz, current_A, L_coil_nH, R_coil_mOhm, t_coil_topology_s |
# | 94 | `examples/ih_esim_benchmark/sweep_data_dense/I50_f20k_scalar.json` | `2ca7382b0c1c` | status, method, coil_solver_used, frequency_hz, current_A, L_coil_nH, R_coil_mOhm, t_coil_topology_s |
# | 95 | `examples/ih_esim_benchmark/sweep_data_dense/I50_f500k_per_panel.json` | `922b7d6f4399` | status, method, coil_solver_used, frequency_hz, current_A, L_coil_nH, R_coil_mOhm, t_coil_topology_s |
# | 96 | `examples/ih_esim_benchmark/sweep_data_dense/I50_f500k_scalar.json` | `a14cedd91628` | status, method, coil_solver_used, frequency_hz, current_A, L_coil_nH, R_coil_mOhm, t_coil_topology_s |
# | 97 | `examples/ih_esim_benchmark/sweep_data_dense/I50_f50k_per_panel.json` | `e7ae347a4338` | status, method, coil_solver_used, frequency_hz, current_A, L_coil_nH, R_coil_mOhm, t_coil_topology_s |
# | 98 | `examples/ih_esim_benchmark/sweep_data_dense/I50_f50k_scalar.json` | `e0a96dd06241` | status, method, coil_solver_used, frequency_hz, current_A, L_coil_nH, R_coil_mOhm, t_coil_topology_s |
# | 99 | `examples/ih_esim_benchmark/sweep_data_dense/I5_f100k_per_panel.json` | `4da3b0af48ba` | status, method, coil_solver_used, frequency_hz, current_A, L_coil_nH, R_coil_mOhm, t_coil_topology_s |
# | 100 | `examples/ih_esim_benchmark/sweep_data_dense/I5_f100k_scalar.json` | `48414b9a6645` | status, method, coil_solver_used, frequency_hz, current_A, L_coil_nH, R_coil_mOhm, t_coil_topology_s |
# | 101 | `examples/ih_esim_benchmark/sweep_data_dense/I5_f10k_per_panel.json` | `c311baec4847` | status, method, coil_solver_used, frequency_hz, current_A, L_coil_nH, R_coil_mOhm, t_coil_topology_s |
# | 102 | `examples/ih_esim_benchmark/sweep_data_dense/I5_f10k_scalar.json` | `a8ba31b267e8` | status, method, coil_solver_used, frequency_hz, current_A, L_coil_nH, R_coil_mOhm, t_coil_topology_s |
# | 103 | `examples/ih_esim_benchmark/sweep_data_dense/I5_f200k_per_panel.json` | `61fd36f48980` | status, method, coil_solver_used, frequency_hz, current_A, L_coil_nH, R_coil_mOhm, t_coil_topology_s |
# | 104 | `examples/ih_esim_benchmark/sweep_data_dense/I5_f200k_scalar.json` | `7a512aa6a58e` | status, method, coil_solver_used, frequency_hz, current_A, L_coil_nH, R_coil_mOhm, t_coil_topology_s |
# | 105 | `examples/ih_esim_benchmark/sweep_data_dense/I5_f20k_per_panel.json` | `e68c0da16c91` | status, method, coil_solver_used, frequency_hz, current_A, L_coil_nH, R_coil_mOhm, t_coil_topology_s |
# | 106 | `examples/ih_esim_benchmark/sweep_data_dense/I5_f20k_scalar.json` | `30570cf1792e` | status, method, coil_solver_used, frequency_hz, current_A, L_coil_nH, R_coil_mOhm, t_coil_topology_s |
# | 107 | `examples/ih_esim_benchmark/sweep_data_dense/I5_f500k_per_panel.json` | `e2e85d6b01d8` | status, method, coil_solver_used, frequency_hz, current_A, L_coil_nH, R_coil_mOhm, t_coil_topology_s |
# | 108 | `examples/ih_esim_benchmark/sweep_data_dense/I5_f500k_scalar.json` | `11fcbf91495e` | status, method, coil_solver_used, frequency_hz, current_A, L_coil_nH, R_coil_mOhm, t_coil_topology_s |
# | 109 | `examples/ih_esim_benchmark/sweep_data_dense/I5_f50k_per_panel.json` | `0fc7d63b3d4a` | status, method, coil_solver_used, frequency_hz, current_A, L_coil_nH, R_coil_mOhm, t_coil_topology_s |
# | 110 | `examples/ih_esim_benchmark/sweep_data_dense/I5_f50k_scalar.json` | `9e5b686dbca4` | status, method, coil_solver_used, frequency_hz, current_A, L_coil_nH, R_coil_mOhm, t_coil_topology_s |
# | 111 | `examples/ih_esim_benchmark/sweep_data_dense/sweep_results.json` | `695fa4e27282` | runs |
# media artifacts indexed: 16
