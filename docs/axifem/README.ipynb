# %% [markdown]
# # AXIFEM notebooks
#
# This folder is the promoted documentation surface for AXIFEM. Example scripts and raw validation material remain reproducibility inputs; result-bearing notebooks are the reader-facing artifacts.

# %%
from pathlib import Path
import json

relative = Path("validation_test/axifem/axifem_element_evidence.json")
for root in [Path.cwd(), *Path.cwd().parents]:
    candidate = root / relative
    if candidate.exists():
        evidence = json.loads(candidate.read_text(encoding="utf-8"))
        break
else:
    raise FileNotFoundError(relative)

print(json.dumps(evidence["version_stamp"], indent=2, ensure_ascii=False))
# Out:
# {
#   "runtime_radia_version": "4.95.5",
#   "executed_at_utc": "2026-07-05T02:09:01.637577+00:00",
#   "python": "3.12.10",
#   "python_executable": "C:\\Program Files\\Python312\\python.exe",
#   "platform": "Windows-2022Server-10.0.20348-SP0",
#   "git_head": "19e54c13",
#   "git_dirty": true,
#   "mesh_route": "Netgen .vol -> ngsolve.Mesh(path)",
#   "pytest_passed": 34
# }

# %%
from IPython.display import Markdown, display
display(Markdown('| Notebook | Role |\n| --- | --- |\n| `AXIFEM_ELEMENT_EVIDENCE.ipynb` | Executed evidence for P1, Q1, P2, Q2, P2 curved, Q2 curved |\n| `AXIFEM.md` | API-facing design notes for AXIFEM |\n| `FORMULATION.md` | Mathematical formulation and implementation notes |'))
# Out:
# | Notebook | Role |
# | --- | --- |
# | `AXIFEM_ELEMENT_EVIDENCE.ipynb` | Executed evidence for P1, Q1, P2, Q2, P2 curved, Q2 curved |
# | `AXIFEM.md` | API-facing design notes for AXIFEM |
# | `FORMULATION.md` | Mathematical formulation and implementation notes |
