# %% [markdown]
# # Axifem Examples Archive
#
# This notebook is a result-saved promotion archive for `examples/axifem`.
# It keeps theory, source inventory, result payloads, and placement policy in one
# human-readable surface while the adjacent JSON remains the durable debug record.
#
# ## Theory and Scope
#
# - This notebook is the topic-specific source/result archive for examples/axifem.
# - It preserves full source, hashes, adjacent JSON payloads, and result media hashes before any pruning decision.
# - Validation-class scripts remain executable in examples until explicit validation_test gates or reusable src APIs exist.
#
# ## Placement Policy
#
# Docs-first topic archive for examples/axifem. Keep scripts until protected docs, panel, package, and validation_test references have been migrated to docs, src, panels, or validation_test.
#
# ## Synchronization
#
# The durable archive is `axifem_examples_archive_results.json`. It stores full source, SHA-256 hashes,
# existing result JSON payloads, media hashes, runtime metadata, and the promotion
# lane for every script in this batch.

# %%
from pathlib import Path
import json
from IPython.display import Markdown, display

archive_path = Path('axifem_examples_archive_results.json')
if not archive_path.exists():
    archive_path = Path('docs/axifem/axifem_examples_archive_results.json')
data = json.loads(archive_path.read_text(encoding='utf-8'))
counts = data['counts']
print(f"topic={data['topic']}")
print(f"python_scripts={counts['python_scripts']}")
print(f"topic_json_files={counts['topic_json_files']}")
print(f"media_files={counts['media_files']}")
print(f"promotion_lane={data['promotion_lane']}")
# Out:
# topic=axifem
# python_scripts=22
# topic_json_files=8
# media_files=1
# promotion_lane=topic_docs_first_archive

# %% [markdown]
# ## Script Inventory
# Generated from the synchronized JSON archive.

# %%
header = '| # | script | lines | json refs | docstring |\n|---:|---|---:|---:|---|'
body = []
for i, rec in enumerate(data['records'], 1):
    doc = (rec.get('docstring_first_line') or '').replace('|', '\\|')
    body.append(f"| {i} | `{rec['path']}` | {rec['line_count']} | {len(rec.get('attached_json', []))} | {doc} |")
display(Markdown('\n'.join([header] + body)))
# Out:
# | # | script | lines | json refs | docstring |
# |---:|---|---:|---:|---|
# | 1 | `examples/axifem/disk_convergence/axifem_core.py` | 311 | 0 | axifem_core.py — Phase 1 prototype: FEMM-style axisymmetric magnetostatic solver. |
# | 2 | `examples/axifem/disk_convergence/disk_convergence_sweep.py` | 128 | 0 | disk_convergence_sweep.py — Probe axifem convergence to v22b (208.32 us). |
# | 3 | `examples/axifem/disk_convergence/sigma_mass.py` | 150 | 0 | sigma_mass.py — Sigma mass matrix for axifem (V-form, FEMM-style basis). |
# | 4 | `examples/axifem/nmr_validation/axifem_core.py` | 311 | 0 | axifem_core.py — Phase 1 prototype: FEMM-style axisymmetric magnetostatic solver. |
# | 5 | `examples/axifem/nmr_validation/nmr_validate.py` | 234 | 0 | nmr_validate.py — Reproduce the FEMM NMR axisymmetric problem with axifem_core |
# | 6 | `examples/axifem/research/bem_cauer_high_moments.py` | 163 | 0 | BEM-Foster Cauer extraction with high moment count (50-digit mpmath). |
# | 7 | `examples/axifem/research/breakdown_study.py` | 200 | 0 | Failure-mode comparison: FE-Hiruma 3-term vs BEM-Foster classical Cauer. |
# | 8 | `examples/axifem/research/codegen_q2_henrotte.py` | 199 | 0 | Codegen: convert Mathematica-derived Q2 Henrotte element-matrix strings |
# | 9 | `examples/axifem/research/hex_bem_cauer_high_moments.py` | 163 | 0 | Cuboid 5x2x1 mm BEM HDiv order-3 -> Cauer extraction at high moments. |
# | 10 | `examples/axifem/research/precision_sensitivity_study.py` | 186 | 0 | Precision sensitivity study for BEM-Foster -> Cauer extraction pipeline. |
# | 11 | `examples/axifem/research/validate_q2_codegen.py` | 158 | 0 | validate_q2_codegen.py — Verify the JSON closed-form Q2 element matrices |
# | 12 | `examples/axifem/research/verification/test_3way_cauer_cross_validation.py` | 146 | 0 | Cauer-I cross-validation: BEM-Foster (Nagamine pipeline) vs axihenrotte FE. |
# | 13 | `examples/axifem/research/verification/test_bilinearform_smoke.py` | 49 | 0 | Phase 2-C smoke test: verify BilinearForm grad(u)*grad(v)*dx integrates |
# | 14 | `examples/axifem/research/verification/test_closed_form_vs_python.py` | 132 | 0 | Phase 2-E sanity test: |
# | 15 | `examples/axifem/research/verification/test_disk_eigenvalue.py` | 119 | 0 | Phase 2-D numerical correctness test: |
# | 16 | `examples/axifem/research/verification/test_disk_eigenvalue_closedform.py` | 112 | 0 | Phase 2-E disk validation: |
# | 17 | `examples/axifem/research/verification/test_hiruma_disk.py` | 262 | 0 | Phase 3: Hiruma 3-term recurrence on axifem Cu disk. |
# | 18 | `examples/axifem/research/verification/test_hiruma_disk_q1.py` | 294 | 0 | Phase 3 follow-up: Hiruma 3-term on Cu disk with **structured Q1 quad mesh**. |
# | 19 | `examples/axifem/research/verification/test_hiruma_disk_q2.py` | 124 | 0 | Phase A2: Hiruma 3-term on Cu disk with **Q2 quad mesh**. |
# | 20 | `examples/axifem/research/verification/test_magnetized_sphere.py` | 127 | 0 | Permanent-magnet SOURCE term for the axisymmetric A_phi formulation, |
# | 21 | `examples/axifem/research/verification/test_q2_assembly_diag.py` | 126 | 0 | Diagnose Q2 multi-element assembly: build a tiny 2-quad mesh and dump the |
# | 22 | `examples/axifem/research/verification/test_q2_single_element.py` | 141 | 0 | Q2 single-element sanity test. |

# %% [markdown]
# ## Integrity Checks

# %%
assert counts['python_scripts'] == len(data['records'])
assert all(len(rec['sha256']) == 64 for rec in data['records'])
assert all(rec.get('source') for rec in data['records'])
print('archive integrity: ok')
# Out:
# archive integrity: ok

# %% [markdown]
# ## Result Payloads and Media

# %%
rows = data.get('topic_json_files', [])
if rows:
    header = '| # | json | sha256 | keys |\n|---:|---|---|---|'
    body = []
    for i, row in enumerate(rows, 1):
        payload = row.get('payload')
        keys = ', '.join(list(payload.keys())[:8]) if isinstance(payload, dict) else type(payload).__name__
        body.append(f"| {i} | `{row['path']}` | `{row['sha256'][:12]}` | {keys.replace('|', '\\|')} |")
    display(Markdown('\n'.join([header] + body)))
else:
    print('no existing JSON payloads found')

media = data.get('media_files', [])
print(f"media artifacts indexed: {len(media)}")
# Out:
# | # | json | sha256 | keys |
# |---:|---|---|---|
# | 1 | `examples/axifem/research/bem_cauer_high_moments_results.json` | `d556d81749f8` | config, bem_R_2k, bem_L_2k_plus_1, tau_pair_us, tau_pair_us_float, alphas, breakdown_k |
# | 2 | `examples/axifem/research/breakdown_study_results.json` | `ae23229921cb` | config, fe_q1, fe_q2, bem_tau_us, comparison, breakdown_k |
# | 3 | `examples/axifem/research/hex_bem_cauer_high_moments_results.json` | `a56783f27498` | config, bem_R_2k, bem_L_2k_plus_1, tau_pair_us, tau_pair_us_float, alphas, physical_modes, breakdown_k |
# | 4 | `examples/axifem/research/precision_sensitivity_results.json` | `bbcc78e015a9` | small_6modes, medium_15modes, large_30modes, xlarge_50modes |
# | 5 | `examples/axifem/research/q2_henrotte_test_values.json` | `731fc65e57f1` | test_params_general, test_params_axis, K_phi_general, M_sigma_phi_general, K_phi_axis, M_sigma_phi_axis |
# | 6 | `examples/axifem/research/verification/test_hiruma_disk_q1_results.json` | `d8f1b8acdce5` | results, bem_tau_us, python_q1_tau_us |
# | 7 | `examples/axifem/research/verification/test_hiruma_disk_q2_results.json` | `483b106ee300` | results, bem_tau_us, python_q1_tau_us |
# | 8 | `examples/axifem/research/verification/test_hiruma_disk_results.json` | `08ebf38c5dab` | results, bem_tau_us |
# media artifacts indexed: 1
