# %% [markdown]
# # Ngsolve Integration Examples Archive
#
# This notebook is a result-saved promotion archive for `examples/ngsolve_integration`.
# It keeps theory, source inventory, result payloads, and placement policy in one
# human-readable surface while the adjacent JSON remains the durable debug record.
#
# ## Theory and Scope
#
# - This notebook is the topic-specific source/result archive for examples/ngsolve_integration.
# - It preserves full source, hashes, adjacent JSON payloads, and result media hashes before any pruning decision.
# - Validation-class scripts remain executable in examples until explicit validation_test gates or reusable src APIs exist.
#
# ## Placement Policy
#
# Docs-first topic archive for examples/ngsolve_integration. Keep scripts until protected docs, panel, package, and validation_test references have been migrated to docs, src, panels, or validation_test.
#
# ## Synchronization
#
# The durable archive is `ngsolve_integration_examples_archive_results.json`. It stores full source, SHA-256 hashes,
# existing result JSON payloads, media hashes, runtime metadata, and the promotion
# lane for every script in this batch.

# %%
from pathlib import Path
import json
from IPython.display import Markdown, display

archive_path = Path('ngsolve_integration_examples_archive_results.json')
if not archive_path.exists():
    archive_path = Path('docs/ngsolve_integration/ngsolve_integration_examples_archive_results.json')
data = json.loads(archive_path.read_text(encoding='utf-8'))
counts = data['counts']
print(f"topic={data['topic']}")
print(f"python_scripts={counts['python_scripts']}")
print(f"topic_json_files={counts['topic_json_files']}")
print(f"media_files={counts['media_files']}")
print(f"promotion_lane={data['promotion_lane']}")
# Out:
# topic=ngsolve_integration
# python_scripts=17
# topic_json_files=0
# media_files=2
# promotion_lane=topic_docs_first_archive

# %% [markdown]
# ## Script Inventory
# Generated from the synchronized JSON archive.

# %%
header = '| # | script | lines | json refs | docstring |\n|---:|---|---:|---:|---|'
body = []
for i, rec in enumerate(data['records'], 1):
    doc = (rec.get('docstring_first_line') or '').replace('|', '\\|')
    body.append(f"| {i} | `{rec['path']}` | {rec['line_count']} | {len(rec.get('attached_json', []))} | {doc} |")
display(Markdown('\n'.join([header] + body)))
# Out:
# | # | script | lines | json refs | docstring |
# |---:|---|---:|---:|---|
# | 1 | `examples/ngsolve_integration/benchmark_gridfunction_set.py` | 297 | 0 | Performance benchmark: GridFunction.Set() time evaluation |
# | 2 | `examples/ngsolve_integration/demo_basic_field.py` | 98 | 0 | Basic NGSolve integration example with Radia. |
# | 3 | `examples/ngsolve_integration/demo_batch_evaluation.py` | 203 | 0 | Demonstration: Batch evaluation for H-matrix acceleration |
# | 4 | `examples/ngsolve_integration/demo_coil_cohomology_cut.py` | 198 | 0 | Demo: Total scalar potential with a gmsh-free cohomology cut (coil + iron). |
# | 5 | `examples/ngsolve_integration/demo_coil_scalar_potential.py` | 287 | 0 | Demo: Coil source field with phi-reduced scalar potential (Radia + NGSolve). |
# | 6 | `examples/ngsolve_integration/demo_coordinate_transform.py` | 147 | 0 | Coordinate transformation example for NGSolve integration. |
# | 7 | `examples/ngsolve_integration/demo_field_types.py` | 213 | 0 | Radia Field Types Demo - NGSolve Integration |
# | 8 | `examples/ngsolve_integration/demo_hdiv_projection.py` | 282 | 0 | HDiv Function Space Projection Demo - NGSolve Integration |
# | 9 | `examples/ngsolve_integration/demo_scalar_potential.py` | 176 | 0 | Demo: Scalar potential solver combining Radia (MMM/MSC) + NGSolve FEM. |
# | 10 | `examples/ngsolve_integration/mesh_magnetization_import/ngsolve_cube_uniform_field.py` | 245 | 0 | NGSolve H-formulation for cube with uniform external field |
# | 11 | `examples/ngsolve_integration/mesh_magnetization_import/sphere_analytical_to_radia.py` | 284 | 0 | Sphere Analytical Magnetization to Radia Field Comparison |
# | 12 | `examples/ngsolve_integration/mesh_magnetization_import/verified_ngsolve_to_radia.py` | 534 | 0 | Verified NGSolve to Radia: Sphere Magnetization Transfer |
# | 13 | `examples/ngsolve_integration/RadiaField_HACApK/verify_batch_evaluation.py` | 272 | 0 | Verify RadiaField batch evaluation performance |
# | 14 | `examples/ngsolve_integration/rotating_magnets/comparison_A_Phi_method.py` | 1031 | 0 | A-Φ法による渦電流解析（改訂版） |
# | 15 | `examples/ngsolve_integration/rotating_magnets/comparison_T_Omega_method.py` | 1187 | 0 | 回転磁石と銅板の渦電流シミュレーション（過渡解析版 - T-Omega法 - CF形式アプローチ） |
# | 16 | `examples/ngsolve_integration/verify_curl_A_equals_B/verify_curl_A_equals_B.py` | 350 | 0 | Verify that curl(A) = B using RadiaField with HCurl and HDiv spaces |
# | 17 | `examples/ngsolve_integration/visualize_field.py` | 282 | 0 | Radia Magnetic Field Visualization - Comparison Study |

# %% [markdown]
# ## Integrity Checks

# %%
assert counts['python_scripts'] == len(data['records'])
assert all(len(rec['sha256']) == 64 for rec in data['records'])
assert all(rec.get('source') for rec in data['records'])
print('archive integrity: ok')
# Out:
# archive integrity: ok

# %% [markdown]
# ## Result Payloads and Media

# %%
rows = data.get('topic_json_files', [])
if rows:
    header = '| # | json | sha256 | keys |\n|---:|---|---|---|'
    body = []
    for i, row in enumerate(rows, 1):
        payload = row.get('payload')
        keys = ', '.join(list(payload.keys())[:8]) if isinstance(payload, dict) else type(payload).__name__
        body.append(f"| {i} | `{row['path']}` | `{row['sha256'][:12]}` | {keys.replace('|', '\\|')} |")
    display(Markdown('\n'.join([header] + body)))
else:
    print('no existing JSON payloads found')

media = data.get('media_files', [])
print(f"media artifacts indexed: {len(media)}")
# Out:
# no existing JSON payloads found
# media artifacts indexed: 2
