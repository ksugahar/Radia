# %% [markdown]
# # Solver Benchmarks Examples Archive
#
# This notebook is a result-saved promotion archive for `examples/solver_benchmarks`.
# It keeps theory, source inventory, result payloads, and placement policy in one
# human-readable surface while the adjacent JSON remains the durable debug record.
#
# ## Theory and Scope
#
# - This notebook is the topic-specific source/result archive for examples/solver_benchmarks.
# - It preserves full source, hashes, adjacent JSON payloads, and result media hashes before any pruning decision.
# - Validation-class scripts remain executable in examples until explicit validation_test gates or reusable src APIs exist.
#
# ## Placement Policy
#
# Docs-first topic archive for examples/solver_benchmarks. Keep scripts until protected docs, panel, package, and validation_test references have been migrated to docs, src, panels, or validation_test.
#
# ## Synchronization
#
# The durable archive is `solver_benchmarks_examples_archive_results.json`. It stores full source, SHA-256 hashes,
# existing result JSON payloads, media hashes, runtime metadata, and the promotion
# lane for every script in this batch.

# %%
from pathlib import Path
import json
from IPython.display import Markdown, display

archive_path = Path('solver_benchmarks_examples_archive_results.json')
if not archive_path.exists():
    archive_path = Path('docs/solver_benchmarks/solver_benchmarks_examples_archive_results.json')
data = json.loads(archive_path.read_text(encoding='utf-8'))
counts = data['counts']
print(f"topic={data['topic']}")
print(f"python_scripts={counts['python_scripts']}")
print(f"topic_json_files={counts['topic_json_files']}")
print(f"media_files={counts['media_files']}")
print(f"promotion_lane={data['promotion_lane']}")
# Out:
# topic=solver_benchmarks
# python_scripts=20
# topic_json_files=3
# media_files=0
# promotion_lane=topic_docs_first_archive

# %% [markdown]
# ## Script Inventory
# Generated from the synchronized JSON archive.

# %%
header = '| # | script | lines | json refs | docstring |\n|---:|---|---:|---:|---|'
body = []
for i, rec in enumerate(data['records'], 1):
    doc = (rec.get('docstring_first_line') or '').replace('|', '\\|')
    body.append(f"| {i} | `{rec['path']}` | {rec['line_count']} | {len(rec.get('attached_json', []))} | {doc} |")
display(Markdown('\n'.join([header] + body)))
# Out:
# | # | script | lines | json refs | docstring |
# |---:|---|---:|---:|---|
# | 1 | `examples/solver_benchmarks/bench_peec_dense.py` | 247 | 0 | bench_peec_dense.py -- Baseline for HACApK-PEEC (Phase 1) |
# | 2 | `examples/solver_benchmarks/bench_peec_hacapk.py` | 408 | 0 | bench_peec_hacapk.py -- HACApK-PEEC scaling benchmark (Phase 1) |
# | 3 | `examples/solver_benchmarks/bench_peec_mna_crossover.py` | 437 | 0 | bench_peec_mna_crossover.py -- Step 4 stage 5 |
# | 4 | `examples/solver_benchmarks/benchmark_dipole_vs_msc.py` | 112 | 0 | Benchmark: Dipole Approximation vs MSC Integration |
# | 5 | `examples/solver_benchmarks/benchmark_field_evaluation.py` | 273 | 0 | Field Evaluation Performance Benchmark |
# | 6 | `examples/solver_benchmarks/benchmark_large_scale_comparison.py` | 367 | 0 | Large-Scale Solver Comparison: LU vs BiCGSTAB vs HACApK |
# | 7 | `examples/solver_benchmarks/benchmark_linear_material.py` | 151 | 0 | Benchmark: Linear material solver performance |
# | 8 | `examples/solver_benchmarks/benchmark_lu_vs_hmatrix.py` | 259 | 0 | Benchmark: LU Decomposition vs BiCGSTAB vs HACApK (H-matrix) |
# | 9 | `examples/solver_benchmarks/benchmark_matrix_construction.py` | 159 | 0 | Benchmark: Solver total time scaling |
# | 10 | `examples/solver_benchmarks/benchmark_parallel_construction.py` | 240 | 0 | Parallel H-Matrix Construction Benchmark |
# | 11 | `examples/solver_benchmarks/benchmark_solver.py` | 216 | 0 | H-Matrix Solver Performance Benchmark |
# | 12 | `examples/solver_benchmarks/benchmark_solver_comparison.py` | 261 | 0 | Comprehensive Solver Comparison Benchmark |
# | 13 | `examples/solver_benchmarks/benchmark_solver_methods.py` | 283 | 0 | Solver Methods Benchmark: LU vs BiCGSTAB vs HACApK |
# | 14 | `examples/solver_benchmarks/benchmark_solver_scaling.py` | 204 | 0 | Benchmark: Solver method comparison |
# | 15 | `examples/solver_benchmarks/benchmark_solver_scaling_extended.py` | 293 | 0 | H-Matrix Solver Scaling Benchmark - Extended Range |
# | 16 | `examples/solver_benchmarks/compare_peec_dense_vs_hacapk.py` | 239 | 0 | compare_peec_dense_vs_hacapk.py -- Produce scaling comparison tables. |
# | 17 | `examples/solver_benchmarks/plot_benchmark_results.py` | 226 | 0 | Plot H-Matrix Benchmark Results |
# | 18 | `examples/solver_benchmarks/run_all_benchmarks.py` | 111 | 0 | Run All H-Matrix Benchmarks |
# | 19 | `examples/solver_benchmarks/validate_peec_circuit_hacapk.py` | 109 | 0 | validate_peec_circuit_hacapk.py -- Step 4 stage 4 validation |
# | 20 | `examples/solver_benchmarks/verify_field_accuracy.py` | 201 | 0 | Verify H-Matrix Field Accuracy |

# %% [markdown]
# ## Integrity Checks

# %%
assert counts['python_scripts'] == len(data['records'])
assert all(len(rec['sha256']) == 64 for rec in data['records'])
assert all(rec.get('source') for rec in data['records'])
print('archive integrity: ok')
# Out:
# archive integrity: ok

# %% [markdown]
# ## Result Payloads and Media

# %%
rows = data.get('topic_json_files', [])
if rows:
    header = '| # | json | sha256 | keys |\n|---:|---|---|---|'
    body = []
    for i, row in enumerate(rows, 1):
        payload = row.get('payload')
        keys = ', '.join(list(payload.keys())[:8]) if isinstance(payload, dict) else type(payload).__name__
        body.append(f"| {i} | `{row['path']}` | `{row['sha256'][:12]}` | {keys.replace('|', '\\|')} |")
    display(Markdown('\n'.join([header] + body)))
else:
    print('no existing JSON payloads found')

media = data.get('media_files', [])
print(f"media artifacts indexed: {len(media)}")
# Out:
# | # | json | sha256 | keys |
# |---:|---|---|---|
# | 1 | `examples/solver_benchmarks/results_bench_peec_dense.json` | `1b815aa4354f` | timestamp, hostname, benchmark, problem, results |
# | 2 | `examples/solver_benchmarks/results_bench_peec_hacapk.json` | `5d4ed89482f0` | timestamp, hostname, benchmark, problem, results |
# | 3 | `examples/solver_benchmarks/results_bench_peec_mna_crossover.json` | `780e2163fef9` | timestamp, hostname, benchmark, problem, results |
# media artifacts indexed: 0
