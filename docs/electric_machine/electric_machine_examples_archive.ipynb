# %% [markdown]
# # Electric Machine Examples Archive
#
# This notebook is a result-saved promotion archive for `examples/electric_machine`.
# It keeps theory, source inventory, result payloads, and placement policy in one
# human-readable surface while the adjacent JSON remains the durable debug record.
#
# ## Theory and Scope
#
# - This notebook is the topic-specific source/result archive for examples/electric_machine.
# - It preserves full source, hashes, adjacent JSON payloads, and result media hashes before any pruning decision.
# - Validation-class scripts remain executable in examples until explicit validation_test gates or reusable src APIs exist.
#
# ## Placement Policy
#
# Docs-first topic archive for examples/electric_machine. Keep scripts until protected docs, panel, package, and validation_test references have been migrated to docs, src, panels, or validation_test.
#
# ## Synchronization
#
# The durable archive is `electric_machine_examples_archive_results.json`. It stores full source, SHA-256 hashes,
# existing result JSON payloads, media hashes, runtime metadata, and the promotion
# lane for every script in this batch.

# %%
from pathlib import Path
import json
from IPython.display import Markdown, display

archive_path = Path('electric_machine_examples_archive_results.json')
if not archive_path.exists():
    archive_path = Path('docs/electric_machine/electric_machine_examples_archive_results.json')
data = json.loads(archive_path.read_text(encoding='utf-8'))
counts = data['counts']
print(f"topic={data['topic']}")
print(f"python_scripts={counts['python_scripts']}")
print(f"topic_json_files={counts['topic_json_files']}")
print(f"media_files={counts['media_files']}")
print(f"promotion_lane={data['promotion_lane']}")
# Out:
# topic=electric_machine
# python_scripts=25
# topic_json_files=25
# media_files=0
# promotion_lane=topic_docs_first_archive

# %% [markdown]
# ## Script Inventory
# Generated from the synchronized JSON archive.

# %%
header = '| # | script | lines | json refs | docstring |\n|---:|---|---:|---:|---|'
body = []
for i, rec in enumerate(data['records'], 1):
    doc = (rec.get('docstring_first_line') or '').replace('|', '\\|')
    body.append(f"| {i} | `{rec['path']}` | {rec['line_count']} | {len(rec.get('attached_json', []))} | {doc} |")
display(Markdown('\n'.join([header] + body)))
# Out:
# | # | script | lines | json refs | docstring |
# |---:|---|---:|---:|---|
# | 1 | `examples/electric_machine/cogging_skew_demo.py` | 114 | 0 | Electric-machine demo: torque ripple tau(theta), physical scaling, and SKEW |
# | 2 | `examples/electric_machine/validation_air_gap_force_sweep.py` | 154 | 1 | Validation-class air-gap Maxwell pressure / holding-force sweep. |
# | 3 | `examples/electric_machine/validation_air_gap_shear_torque.py` | 169 | 1 | Validation-class air-gap Maxwell shear torque identities. |
# | 4 | `examples/electric_machine/validation_carter_magnetizing_sweep.py` | 198 | 1 | Validation-class Carter air-gap and magnetizing-inductance sweep. |
# | 5 | `examples/electric_machine/validation_coenergy_torque_angle_sweep.py` | 119 | 1 | Validation-class coenergy torque from a rotor-angle sweep. |
# | 6 | `examples/electric_machine/validation_cogging_skew_plan.py` | 139 | 1 | Validation-class cogging order and skew planning table. |
# | 7 | `examples/electric_machine/validation_cross_saturation_flux_map.py` | 237 | 1 | Validation-class d-q cross-saturation flux-map example. |
# | 8 | `examples/electric_machine/validation_force_resultant_torque.py` | 117 | 1 | Validation-class force-row resultant and torque identities. |
# | 9 | `examples/electric_machine/validation_lamination_mu_eff_sweep.py` | 217 | 1 | Validation-class laminated-steel complex-permeability frequency sweep. |
# | 10 | `examples/electric_machine/validation_machine_torque_scaling.py` | 133 | 1 | Validation-class 2D sector torque to whole-machine torque scaling. |
# | 11 | `examples/electric_machine/validation_maxwell_stress_traction.py` | 188 | 1 | Validation-class Maxwell stress tensor / traction identities. |
# | 12 | `examples/electric_machine/validation_mtpa_saliency_sweep.py` | 218 | 1 | Validation-class MTPA saliency sweep for dq machine models. |
# | 13 | `examples/electric_machine/validation_nonlinear_bh_circuit_sweep.py` | 222 | 1 | Validation-class nonlinear B-H magnetic-circuit sweep. |
# | 14 | `examples/electric_machine/validation_nonlinear_bh_inductance_sweep.py` | 236 | 1 | Validation-class nonlinear B-H winding-inductance sweep. |
# | 15 | `examples/electric_machine/validation_planar_lorentz_block_force.py` | 131 | 1 | Validation-class planar Lorentz block-force identity. |
# | 16 | `examples/electric_machine/validation_planar_maxwell_contour_force.py` | 121 | 1 | Validation-class 2D Maxwell-stress contour force. |
# | 17 | `examples/electric_machine/validation_pm_drive_speed_map.py` | 144 | 1 | Validation-class PM machine drive and short-circuit speed map. |
# | 18 | `examples/electric_machine/validation_pm_emf_constant_table.py` | 161 | 1 | Validation-class PM back-EMF / torque-constant table. |
# | 19 | `examples/electric_machine/validation_pm_loadline_demag_sweep.py` | 239 | 1 | Validation-class PM load-line and irreversible-demag margin sweep. |
# | 20 | `examples/electric_machine/validation_sampled_air_gap_shear_torque.py` | 153 | 1 | Validation-class sampled air-gap Maxwell shear torque. |
# | 21 | `examples/electric_machine/validation_slot_winding_spectrum.py` | 135 | 1 | Validation-class slot-table winding spectrum example. |
# | 22 | `examples/electric_machine/validation_torque_angle_sweep_summary.py` | 119 | 1 | Validation-class torque-angle sweep summary. |
# | 23 | `examples/electric_machine/validation_torque_ripple_harmonic_budget.py` | 251 | 1 | Validation-class three-phase torque-ripple harmonic budget. |
# | 24 | `examples/electric_machine/validation_virtual_work_force_displacement_sweep.py` | 125 | 1 | Validation-class virtual-work force from displacement energy samples. |
# | 25 | `examples/electric_machine/validation_virtual_work_symmetric_pair_force.py` | 147 | 1 | Validation-class virtual-work force from a symmetric displacement pair. |

# %% [markdown]
# ## Integrity Checks

# %%
assert counts['python_scripts'] == len(data['records'])
assert all(len(rec['sha256']) == 64 for rec in data['records'])
assert all(rec.get('source') for rec in data['records'])
print('archive integrity: ok')
# Out:
# archive integrity: ok

# %% [markdown]
# ## Result Payloads and Media

# %%
rows = data.get('topic_json_files', [])
if rows:
    header = '| # | json | sha256 | keys |\n|---:|---|---|---|'
    body = []
    for i, row in enumerate(rows, 1):
        payload = row.get('payload')
        keys = ', '.join(list(payload.keys())[:8]) if isinstance(payload, dict) else type(payload).__name__
        body.append(f"| {i} | `{row['path']}` | `{row['sha256'][:12]}` | {keys.replace('|', '\\|')} |")
    display(Markdown('\n'.join([header] + body)))
else:
    print('no existing JSON payloads found')

media = data.get('media_files', [])
print(f"media artifacts indexed: {len(media)}")
# Out:
# | # | json | sha256 | keys |
# |---:|---|---|---|
# | 1 | `examples/electric_machine/runs/validation_slot_winding_spectrum_summary.json` | `5de1bbee7477` | kind, validation_class, harmonics, layouts |
# | 2 | `examples/electric_machine/validation_air_gap_force_sweep_summary.json` | `03d97a431326` | kind, validation_class, iron_path_m, pole_area_m2, active_faces, mmf_A_turn, gap_sweep_m, rows |
# | 3 | `examples/electric_machine/validation_air_gap_shear_torque_summary.json` | `de1f7e058f6c` | checks, field, geometry, kind, rows, validation_class |
# | 4 | `examples/electric_machine/validation_carter_magnetizing_sweep_summary.json` | `708370ce410a` | kind, validation_class, slots, poles, phases, gap_diameter_m, stack_length_m, physical_gap_m |
# | 5 | `examples/electric_machine/validation_coenergy_torque_angle_sweep_summary.json` | `f55f37d56855` | checks, coenergy_model, force_learning, kind, sample_rows, summary, validation_class |
# | 6 | `examples/electric_machine/validation_cogging_skew_plan_summary.json` | `22fd6761c55c` | kind, validation_class, one_slot_pitch_skew, half_slot_pitch_skew, checks |
# | 7 | `examples/electric_machine/validation_cross_saturation_flux_map_summary.json` | `4bbccbe6bfe9` | kind, validation_class, finite_difference_step, parameters, operating_points, checks |
# | 8 | `examples/electric_machine/validation_force_resultant_torque_summary.json` | `b3a63691168e` | cases, checks, force_learning, kind, parameters, validation_class |
# | 9 | `examples/electric_machine/validation_lamination_mu_eff_sweep_summary.json` | `6ee24ac5bcce` | kind, validation_class, frequencies_hz, cases, checks |
# | 10 | `examples/electric_machine/validation_machine_torque_scaling_summary.json` | `1167fe6f4f9b` | cases, checks, force_learning, kind, parameters, validation_class |
# | 11 | `examples/electric_machine/validation_maxwell_stress_traction_summary.json` | `d7ae541a457c` | checks, kind, rows, validation_class |
# | 12 | `examples/electric_machine/validation_mtpa_saliency_sweep_summary.json` | `514974a27645` | kind, validation_class, rows, checks |
# | 13 | `examples/electric_machine/validation_nonlinear_bh_circuit_sweep_summary.json` | `7f216271c808` | kind, validation_class, iron_path_m, mmf_sweep_A_turn, gap_sweep_m, gap_sweep_mmf_A_turn, closed_path_sweep, gap_sweep |
# | 14 | `examples/electric_machine/validation_nonlinear_bh_inductance_sweep_summary.json` | `d0448b02d2dc` | kind, validation_class, turns, area_m2, iron_path_m, current_sweep_A, gap_sweep_m, gap_sweep_current_A |
# | 15 | `examples/electric_machine/validation_planar_lorentz_block_force_summary.json` | `bf29bbf585e0` | cases, checks, force_learning, kind, parameters, validation_class |
# | 16 | `examples/electric_machine/validation_planar_maxwell_contour_force_summary.json` | `709e036ae41b` | cases, checks, force_learning, kind, validation_class |
# | 17 | `examples/electric_machine/validation_pm_drive_speed_map_summary.json` | `68b20f74f064` | kind, validation_class, speed_multiples, drive_maps, short_circuit_maps |
# | 18 | `examples/electric_machine/validation_pm_emf_constant_table_summary.json` | `b018b309794e` | kind, validation_class, omega_mech_rad_per_s, rows, checks |
# | 19 | `examples/electric_machine/validation_pm_loadline_demag_sweep_summary.json` | `f0e63e8a9472` | kind, validation_class, base, gap_sweep, magnet_length_sweep, thermal_knee_sweep, shape_demag_sweep, checks |
# | 20 | `examples/electric_machine/validation_sampled_air_gap_shear_torque_summary.json` | `5a15870c1e6b` | force_learning, geometry, kind, sinusoidal_gate, uniform_gate, validation_class |
# | 21 | `examples/electric_machine/validation_slot_winding_spectrum_summary.json` | `5de1bbee7477` | kind, validation_class, harmonics, layouts |
# | 22 | `examples/electric_machine/validation_torque_angle_sweep_summary.json` | `4b137fd5d3fc` | checks, force_learning, kind, summary, validation_class, waveform |
# | 23 | `examples/electric_machine/validation_torque_ripple_harmonic_budget_summary.json` | `f4c6b636c33f` | kind, validation_class, machine, raw_emf_harmonics, cases, checks |
# | 24 | `examples/electric_machine/validation_virtual_work_force_displacement_sweep_summary.json` | `00b11769551a` | checks, coenergy_summary, energy_model, force_learning, kind, sample_rows, stored_energy_summary, validation_class |
# | 25 | `examples/electric_machine/validation_virtual_work_symmetric_pair_force_summary.json` | `0e0846cf3315` | checks, coenergy_pair, coenergy_sweep_summary, energy_model, force_learning, kind, stored_energy_pair, stored_energy_sweep_summary |
# media artifacts indexed: 0
