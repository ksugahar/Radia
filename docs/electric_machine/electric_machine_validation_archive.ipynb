# %% [markdown]
# # Electric-Machine Validation Archive
#
# This notebook is a result-saved promotion archive for `examples/electric_machine_validation`.
# It keeps theory, source inventory, result payloads, and placement policy in one
# human-readable surface while the adjacent JSON remains the durable debug record.
#
# ## Theory and Scope
#
# - This validation lane records analytic and self-consistency gates for machine torque scaling, Maxwell/Lorentz forces, virtual work, PM load-line checks, winding harmonics, and d-q operating maps.
# - The notebook is the human-readable source/result archive; validation_test is the executable regression surface.
# - Summary JSON sidecars stay beside the moved scripts and are refreshed when the scripts are rerun.
#
# ## Placement Policy
#
# Electric-machine validation scripts live in validation_test/electric_machine. The readable cogging/skew demo lives in docs/electric_machine/cogging_skew_demo.ipynb with cogging_skew_demo.py beside it; maintain validation scripts and their *_summary.json sidecars in validation_test.
#
# ## Synchronization
#
# The durable archive is `electric_machine_validation_archive_results.json`. It stores full source, SHA-256 hashes,
# existing result JSON payloads, media hashes, runtime metadata, and the promotion
# lane for every script in this batch.

# %%
from pathlib import Path
import json
from IPython.display import Markdown, display

archive_path = Path('electric_machine_validation_archive_results.json')
if not archive_path.exists():
    archive_path = Path('docs\\electric_machine/electric_machine_validation_archive_results.json')
data = json.loads(archive_path.read_text(encoding='utf-8'))
counts = data['counts']
print(f"topic={data['topic']}")
print(f"python_scripts={counts['python_scripts']}")
print(f"topic_json_files={counts['topic_json_files']}")
print(f"media_files={counts['media_files']}")
print(f"promotion_lane={data['promotion_lane']}")
# Out:
# topic=electric_machine_validation
# python_scripts=24
# topic_json_files=24
# media_files=0
# promotion_lane=validation-test

# %% [markdown]
# ## Script Inventory
# Generated from the synchronized JSON archive.

# %%
header = '| # | script | lines | json refs | docstring |\n|---:|---|---:|---:|---|'
body = []
for i, rec in enumerate(data['records'], 1):
    doc = (rec.get('docstring_first_line') or '').replace('|', '\\|')
    body.append(f"| {i} | `{rec['path']}` | {rec['line_count']} | {len(rec.get('attached_json', []))} | {doc} |")
display(Markdown('\n'.join([header] + body)))
# Out:
# | # | script | lines | json refs | docstring |
# |---:|---|---:|---:|---|
# | 1 | `validation_test/electric_machine/validation_air_gap_force_sweep.py` | 155 | 1 | Validation-class air-gap Maxwell pressure / holding-force sweep. |
# | 2 | `validation_test/electric_machine/validation_air_gap_shear_torque.py` | 170 | 1 | Validation-class air-gap Maxwell shear torque identities. |
# | 3 | `validation_test/electric_machine/validation_carter_magnetizing_sweep.py` | 199 | 1 | Validation-class Carter air-gap and magnetizing-inductance sweep. |
# | 4 | `validation_test/electric_machine/validation_coenergy_torque_angle_sweep.py` | 120 | 1 | Validation-class coenergy torque from a rotor-angle sweep. |
# | 5 | `validation_test/electric_machine/validation_cogging_skew_plan.py` | 140 | 1 | Validation-class cogging order and skew planning table. |
# | 6 | `validation_test/electric_machine/validation_cross_saturation_flux_map.py` | 238 | 1 | Validation-class d-q cross-saturation flux-map example. |
# | 7 | `validation_test/electric_machine/validation_force_resultant_torque.py` | 118 | 1 | Validation-class force-row resultant and torque identities. |
# | 8 | `validation_test/electric_machine/validation_lamination_mu_eff_sweep.py` | 218 | 1 | Validation-class laminated-steel complex-permeability frequency sweep. |
# | 9 | `validation_test/electric_machine/validation_machine_torque_scaling.py` | 134 | 1 | Validation-class 2D sector torque to whole-machine torque scaling. |
# | 10 | `validation_test/electric_machine/validation_maxwell_stress_traction.py` | 189 | 1 | Validation-class Maxwell stress tensor / traction identities. |
# | 11 | `validation_test/electric_machine/validation_mtpa_saliency_sweep.py` | 219 | 1 | Validation-class MTPA saliency sweep for dq machine models. |
# | 12 | `validation_test/electric_machine/validation_nonlinear_bh_circuit_sweep.py` | 223 | 1 | Validation-class nonlinear B-H magnetic-circuit sweep. |
# | 13 | `validation_test/electric_machine/validation_nonlinear_bh_inductance_sweep.py` | 237 | 1 | Validation-class nonlinear B-H winding-inductance sweep. |
# | 14 | `validation_test/electric_machine/validation_planar_lorentz_block_force.py` | 132 | 1 | Validation-class planar Lorentz block-force identity. |
# | 15 | `validation_test/electric_machine/validation_planar_maxwell_contour_force.py` | 122 | 1 | Validation-class 2D Maxwell-stress contour force. |
# | 16 | `validation_test/electric_machine/validation_pm_drive_speed_map.py` | 145 | 1 | Validation-class PM machine drive and short-circuit speed map. |
# | 17 | `validation_test/electric_machine/validation_pm_emf_constant_table.py` | 162 | 1 | Validation-class PM back-EMF / torque-constant table. |
# | 18 | `validation_test/electric_machine/validation_pm_loadline_demag_sweep.py` | 240 | 1 | Validation-class PM load-line and irreversible-demag margin sweep. |
# | 19 | `validation_test/electric_machine/validation_sampled_air_gap_shear_torque.py` | 154 | 1 | Validation-class sampled air-gap Maxwell shear torque. |
# | 20 | `validation_test/electric_machine/validation_slot_winding_spectrum.py` | 136 | 1 | Validation-class slot-table winding spectrum example. |
# | 21 | `validation_test/electric_machine/validation_torque_angle_sweep_summary.py` | 120 | 1 | Validation-class torque-angle sweep summary. |
# | 22 | `validation_test/electric_machine/validation_torque_ripple_harmonic_budget.py` | 252 | 1 | Validation-class three-phase torque-ripple harmonic budget. |
# | 23 | `validation_test/electric_machine/validation_virtual_work_force_displacement_sweep.py` | 126 | 1 | Validation-class virtual-work force from displacement energy samples. |
# | 24 | `validation_test/electric_machine/validation_virtual_work_symmetric_pair_force.py` | 148 | 1 | Validation-class virtual-work force from a symmetric displacement pair. |

# %% [markdown]
# ## Integrity Checks

# %%
assert counts['python_scripts'] == len(data['records'])
assert all(len(rec['sha256']) == 64 for rec in data['records'])
assert all(rec.get('source') for rec in data['records'])
print('archive integrity: ok')
# Out:
# archive integrity: ok

# %% [markdown]
# ## Result Payloads and Media

# %%
rows = data.get('topic_json_files', [])
if rows:
    header = '| # | json | sha256 | keys |\n|---:|---|---|---|'
    body = []
    for i, row in enumerate(rows, 1):
        payload = row.get('payload')
        keys = ', '.join(list(payload.keys())[:8]) if isinstance(payload, dict) else type(payload).__name__
        body.append(f"| {i} | `{row['path']}` | `{row['sha256'][:12]}` | {keys.replace('|', '\\|')} |")
    display(Markdown('\n'.join([header] + body)))
else:
    print('no existing JSON payloads found')

media = data.get('media_files', [])
print(f"media artifacts indexed: {len(media)}")
# Out:
# | # | json | sha256 | keys |
# |---:|---|---|---|
# | 1 | `validation_test/electric_machine/validation_air_gap_force_sweep_summary.json` | `03d97a431326` | kind, validation_class, iron_path_m, pole_area_m2, active_faces, mmf_A_turn, gap_sweep_m, rows |
# | 2 | `validation_test/electric_machine/validation_air_gap_shear_torque_summary.json` | `de1f7e058f6c` | checks, field, geometry, kind, rows, validation_class |
# | 3 | `validation_test/electric_machine/validation_carter_magnetizing_sweep_summary.json` | `708370ce410a` | kind, validation_class, slots, poles, phases, gap_diameter_m, stack_length_m, physical_gap_m |
# | 4 | `validation_test/electric_machine/validation_coenergy_torque_angle_sweep_summary.json` | `f55f37d56855` | checks, coenergy_model, force_learning, kind, sample_rows, summary, validation_class |
# | 5 | `validation_test/electric_machine/validation_cogging_skew_plan_summary.json` | `f92f52ebdfe2` | kind, validation_class, one_slot_pitch_skew, half_slot_pitch_skew, checks |
# | 6 | `validation_test/electric_machine/validation_cross_saturation_flux_map_summary.json` | `4bbccbe6bfe9` | kind, validation_class, finite_difference_step, parameters, operating_points, checks |
# | 7 | `validation_test/electric_machine/validation_force_resultant_torque_summary.json` | `b3a63691168e` | cases, checks, force_learning, kind, parameters, validation_class |
# | 8 | `validation_test/electric_machine/validation_lamination_mu_eff_sweep_summary.json` | `6ee24ac5bcce` | kind, validation_class, frequencies_hz, cases, checks |
# | 9 | `validation_test/electric_machine/validation_machine_torque_scaling_summary.json` | `1167fe6f4f9b` | cases, checks, force_learning, kind, parameters, validation_class |
# | 10 | `validation_test/electric_machine/validation_maxwell_stress_traction_summary.json` | `d7ae541a457c` | checks, kind, rows, validation_class |
# | 11 | `validation_test/electric_machine/validation_mtpa_saliency_sweep_summary.json` | `514974a27645` | kind, validation_class, rows, checks |
# | 12 | `validation_test/electric_machine/validation_nonlinear_bh_circuit_sweep_summary.json` | `7f216271c808` | kind, validation_class, iron_path_m, mmf_sweep_A_turn, gap_sweep_m, gap_sweep_mmf_A_turn, closed_path_sweep, gap_sweep |
# | 13 | `validation_test/electric_machine/validation_nonlinear_bh_inductance_sweep_summary.json` | `d0448b02d2dc` | kind, validation_class, turns, area_m2, iron_path_m, current_sweep_A, gap_sweep_m, gap_sweep_current_A |
# | 14 | `validation_test/electric_machine/validation_planar_lorentz_block_force_summary.json` | `bf29bbf585e0` | cases, checks, force_learning, kind, parameters, validation_class |
# | 15 | `validation_test/electric_machine/validation_planar_maxwell_contour_force_summary.json` | `709e036ae41b` | cases, checks, force_learning, kind, validation_class |
# | 16 | `validation_test/electric_machine/validation_pm_drive_speed_map_summary.json` | `68b20f74f064` | kind, validation_class, speed_multiples, drive_maps, short_circuit_maps |
# | 17 | `validation_test/electric_machine/validation_pm_emf_constant_table_summary.json` | `b018b309794e` | kind, validation_class, omega_mech_rad_per_s, rows, checks |
# | 18 | `validation_test/electric_machine/validation_pm_loadline_demag_sweep_summary.json` | `7d180b39830e` | kind, validation_class, base, gap_sweep, magnet_length_sweep, thermal_knee_sweep, shape_demag_sweep, checks |
# | 19 | `validation_test/electric_machine/validation_sampled_air_gap_shear_torque_summary.json` | `5a15870c1e6b` | force_learning, geometry, kind, sinusoidal_gate, uniform_gate, validation_class |
# | 20 | `validation_test/electric_machine/validation_slot_winding_spectrum_summary.json` | `5de1bbee7477` | kind, validation_class, harmonics, layouts |
# | 21 | `validation_test/electric_machine/validation_torque_angle_sweep_summary.json` | `4b137fd5d3fc` | checks, force_learning, kind, summary, validation_class, waveform |
# | 22 | `validation_test/electric_machine/validation_torque_ripple_harmonic_budget_summary.json` | `f4c6b636c33f` | kind, validation_class, machine, raw_emf_harmonics, cases, checks |
# | 23 | `validation_test/electric_machine/validation_virtual_work_force_displacement_sweep_summary.json` | `00b11769551a` | checks, coenergy_summary, energy_model, force_learning, kind, sample_rows, stored_energy_summary, validation_class |
# | 24 | `validation_test/electric_machine/validation_virtual_work_symmetric_pair_force_summary.json` | `0e0846cf3315` | checks, coenergy_pair, coenergy_sweep_summary, energy_model, force_learning, kind, stored_energy_pair, stored_energy_sweep_summary |
# media artifacts indexed: 0
