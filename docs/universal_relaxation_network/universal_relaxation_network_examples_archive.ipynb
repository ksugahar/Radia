# %% [markdown]
# # Universal Relaxation Network Examples Archive
#
# This notebook is a result-saved promotion archive for `examples/universal_relaxation_network`.
# It keeps theory, source inventory, result payloads, and placement policy in one
# human-readable surface while the adjacent JSON remains the durable debug record.
#
# ## Theory and Scope
#
# - This notebook is the topic-specific source/result archive for examples/universal_relaxation_network.
# - It preserves full source, hashes, adjacent JSON payloads, and result media hashes before any pruning decision.
# - Validation-class scripts remain executable in examples until explicit validation_test gates or reusable src APIs exist.
#
# ## Placement Policy
#
# Docs-first topic archive for examples/universal_relaxation_network. Keep scripts until protected docs, panel, package, and validation_test references have been migrated to docs, src, panels, or validation_test.
#
# ## Synchronization
#
# The durable archive is `universal_relaxation_network_examples_archive_results.json`. It stores full source, SHA-256 hashes,
# existing result JSON payloads, media hashes, runtime metadata, and the promotion
# lane for every script in this batch.

# %%
from pathlib import Path
import json
from IPython.display import Markdown, display

archive_path = Path('universal_relaxation_network_examples_archive_results.json')
if not archive_path.exists():
    archive_path = Path('docs/universal_relaxation_network/universal_relaxation_network_examples_archive_results.json')
data = json.loads(archive_path.read_text(encoding='utf-8'))
counts = data['counts']
print(f"topic={data['topic']}")
print(f"python_scripts={counts['python_scripts']}")
print(f"topic_json_files={counts['topic_json_files']}")
print(f"media_files={counts['media_files']}")
print(f"promotion_lane={data['promotion_lane']}")
# Out:
# topic=universal_relaxation_network
# python_scripts=23
# topic_json_files=6
# media_files=43
# promotion_lane=topic_docs_first_archive

# %% [markdown]
# ## Script Inventory
# Generated from the synchronized JSON archive.

# %%
header = '| # | script | lines | json refs | docstring |\n|---:|---|---:|---:|---|'
body = []
for i, rec in enumerate(data['records'], 1):
    doc = (rec.get('docstring_first_line') or '').replace('|', '\\|')
    body.append(f"| {i} | `{rec['path']}` | {rec['line_count']} | {len(rec.get('attached_json', []))} | {doc} |")
display(Markdown('\n'.join([header] + body)))
# Out:
# | # | script | lines | json refs | docstring |
# |---:|---|---:|---:|---|
# | 1 | `examples/universal_relaxation_network/ablation_study.py` | 455 | 0 | Ablation Study: Feature Contribution Analysis |
# | 2 | `examples/universal_relaxation_network/benchmark_urn_vs_skrf_vf.py` | 504 | 0 | URN vs scikit-rf Vector Fitting Benchmark |
# | 3 | `examples/universal_relaxation_network/data/real_world/nasa_battery/download_nasa_data.py` | 367 | 0 | Download and extract NASA Battery EIS data. |
# | 4 | `examples/universal_relaxation_network/data/real_world/nasa_battery/extract_nasa_eis.py` | 317 | 0 | Extract EIS data from NASA Battery Dataset. |
# | 5 | `examples/universal_relaxation_network/data/real_world/nasa_battery/extract_real_eis.py` | 211 | 0 | Extract REAL EIS data from NASA Battery Dataset. |
# | 6 | `examples/universal_relaxation_network/data/real_world/tdk_ferrite/convert_permeability_to_impedance.py` | 150 | 0 | Convert TDK ferrite complex permeability data to impedance Z(f). |
# | 7 | `examples/universal_relaxation_network/demo_spice_timedomain.py` | 433 | 0 | SPICE Time-Domain Simulation Demonstration |
# | 8 | `examples/universal_relaxation_network/generate_paper_figures.py` | 373 | 0 | Generate publication-quality PNG figures for URN paper. |
# | 9 | `examples/universal_relaxation_network/paper/compile.py` | 194 | 0 | Adaptive LaTeX compilation script for URN paper. |
# | 10 | `examples/universal_relaxation_network/relaxation_basis_library.py` | 1237 | 0 | Relaxation Basis Function Library (Circuit-Compatible Version) |
# | 11 | `examples/universal_relaxation_network/run_ltspice_verification.py` | 565 | 0 | LTspice Simulation Verification using PyLTSpice |
# | 12 | `examples/universal_relaxation_network/universal_relaxation_network.py` | 3864 | 0 | KAN-inspired Universal Relaxation Network (URN) |
# | 13 | `examples/universal_relaxation_network/urn_benchmark_improved.py` | 333 | 0 | URN Improved Benchmark - Focused Tests |
# | 14 | `examples/universal_relaxation_network/urn_benchmark_suite.py` | 902 | 0 | URN Benchmark Suite for Paper |
# | 15 | `examples/universal_relaxation_network/urn_vs_vf_comparison.py` | 537 | 1 | URN vs Vector Fitting Comparison Benchmark |
# | 16 | `examples/universal_relaxation_network/urn_vs_vf_quick.py` | 337 | 0 | URN vs Vector Fitting Quick Comparison |
# | 17 | `examples/universal_relaxation_network/validate_all_datasets.py` | 275 | 0 | Comprehensive URN vs Vector Fitting Validation on All Real-World Datasets |
# | 18 | `examples/universal_relaxation_network/validate_real_data.py` | 567 | 0 | URN Validation with Real-World Measured Data |
# | 19 | `examples/universal_relaxation_network/validate_real_world.py` | 493 | 0 | Real-World Validation of Universal Relaxation Network (URN) |
# | 20 | `examples/universal_relaxation_network/validate_tdk_ferrite.py` | 366 | 0 | Validate URN with TDK MnZn Ferrite Real Measurement Data |
# | 21 | `examples/universal_relaxation_network/validate_urn_vs_vf.py` | 432 | 0 | URN vs Vector Fitting Validation Script |
# | 22 | `examples/universal_relaxation_network/verify_timedomain_stability.py` | 695 | 0 | Time-Domain Stability Verification: URN vs Vector Fitting |
# | 23 | `examples/universal_relaxation_network/vf_benchmark_same_data.py` | 561 | 0 | Vector Fitting Benchmark on Same Test Cases as URN |

# %% [markdown]
# ## Integrity Checks

# %%
assert counts['python_scripts'] == len(data['records'])
assert all(len(rec['sha256']) == 64 for rec in data['records'])
assert all(rec.get('source') for rec in data['records'])
print('archive integrity: ok')
# Out:
# archive integrity: ok

# %% [markdown]
# ## Result Payloads and Media

# %%
rows = data.get('topic_json_files', [])
if rows:
    header = '| # | json | sha256 | keys |\n|---:|---|---|---|'
    body = []
    for i, row in enumerate(rows, 1):
        payload = row.get('payload')
        keys = ', '.join(list(payload.keys())[:8]) if isinstance(payload, dict) else type(payload).__name__
        body.append(f"| {i} | `{row['path']}` | `{row['sha256'][:12]}` | {keys.replace('|', '\\|')} |")
    display(Markdown('\n'.join([header] + body)))
else:
    print('no existing JSON payloads found')

media = data.get('media_files', [])
print(f"media artifacts indexed: {len(media)}")
# Out:
# | # | json | sha256 | keys |
# |---:|---|---|---|
# | 1 | `examples/universal_relaxation_network/real_world_validation_results.json` | `afba042f704c` | validation_date, method, datasets |
# | 2 | `examples/universal_relaxation_network/urn_benchmark_focused.json` | `c9d3c5de3d58` | timestamp, success_rate, results |
# | 3 | `examples/universal_relaxation_network/urn_benchmark_results.json` | `67bdcff90c86` | timestamp, n_tests, results |
# | 4 | `examples/universal_relaxation_network/urn_vs_vf_comparison.json` | `626858c92059` | timestamp, urn_results, vf_conservative, vf_aggressive, summary |
# | 5 | `examples/universal_relaxation_network/validation_output/comprehensive_validation_results.json` | `b996e4d3d269` | timestamp, results, summary |
# | 6 | `examples/universal_relaxation_network/validation_output/validation_results.json` | `bb06070d21bd` | timestamp, datasets |
# media artifacts indexed: 43
