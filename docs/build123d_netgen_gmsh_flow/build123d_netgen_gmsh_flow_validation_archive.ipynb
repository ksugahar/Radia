# %% [markdown]
# # Build123d, Netgen, GMSH Flow Validation Archive
#
# This notebook is a result-saved promotion archive for `validation_test/build123d_netgen_gmsh_flow`.
# It keeps theory, source inventory, result payloads, and placement policy in one
# human-readable surface while the adjacent JSON remains the durable debug record.
#
# ## Theory and Scope
#
# - This archive documents the executable validation corpus for build123d geometry contracts: CAD measurements, STEP/Cubit round trips, named region preservation through Netgen/GMSH, and force/moment reference rows.
#
# ## Placement Policy
#
# Validation-class build123d/Netgen/GMSH checks live in validation_test/build123d_netgen_gmsh_flow; docs stores synchronized source, summary JSON payloads, and result-saved notebook output for future debugging.
#
# ## Synchronization
#
# The durable archive is `build123d_netgen_gmsh_flow_validation_archive_results.json`. It stores full source, SHA-256 hashes,
# existing result JSON payloads, media hashes, runtime metadata, and the promotion
# lane for every script in this batch.

# %%
from pathlib import Path
import json
from IPython.display import Markdown, display

archive_path = Path('build123d_netgen_gmsh_flow_validation_archive_results.json')
if not archive_path.exists():
    archive_path = Path('docs\\build123d_netgen_gmsh_flow/build123d_netgen_gmsh_flow_validation_archive_results.json')
data = json.loads(archive_path.read_text(encoding='utf-8'))
counts = data['counts']
print(f"topic={data['topic']}")
print(f"python_scripts={counts['python_scripts']}")
print(f"topic_json_files={counts['topic_json_files']}")
print(f"media_files={counts['media_files']}")
print(f"promotion_lane={data['promotion_lane']}")
# Out:
# topic=build123d_netgen_gmsh_flow_validation
# python_scripts=15
# topic_json_files=15
# media_files=0
# promotion_lane=validation-test-plus-docs-showcase

# %% [markdown]
# ## Script Inventory
# Generated from the synchronized JSON archive.

# %%
header = '| # | script | lines | json refs | docstring |\n|---:|---|---:|---:|---|'
body = []
for i, rec in enumerate(data['records'], 1):
    doc = (rec.get('docstring_first_line') or '').replace('|', '\\|')
    body.append(f"| {i} | `{rec['path']}` | {rec['line_count']} | {len(rec.get('attached_json', []))} | {doc} |")
display(Markdown('\n'.join([header] + body)))
# Out:
# | # | script | lines | json refs | docstring |
# |---:|---|---:|---:|---|
# | 1 | `validation_test/build123d_netgen_gmsh_flow/validation_build123d_bbox_clearance_audit.py` | 115 | 1 | Validation-class build123d bbox clearance audit. |
# | 2 | `validation_test/build123d_netgen_gmsh_flow/validation_build123d_cubit_boundary_normals.py` | 137 | 1 | Validation-class build123d boundary normals against a Netgen .vol mesh. |
# | 3 | `validation_test/build123d_netgen_gmsh_flow/validation_build123d_cubit_measurement.py` | 321 | 1 | Validation-class build123d -> Cubit measurement cross-check. |
# | 4 | `validation_test/build123d_netgen_gmsh_flow/validation_build123d_cubit_pressure_force.py` | 126 | 1 | Validation-class build123d analytic box pressure force. |
# | 5 | `validation_test/build123d_netgen_gmsh_flow/validation_build123d_cubit_pressure_moment.py` | 171 | 1 | Validation-class build123d analytic box pressure force/moment. |
# | 6 | `validation_test/build123d_netgen_gmsh_flow/validation_build123d_cubit_pressure_resultant.py` | 206 | 1 | Validation-class build123d analytic box pressure resultant. |
# | 7 | `validation_test/build123d_netgen_gmsh_flow/validation_build123d_cubit_traction_moment.py` | 170 | 1 | Validation-class build123d analytic box vector-traction force/moment. |
# | 8 | `validation_test/build123d_netgen_gmsh_flow/validation_build123d_measurement_health.py` | 238 | 1 | Validation-class build123d measurement health cross-check. |
# | 9 | `validation_test/build123d_netgen_gmsh_flow/validation_build123d_parameter_sweep_summary.py` | 142 | 1 | Validation-class build123d parameter sweep measurement summary. |
# | 10 | `validation_test/build123d_netgen_gmsh_flow/validation_coaxial_region_stack.py` | 216 | 1 | Validation-class coaxial multi-region stack for build123d -> Netgen -> Gmsh. |
# | 11 | `validation_test/build123d_netgen_gmsh_flow/validation_enclosure_cubit_measurement.py` | 260 | 1 | Validation-class enclosure/void region measurement through Cubit. |
# | 12 | `validation_test/build123d_netgen_gmsh_flow/validation_halbach_region_sweep.py` | 241 | 1 | Validation-class segmented Halbach region sweep. |
# | 13 | `validation_test/build123d_netgen_gmsh_flow/validation_helix_mesh_sweep.py` | 213 | 1 | Validation-class helical conductor sweep for the build123d -> Netgen -> Gmsh flow. |
# | 14 | `validation_test/build123d_netgen_gmsh_flow/validation_laminated_stack_region_sweep.py` | 276 | 1 | Validation-class laminated stack for build123d -> Netgen -> Gmsh. |
# | 15 | `validation_test/build123d_netgen_gmsh_flow/validation_racetrack_plate_air_region.py` | 272 | 1 | Validation-class racetrack coil / plate / air multi-region model. |

# %% [markdown]
# ## Integrity Checks

# %%
assert counts['python_scripts'] == len(data['records'])
assert all(len(rec['sha256']) == 64 for rec in data['records'])
assert all(rec.get('source') for rec in data['records'])
print('archive integrity: ok')
# Out:
# archive integrity: ok

# %% [markdown]
# ## Result Payloads and Media

# %%
rows = data.get('topic_json_files', [])
if rows:
    header = '| # | json | sha256 | keys |\n|---:|---|---|---|'
    body = []
    for i, row in enumerate(rows, 1):
        payload = row.get('payload')
        keys = ', '.join(list(payload.keys())[:8]) if isinstance(payload, dict) else type(payload).__name__
        body.append(f"| {i} | `{row['path']}` | `{row['sha256'][:12]}` | {keys.replace('|', '\\|')} |")
    display(Markdown('\n'.join([header] + body)))
else:
    print('no existing JSON payloads found')

media = data.get('media_files', [])
print(f"media artifacts indexed: {len(media)}")
# Out:
# | # | json | sha256 | keys |
# |---:|---|---|---|
# | 1 | `validation_test/build123d_netgen_gmsh_flow/validation_build123d_bbox_clearance_audit_summary.json` | `c08915ac14c0` | audit, checks, kind, learning_theme, measurement_rows, validation_class |
# | 2 | `validation_test/build123d_netgen_gmsh_flow/validation_build123d_cubit_boundary_normals_summary.json` | `f90c9e262447` | case, size, build123d_measurement, reference_boundary_rows, reference_total_surface_area, reference_closed_surface_vector_area, vol, elapsed_seconds |
# | 3 | `validation_test/build123d_netgen_gmsh_flow/validation_build123d_cubit_measurement_summary.json` | `29df19e6f543` | checks, elapsed_seconds, kind, rows, validation_class |
# | 4 | `validation_test/build123d_netgen_gmsh_flow/validation_build123d_cubit_pressure_force_summary.json` | `368384131f92` | kind, validation_class, size, pressure_by_face_Pa, reference_rows, checks, vol |
# | 5 | `validation_test/build123d_netgen_gmsh_flow/validation_build123d_cubit_pressure_moment_summary.json` | `540ce77c4e96` | kind, validation_class, size, pivot_m, pressure_by_face_Pa, reference_rows, checks, vol |
# | 6 | `validation_test/build123d_netgen_gmsh_flow/validation_build123d_cubit_pressure_resultant_summary.json` | `23145e2c42b9` | kind, validation_class, size, center, pressure_by_face_Pa, uniform_pressure_Pa, build123d_measurement, checks |
# | 7 | `validation_test/build123d_netgen_gmsh_flow/validation_build123d_cubit_traction_moment_summary.json` | `9c3b293d3f56` | kind, validation_class, size, pivot_m, traction_by_face_N_per_m2, reference_rows, checks, vol |
# | 8 | `validation_test/build123d_netgen_gmsh_flow/validation_build123d_measurement_health_summary.json` | `1ebc8bbf95fe` | analytic_comparison_rows, build123d_rows, checks, cubit_rows, elapsed_seconds, health, inventory, kind |
# | 9 | `validation_test/build123d_netgen_gmsh_flow/validation_build123d_parameter_sweep_summary.json` | `5607fb59437b` | checks, clean_sweep, constrained_sweep, errors, kind, learning_theme, rows, validation_class |
# | 10 | `validation_test/build123d_netgen_gmsh_flow/validation_coaxial_region_stack_summary.json` | `a3b8a82451cb` | kind, validation_class, quick, elapsed_seconds, region_names, cases, n_ok, n_total |
# | 11 | `validation_test/build123d_netgen_gmsh_flow/validation_enclosure_cubit_measurement_summary.json` | `9b941968b250` | checks, clearance, elapsed_seconds, kind, rows, validation_class |
# | 12 | `validation_test/build123d_netgen_gmsh_flow/validation_halbach_region_sweep_summary.json` | `84c033a1f4bd` | kind, validation_class, quick, elapsed_seconds, cases, n_ok, n_total |
# | 13 | `validation_test/build123d_netgen_gmsh_flow/validation_helix_mesh_sweep_summary.json` | `af053979e51c` | kind, validation_class, quick, elapsed_seconds, cases, n_ok, n_total |
# | 14 | `validation_test/build123d_netgen_gmsh_flow/validation_laminated_stack_region_sweep_summary.json` | `26d0b148927f` | kind, validation_class, quick, elapsed_seconds, cases, n_ok, n_total |
# | 15 | `validation_test/build123d_netgen_gmsh_flow/validation_racetrack_plate_air_region_summary.json` | `2792bf9d8869` | kind, validation_class, quick, elapsed_seconds, region_names, cases, n_ok, n_total |
# media artifacts indexed: 0
