# %% [markdown]
# # Build123d, Netgen, GMSH Flow Examples Archive
#
# This notebook is a result-saved promotion archive for `examples/build123d_netgen_gmsh_flow`.
# It keeps theory, source inventory, result payloads, and placement policy in one
# human-readable surface while the adjacent JSON remains the durable debug record.
#
# ## Theory and Scope
#
# - This archive documents the lightweight build123d -> Netgen -> GMSH examples that remain after the validation corpus moved to validation_test.
#
# ## Placement Policy
#
# Reusable build123d/Netgen/GMSH pipeline code belongs in radia_mcp.build123d.pipeline; examples keep only the lightweight demos and sweep; validation-class executables live in validation_test/build123d_netgen_gmsh_flow.
#
# ## Synchronization
#
# The durable archive is `build123d_netgen_gmsh_flow_examples_archive_results.json`. It stores full source, SHA-256 hashes,
# existing result JSON payloads, media hashes, runtime metadata, and the promotion
# lane for every script in this batch.

# %%
from pathlib import Path
import json
from IPython.display import Markdown, display

archive_path = Path('build123d_netgen_gmsh_flow_examples_archive_results.json')
if not archive_path.exists():
    archive_path = Path('docs\\build123d_netgen_gmsh_flow/build123d_netgen_gmsh_flow_examples_archive_results.json')
data = json.loads(archive_path.read_text(encoding='utf-8'))
counts = data['counts']
print(f"topic={data['topic']}")
print(f"python_scripts={counts['python_scripts']}")
print(f"topic_json_files={counts['topic_json_files']}")
print(f"media_files={counts['media_files']}")
print(f"promotion_lane={data['promotion_lane']}")
# Out:
# topic=build123d_netgen_gmsh_flow
# python_scripts=4
# topic_json_files=22
# media_files=0
# promotion_lane=docs-showcase-with-src-api

# %% [markdown]
# ## Script Inventory
# Generated from the synchronized JSON archive.

# %%
header = '| # | script | lines | json refs | docstring |\n|---:|---|---:|---:|---|'
body = []
for i, rec in enumerate(data['records'], 1):
    doc = (rec.get('docstring_first_line') or '').replace('|', '\\|')
    body.append(f"| {i} | `{rec['path']}` | {rec['line_count']} | {len(rec.get('attached_json', []))} | {doc} |")
display(Markdown('\n'.join([header] + body)))
# Out:
# | # | script | lines | json refs | docstring |
# |---:|---|---:|---:|---|
# | 1 | `examples/build123d_netgen_gmsh_flow/_pipeline.py` | 25 | 0 | Compatibility shim for the promoted build123d -> Netgen -> Gmsh API. |
# | 2 | `examples/build123d_netgen_gmsh_flow/demo_box.py` | 46 | 0 | demo_box.py — minimal end-to-end demo for the |
# | 3 | `examples/build123d_netgen_gmsh_flow/demo_ih_multi.py` | 79 | 0 | demo_ih_multi.py — multi-region demo: workpiece + coil + air. |
# | 4 | `examples/build123d_netgen_gmsh_flow/sweep.py` | 248 | 0 | sweep.py — parametric sweep driving the build123d -> Netgen -> Gmsh |

# %% [markdown]
# ## Integrity Checks

# %%
assert counts['python_scripts'] == len(data['records'])
assert all(len(rec['sha256']) == 64 for rec in data['records'])
assert all(rec.get('source') for rec in data['records'])
print('archive integrity: ok')
# Out:
# archive integrity: ok

# %% [markdown]
# ## Result Payloads and Media

# %%
rows = data.get('topic_json_files', [])
if rows:
    header = '| # | json | sha256 | keys |\n|---:|---|---|---|'
    body = []
    for i, row in enumerate(rows, 1):
        payload = row.get('payload')
        keys = ', '.join(list(payload.keys())[:8]) if isinstance(payload, dict) else type(payload).__name__
        body.append(f"| {i} | `{row['path']}` | `{row['sha256'][:12]}` | {keys.replace('|', '\\|')} |")
    display(Markdown('\n'.join([header] + body)))
else:
    print('no existing JSON payloads found')

media = data.get('media_files', [])
print(f"media artifacts indexed: {len(media)}")
# Out:
# | # | json | sha256 | keys |
# |---:|---|---|---|
# | 1 | `examples/build123d_netgen_gmsh_flow/runs/dipole_bore20.json` | `8a6f76b39187` | label, status, stages |
# | 2 | `examples/build123d_netgen_gmsh_flow/runs/dipole_bore30.json` | `316e90cf2b0f` | label, status, stages |
# | 3 | `examples/build123d_netgen_gmsh_flow/runs/dipole_bore40.json` | `c862ab8fd8e2` | label, status, stages |
# | 4 | `examples/build123d_netgen_gmsh_flow/runs/ecore_W50_H35_t10.json` | `ebc554eed515` | label, status, stages |
# | 5 | `examples/build123d_netgen_gmsh_flow/runs/ecore_W50_H35_t6.json` | `9833f4c6201a` | label, status, stages |
# | 6 | `examples/build123d_netgen_gmsh_flow/runs/ecore_W70_H50_t10.json` | `9a0983ecf7f1` | label, status, stages |
# | 7 | `examples/build123d_netgen_gmsh_flow/runs/ecore_W70_H50_t6.json` | `059760a6c1ba` | label, status, stages |
# | 8 | `examples/build123d_netgen_gmsh_flow/runs/ih_multi.json` | `2d6c237d10c8` | label, status, mode, region_names, stages |
# | 9 | `examples/build123d_netgen_gmsh_flow/runs/ih_multi_rwp12_rin17.json` | `7ebcf383a82f` | label, status, mode, region_names, stages |
# | 10 | `examples/build123d_netgen_gmsh_flow/runs/ih_multi_rwp12_rin22.json` | `a73faef5ba7e` | label, status, mode, region_names, stages |
# | 11 | `examples/build123d_netgen_gmsh_flow/runs/ih_multi_rwp15_rin20.json` | `12086858dc1d` | label, status, mode, region_names, stages |
# | 12 | `examples/build123d_netgen_gmsh_flow/runs/ih_multi_rwp15_rin25.json` | `021a3e1ccd5b` | label, status, mode, region_names, stages |
# | 13 | `examples/build123d_netgen_gmsh_flow/runs/ih_multi_rwp20_rin25.json` | `762648a1ee5f` | label, status, mode, region_names, stages |
# | 14 | `examples/build123d_netgen_gmsh_flow/runs/ih_multi_rwp20_rin30.json` | `23a886686175` | label, status, mode, region_names, stages |
# | 15 | `examples/build123d_netgen_gmsh_flow/runs/ih_rwp20_rin25.json` | `9691549a7b11` | label, status, stages |
# | 16 | `examples/build123d_netgen_gmsh_flow/runs/ih_rwp20_rin30.json` | `a52726f206a6` | label, status, stages |
# | 17 | `examples/build123d_netgen_gmsh_flow/runs/ih_rwp25_rin30.json` | `bfe072376e55` | label, status, stages |
# | 18 | `examples/build123d_netgen_gmsh_flow/runs/ih_rwp25_rin35.json` | `78d2caf1f5ed` | label, status, stages |
# | 19 | `examples/build123d_netgen_gmsh_flow/runs/ih_rwp30_rin35.json` | `3ae3be817dae` | label, status, stages |
# | 20 | `examples/build123d_netgen_gmsh_flow/runs/ih_rwp30_rin40.json` | `885a2bce46ad` | label, status, stages |
# | 21 | `examples/build123d_netgen_gmsh_flow/runs/smoke_test.json` | `1193fc2acc61` | label, status, stages |
# | 22 | `examples/build123d_netgen_gmsh_flow/runs/sweep_summary.json` | `60dbbac1b3fe` | list |
# media artifacts indexed: 0
