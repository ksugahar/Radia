# %% [markdown]
# # Cube Uniform Field Examples Archive
#
# This notebook is a result-saved promotion archive for `examples/cube_uniform_field`.
# It keeps theory, source inventory, result payloads, and placement policy in one
# human-readable surface while the adjacent JSON remains the durable debug record.
#
# ## Theory and Scope
#
# - This notebook is the topic-specific source/result archive for examples/cube_uniform_field.
# - It preserves full source, hashes, adjacent JSON payloads, and result media hashes before any pruning decision.
# - Validation-class scripts remain executable in examples until explicit validation_test gates or reusable src APIs exist.
#
# ## Placement Policy
#
# Docs-first topic archive for examples/cube_uniform_field. Keep scripts until protected docs, panel, package, and validation_test references have been migrated to docs, src, panels, or validation_test.
#
# ## Synchronization
#
# The durable archive is `cube_uniform_field_examples_archive_results.json`. It stores full source, SHA-256 hashes,
# existing result JSON payloads, media hashes, runtime metadata, and the promotion
# lane for every script in this batch.

# %%
from pathlib import Path
import json
from IPython.display import Markdown, display

archive_path = Path('cube_uniform_field_examples_archive_results.json')
if not archive_path.exists():
    archive_path = Path('docs/cube_uniform_field/cube_uniform_field_examples_archive_results.json')
data = json.loads(archive_path.read_text(encoding='utf-8'))
counts = data['counts']
print(f"topic={data['topic']}")
print(f"python_scripts={counts['python_scripts']}")
print(f"topic_json_files={counts['topic_json_files']}")
print(f"media_files={counts['media_files']}")
print(f"promotion_lane={data['promotion_lane']}")
# Out:
# topic=cube_uniform_field
# python_scripts=10
# topic_json_files=74
# media_files=4
# promotion_lane=topic_docs_first_archive

# %% [markdown]
# ## Script Inventory
# Generated from the synchronized JSON archive.

# %%
header = '| # | script | lines | json refs | docstring |\n|---:|---|---:|---:|---|'
body = []
for i, rec in enumerate(data['records'], 1):
    doc = (rec.get('docstring_first_line') or '').replace('|', '\\|')
    body.append(f"| {i} | `{rec['path']}` | {rec['line_count']} | {len(rec.get('attached_json', []))} | {doc} |")
display(Markdown('\n'.join([header] + body)))
# Out:
# | # | script | lines | json refs | docstring |
# |---:|---|---:|---:|---|
# | 1 | `examples/cube_uniform_field/benchmark_common.py` | 430 | 0 | Common benchmark functions for Radia solver testing. |
# | 2 | `examples/cube_uniform_field/benchmark_cube_block_jacobi.py` | 192 | 0 | Benchmark: Cube model with Block Jacobi + Newton. |
# | 3 | `examples/cube_uniform_field/compare_hmatrix_stats.py` | 132 | 0 | Compare H-matrix statistics between ELF and Radia. |
# | 4 | `examples/cube_uniform_field/experiment_objm_minimal.py` | 75 | 0 | Test ObjM with correct benchmark pattern. |
# | 5 | `examples/cube_uniform_field/hexahedron/benchmark_hex.py` | 229 | 0 | Hexahedral Benchmark for Radia |
# | 6 | `examples/cube_uniform_field/hexahedron/plot_scaling.py` | 264 | 0 | Aggregate hexahedron benchmark JSON results and plot solver scaling laws. |
# | 7 | `examples/cube_uniform_field/profile_hacapk.py` | 171 | 0 | Profile HACApK H-matrix build to identify performance bottlenecks. |
# | 8 | `examples/cube_uniform_field/run_benchmarks.py` | 256 | 0 | Run benchmarks based on benchmark_config.json |
# | 9 | `examples/cube_uniform_field/tetrahedron/benchmark_tetra.py` | 243 | 0 | Tetrahedral Benchmark using Netgen mesh for Radia |
# | 10 | `examples/cube_uniform_field/tetrahedron/plot_scaling.py` | 245 | 0 | Aggregate tetrahedron benchmark JSON results and plot solver scaling laws. |

# %% [markdown]
# ## Integrity Checks

# %%
assert counts['python_scripts'] == len(data['records'])
assert all(len(rec['sha256']) == 64 for rec in data['records'])
assert all(rec.get('source') for rec in data['records'])
print('archive integrity: ok')
# Out:
# archive integrity: ok

# %% [markdown]
# ## Result Payloads and Media

# %%
rows = data.get('topic_json_files', [])
if rows:
    header = '| # | json | sha256 | keys |\n|---:|---|---|---|'
    body = []
    for i, row in enumerate(rows, 1):
        payload = row.get('payload')
        keys = ', '.join(list(payload.keys())[:8]) if isinstance(payload, dict) else type(payload).__name__
        body.append(f"| {i} | `{row['path']}` | `{row['sha256'][:12]}` | {keys.replace('|', '\\|')} |")
    display(Markdown('\n'.join([header] + body)))
else:
    print('no existing JSON payloads found')

media = data.get('media_files', [])
print(f"media artifacts indexed: {len(media)}")
# Out:
# | # | json | sha256 | keys |
# |---:|---|---|---|
# | 1 | `examples/cube_uniform_field/hexahedron/nonlinear/bicgstab/hex_N10_results.json` | `6795bb5354d6` | element_type, mesh_description, n_elements, ndof, H_ext, material_type, mu_r, chi |
# | 2 | `examples/cube_uniform_field/hexahedron/nonlinear/bicgstab/hex_N11_results.json` | `59da53f0cc5d` | element_type, mesh_description, n_elements, ndof, H_ext, material_type, mu_r, chi |
# | 3 | `examples/cube_uniform_field/hexahedron/nonlinear/bicgstab/hex_N12_results.json` | `fa953b387f43` | element_type, mesh_description, n_elements, ndof, H_ext, material_type, mu_r, chi |
# | 4 | `examples/cube_uniform_field/hexahedron/nonlinear/bicgstab/hex_N13_results.json` | `d37683bf91e5` | element_type, mesh_description, n_elements, ndof, H_ext, material_type, mu_r, chi |
# | 5 | `examples/cube_uniform_field/hexahedron/nonlinear/bicgstab/hex_N14_results.json` | `02e45e887ce8` | element_type, mesh_description, n_elements, ndof, H_ext, material_type, mu_r, chi |
# | 6 | `examples/cube_uniform_field/hexahedron/nonlinear/bicgstab/hex_N15_results.json` | `0b068b1348f5` | element_type, mesh_description, n_elements, ndof, H_ext, material_type, mu_r, chi |
# | 7 | `examples/cube_uniform_field/hexahedron/nonlinear/bicgstab/hex_N16_results.json` | `f6a925f68d1c` | element_type, mesh_description, n_elements, ndof, H_ext, material_type, mu_r, chi |
# | 8 | `examples/cube_uniform_field/hexahedron/nonlinear/bicgstab/hex_N17_results.json` | `80535eea0be9` | element_type, mesh_description, n_elements, ndof, H_ext, material_type, mu_r, chi |
# | 9 | `examples/cube_uniform_field/hexahedron/nonlinear/bicgstab/hex_N18_results.json` | `9644f02636f0` | element_type, mesh_description, n_elements, ndof, H_ext, material_type, mu_r, chi |
# | 10 | `examples/cube_uniform_field/hexahedron/nonlinear/bicgstab/hex_N20_results.json` | `4d5f32840438` | element_type, mesh_description, n_elements, ndof, H_ext, material_type, mu_r, chi |
# | 11 | `examples/cube_uniform_field/hexahedron/nonlinear/bicgstab/hex_N3_results.json` | `5b757174290e` | element_type, mesh_description, n_elements, ndof, H_ext, material_type, mu_r, chi |
# | 12 | `examples/cube_uniform_field/hexahedron/nonlinear/bicgstab/hex_N4_results.json` | `874ebf05b2e2` | element_type, mesh_description, n_elements, ndof, H_ext, material_type, mu_r, chi |
# | 13 | `examples/cube_uniform_field/hexahedron/nonlinear/bicgstab/hex_N5_results.json` | `bdd8cc8fcaff` | element_type, mesh_description, n_elements, ndof, H_ext, material_type, mu_r, chi |
# | 14 | `examples/cube_uniform_field/hexahedron/nonlinear/bicgstab/hex_N6_results.json` | `00f7cea1f663` | element_type, mesh_description, n_elements, ndof, H_ext, material_type, mu_r, chi |
# | 15 | `examples/cube_uniform_field/hexahedron/nonlinear/bicgstab/hex_N7_results.json` | `2b8e96d9b82d` | element_type, mesh_description, n_elements, ndof, H_ext, material_type, mu_r, chi |
# | 16 | `examples/cube_uniform_field/hexahedron/nonlinear/bicgstab/hex_N8_results.json` | `72eb795a54ed` | element_type, mesh_description, n_elements, ndof, H_ext, material_type, mu_r, chi |
# | 17 | `examples/cube_uniform_field/hexahedron/nonlinear/bicgstab/hex_N9_results.json` | `d302d59dd173` | element_type, mesh_description, n_elements, ndof, H_ext, material_type, mu_r, chi |
# | 18 | `examples/cube_uniform_field/hexahedron/nonlinear/hacapk/hex_N10_results.json` | `f0e5d7b0cb9a` | element_type, mesh_description, n_elements, ndof, H_ext, material_type, mu_r, chi |
# | 19 | `examples/cube_uniform_field/hexahedron/nonlinear/hacapk/hex_N11_results.json` | `beff1759b5af` | element_type, mesh_description, n_elements, ndof, H_ext, material_type, mu_r, chi |
# | 20 | `examples/cube_uniform_field/hexahedron/nonlinear/hacapk/hex_N12_results.json` | `c33d7cbe9d76` | element_type, mesh_description, n_elements, ndof, H_ext, material_type, mu_r, chi |
# | 21 | `examples/cube_uniform_field/hexahedron/nonlinear/hacapk/hex_N13_results.json` | `e992e05cb104` | element_type, mesh_description, n_elements, ndof, H_ext, material_type, mu_r, chi |
# | 22 | `examples/cube_uniform_field/hexahedron/nonlinear/hacapk/hex_N14_results.json` | `1f24542d27ee` | element_type, mesh_description, n_elements, ndof, H_ext, material_type, mu_r, chi |
# | 23 | `examples/cube_uniform_field/hexahedron/nonlinear/hacapk/hex_N15_results.json` | `43095c475e75` | element_type, mesh_description, n_elements, ndof, H_ext, material_type, mu_r, chi |
# | 24 | `examples/cube_uniform_field/hexahedron/nonlinear/hacapk/hex_N16_results.json` | `dd44dc3ed14b` | element_type, mesh_description, n_elements, ndof, H_ext, material_type, mu_r, chi |
# | 25 | `examples/cube_uniform_field/hexahedron/nonlinear/hacapk/hex_N17_results.json` | `3add69e45f2b` | element_type, mesh_description, n_elements, ndof, H_ext, material_type, mu_r, chi |
# | 26 | `examples/cube_uniform_field/hexahedron/nonlinear/hacapk/hex_N18_results.json` | `0e356dc454e1` | element_type, mesh_description, n_elements, ndof, H_ext, material_type, mu_r, chi |
# | 27 | `examples/cube_uniform_field/hexahedron/nonlinear/hacapk/hex_N20_results.json` | `8c6b432782e7` | element_type, mesh_description, n_elements, ndof, H_ext, material_type, mu_r, chi |
# | 28 | `examples/cube_uniform_field/hexahedron/nonlinear/hacapk/hex_N22_results.json` | `050822f8c712` | element_type, mesh_description, n_elements, ndof, H_ext, material_type, mu_r, chi |
# | 29 | `examples/cube_uniform_field/hexahedron/nonlinear/hacapk/hex_N25_results.json` | `e23a00e9adf3` | element_type, mesh_description, n_elements, ndof, H_ext, material_type, mu_r, chi |
# | 30 | `examples/cube_uniform_field/hexahedron/nonlinear/hacapk/hex_N3_results.json` | `7d1fe165ce57` | element_type, mesh_description, n_elements, ndof, H_ext, material_type, mu_r, chi |
# | 31 | `examples/cube_uniform_field/hexahedron/nonlinear/hacapk/hex_N4_results.json` | `cbff1b71fb18` | element_type, mesh_description, n_elements, ndof, H_ext, material_type, mu_r, chi |
# | 32 | `examples/cube_uniform_field/hexahedron/nonlinear/hacapk/hex_N5_results.json` | `e8fbfe2617b5` | element_type, mesh_description, n_elements, ndof, H_ext, material_type, mu_r, chi |
# | 33 | `examples/cube_uniform_field/hexahedron/nonlinear/hacapk/hex_N6_results.json` | `5c20deeed690` | element_type, mesh_description, n_elements, ndof, H_ext, material_type, mu_r, chi |
# | 34 | `examples/cube_uniform_field/hexahedron/nonlinear/hacapk/hex_N7_results.json` | `41c227e839ef` | element_type, mesh_description, n_elements, ndof, H_ext, material_type, mu_r, chi |
# | 35 | `examples/cube_uniform_field/hexahedron/nonlinear/hacapk/hex_N8_results.json` | `bb4066c58128` | element_type, mesh_description, n_elements, ndof, H_ext, material_type, mu_r, chi |
# | 36 | `examples/cube_uniform_field/hexahedron/nonlinear/hacapk/hex_N9_results.json` | `4a1fdc853d3e` | element_type, mesh_description, n_elements, ndof, H_ext, material_type, mu_r, chi |
# | 37 | `examples/cube_uniform_field/hexahedron/nonlinear/lu/hex_N10_results.json` | `2385f0fc295c` | element_type, mesh_description, n_elements, ndof, H_ext, material_type, mu_r, chi |
# | 38 | `examples/cube_uniform_field/hexahedron/nonlinear/lu/hex_N11_results.json` | `1af9d7bfe686` | element_type, mesh_description, n_elements, ndof, H_ext, material_type, mu_r, chi |
# | 39 | `examples/cube_uniform_field/hexahedron/nonlinear/lu/hex_N12_results.json` | `b932a83a1c0f` | element_type, mesh_description, n_elements, ndof, H_ext, material_type, mu_r, chi |
# | 40 | `examples/cube_uniform_field/hexahedron/nonlinear/lu/hex_N13_results.json` | `fc1ffd3d410a` | element_type, mesh_description, n_elements, ndof, H_ext, material_type, mu_r, chi |
# | 41 | `examples/cube_uniform_field/hexahedron/nonlinear/lu/hex_N14_results.json` | `529ee1cf50a4` | element_type, mesh_description, n_elements, ndof, H_ext, material_type, mu_r, chi |
# | 42 | `examples/cube_uniform_field/hexahedron/nonlinear/lu/hex_N15_results.json` | `4a3bea5c1933` | element_type, mesh_description, n_elements, ndof, H_ext, material_type, mu_r, chi |
# | 43 | `examples/cube_uniform_field/hexahedron/nonlinear/lu/hex_N16_results.json` | `49304886045a` | element_type, mesh_description, n_elements, ndof, H_ext, material_type, mu_r, chi |
# | 44 | `examples/cube_uniform_field/hexahedron/nonlinear/lu/hex_N3_results.json` | `55fe8d216196` | element_type, mesh_description, n_elements, ndof, H_ext, material_type, mu_r, chi |
# | 45 | `examples/cube_uniform_field/hexahedron/nonlinear/lu/hex_N4_results.json` | `15e66b8ae44b` | element_type, mesh_description, n_elements, ndof, H_ext, material_type, mu_r, chi |
# | 46 | `examples/cube_uniform_field/hexahedron/nonlinear/lu/hex_N5_results.json` | `946e7a2b366d` | element_type, mesh_description, n_elements, ndof, H_ext, material_type, mu_r, chi |
# | 47 | `examples/cube_uniform_field/hexahedron/nonlinear/lu/hex_N6_results.json` | `d72ca233070e` | element_type, mesh_description, n_elements, ndof, H_ext, material_type, mu_r, chi |
# | 48 | `examples/cube_uniform_field/hexahedron/nonlinear/lu/hex_N7_results.json` | `f4ad1d44a340` | element_type, mesh_description, n_elements, ndof, H_ext, material_type, mu_r, chi |
# | 49 | `examples/cube_uniform_field/hexahedron/nonlinear/lu/hex_N8_results.json` | `8bdba1117e06` | element_type, mesh_description, n_elements, ndof, H_ext, material_type, mu_r, chi |
# | 50 | `examples/cube_uniform_field/hexahedron/nonlinear/lu/hex_N9_results.json` | `24da8caf90bc` | element_type, mesh_description, n_elements, ndof, H_ext, material_type, mu_r, chi |
# | 51 | `examples/cube_uniform_field/tetrahedron/nonlinear/bicgstab/tetra_maxh0_08m_results.json` | `140057684400` | element_type, mesh_description, n_elements, ndof, H_ext, material_type, mu_r, chi |
# | 52 | `examples/cube_uniform_field/tetrahedron/nonlinear/bicgstab/tetra_maxh0_10m_results.json` | `d227ca068ce6` | element_type, mesh_description, n_elements, ndof, H_ext, material_type, mu_r, chi |
# | 53 | `examples/cube_uniform_field/tetrahedron/nonlinear/bicgstab/tetra_maxh0_12m_results.json` | `d701c620e530` | element_type, mesh_description, n_elements, ndof, H_ext, material_type, mu_r, chi |
# | 54 | `examples/cube_uniform_field/tetrahedron/nonlinear/bicgstab/tetra_maxh0_15m_results.json` | `c14f16bdbec1` | element_type, mesh_description, n_elements, ndof, H_ext, material_type, mu_r, chi |
# | 55 | `examples/cube_uniform_field/tetrahedron/nonlinear/bicgstab/tetra_maxh0_20m_results.json` | `0cbaf11ec1a9` | element_type, mesh_description, n_elements, ndof, H_ext, material_type, mu_r, chi |
# | 56 | `examples/cube_uniform_field/tetrahedron/nonlinear/bicgstab/tetra_maxh0_25m_results.json` | `77053340af6b` | element_type, mesh_description, n_elements, ndof, H_ext, material_type, mu_r, chi |
# | 57 | `examples/cube_uniform_field/tetrahedron/nonlinear/bicgstab/tetra_maxh0_30m_results.json` | `c00dc933728f` | element_type, mesh_description, n_elements, ndof, H_ext, material_type, mu_r, chi |
# | 58 | `examples/cube_uniform_field/tetrahedron/nonlinear/bicgstab/tetra_maxh0_40m_results.json` | `c15ede3b54c9` | element_type, mesh_description, n_elements, ndof, H_ext, material_type, mu_r, chi |
# | 59 | `examples/cube_uniform_field/tetrahedron/nonlinear/hacapk/tetra_maxh0_05m_results.json` | `4cb4d8b9a891` | element_type, mesh_description, n_elements, ndof, H_ext, material_type, mu_r, chi |
# | 60 | `examples/cube_uniform_field/tetrahedron/nonlinear/hacapk/tetra_maxh0_06m_results.json` | `c52f2f19cd39` | element_type, mesh_description, n_elements, ndof, H_ext, material_type, mu_r, chi |
# | 61 | `examples/cube_uniform_field/tetrahedron/nonlinear/hacapk/tetra_maxh0_07m_results.json` | `af98396fc818` | element_type, mesh_description, n_elements, ndof, H_ext, material_type, mu_r, chi |
# | 62 | `examples/cube_uniform_field/tetrahedron/nonlinear/hacapk/tetra_maxh0_08m_results.json` | `815e703e0c70` | element_type, mesh_description, n_elements, ndof, H_ext, material_type, mu_r, chi |
# | 63 | `examples/cube_uniform_field/tetrahedron/nonlinear/hacapk/tetra_maxh0_10m_results.json` | `ed5a56390473` | element_type, mesh_description, n_elements, ndof, H_ext, material_type, mu_r, chi |
# | 64 | `examples/cube_uniform_field/tetrahedron/nonlinear/hacapk/tetra_maxh0_12m_results.json` | `402e076dec85` | element_type, mesh_description, n_elements, ndof, H_ext, material_type, mu_r, chi |
# | 65 | `examples/cube_uniform_field/tetrahedron/nonlinear/hacapk/tetra_maxh0_15m_results.json` | `6711b2b4c9f9` | element_type, mesh_description, n_elements, ndof, H_ext, material_type, mu_r, chi |
# | 66 | `examples/cube_uniform_field/tetrahedron/nonlinear/hacapk/tetra_maxh0_20m_results.json` | `e1768460dc5e` | element_type, mesh_description, n_elements, ndof, H_ext, material_type, mu_r, chi |
# | 67 | `examples/cube_uniform_field/tetrahedron/nonlinear/hacapk/tetra_maxh0_25m_results.json` | `4b0a328f8e11` | element_type, mesh_description, n_elements, ndof, H_ext, material_type, mu_r, chi |
# | 68 | `examples/cube_uniform_field/tetrahedron/nonlinear/hacapk/tetra_maxh0_30m_results.json` | `2f6b8b7def2a` | element_type, mesh_description, n_elements, ndof, H_ext, material_type, mu_r, chi |
# | 69 | `examples/cube_uniform_field/tetrahedron/nonlinear/hacapk/tetra_maxh0_40m_results.json` | `c9e4ac96121d` | element_type, mesh_description, n_elements, ndof, H_ext, material_type, mu_r, chi |
# | 70 | `examples/cube_uniform_field/tetrahedron/nonlinear/lu/tetra_maxh0_15m_results.json` | `7a3833f915b6` | element_type, mesh_description, n_elements, ndof, H_ext, material_type, mu_r, chi |
# | 71 | `examples/cube_uniform_field/tetrahedron/nonlinear/lu/tetra_maxh0_20m_results.json` | `8025468b3bea` | element_type, mesh_description, n_elements, ndof, H_ext, material_type, mu_r, chi |
# | 72 | `examples/cube_uniform_field/tetrahedron/nonlinear/lu/tetra_maxh0_25m_results.json` | `11cbaed0eabb` | element_type, mesh_description, n_elements, ndof, H_ext, material_type, mu_r, chi |
# | 73 | `examples/cube_uniform_field/tetrahedron/nonlinear/lu/tetra_maxh0_30m_results.json` | `097873c97ec3` | element_type, mesh_description, n_elements, ndof, H_ext, material_type, mu_r, chi |
# | 74 | `examples/cube_uniform_field/tetrahedron/nonlinear/lu/tetra_maxh0_40m_results.json` | `263541a1a842` | element_type, mesh_description, n_elements, ndof, H_ext, material_type, mu_r, chi |
# media artifacts indexed: 4
