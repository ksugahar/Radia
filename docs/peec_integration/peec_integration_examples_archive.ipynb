# %% [markdown]
# # Peec Integration Examples Archive
#
# This notebook is a result-saved promotion archive for `examples/peec_integration`.
# It keeps theory, source inventory, result payloads, and placement policy in one
# human-readable surface while the adjacent JSON remains the durable debug record.
#
# ## Theory and Scope
#
# - This notebook is the topic-specific source/result archive for examples/peec_integration.
# - It preserves full source, hashes, adjacent JSON payloads, and result media hashes before any pruning decision.
# - Validation-class scripts remain executable in examples until explicit validation_test gates or reusable src APIs exist.
#
# ## Placement Policy
#
# Docs-first topic archive for examples/peec_integration. Keep scripts until protected docs, panel, package, and validation_test references have been migrated to docs, src, panels, or validation_test.
#
# ## Synchronization
#
# The durable archive is `peec_integration_examples_archive_results.json`. It stores full source, SHA-256 hashes,
# existing result JSON payloads, media hashes, runtime metadata, and the promotion
# lane for every script in this batch.

# %%
from pathlib import Path
import json
from IPython.display import Markdown, display

archive_path = Path('peec_integration_examples_archive_results.json')
if not archive_path.exists():
    archive_path = Path('docs/peec_integration/peec_integration_examples_archive_results.json')
data = json.loads(archive_path.read_text(encoding='utf-8'))
counts = data['counts']
print(f"topic={data['topic']}")
print(f"python_scripts={counts['python_scripts']}")
print(f"topic_json_files={counts['topic_json_files']}")
print(f"media_files={counts['media_files']}")
print(f"promotion_lane={data['promotion_lane']}")
# Out:
# topic=peec_integration
# python_scripts=125
# topic_json_files=0
# media_files=53
# promotion_lane=topic_docs_first_archive

# %% [markdown]
# ## Script Inventory
# Generated from the synchronized JSON archive.

# %%
header = '| # | script | lines | json refs | docstring |\n|---:|---|---:|---:|---|'
body = []
for i, rec in enumerate(data['records'], 1):
    doc = (rec.get('docstring_first_line') or '').replace('|', '\\|')
    body.append(f"| {i} | `{rec['path']}` | {rec['line_count']} | {len(rec.get('attached_json', []))} | {doc} |")
display(Markdown('\n'.join([header] + body)))
# Out:
# | # | script | lines | json refs | docstring |
# |---:|---|---:|---:|---|
# | 1 | `examples/peec_integration/algorithm_development/compare_dowell_sibc_bessel_straight_wire.py` | 226 | 0 | Canonical straight-wire comparison: Dowell vs SIBC vs Bessel-exact R_AC. |
# | 2 | `examples/peec_integration/algorithm_development/derive_dowell_cf.py` | 293 | 0 | Dowell F_R(xi) and F_L(xi) Taylor expansion around s=0 |
# | 3 | `examples/peec_integration/algorithm_development/derive_dowell_cf_algorithm.py` | 433 | 0 | Dowell F_R(s) and F_L(s) - Continued Fraction via Viskovatov Algorithm |
# | 4 | `examples/peec_integration/algorithm_development/derive_dowell_pade.py` | 419 | 0 | Dowell F_R(s) and F_L(s) Pade (Rational Function) Expansion |
# | 5 | `examples/peec_integration/algorithm_development/derive_dowell_prima.py` | 226 | 0 | Dowell式からPRIMAパラメータを導出 |
# | 6 | `examples/peec_integration/analysis/analyze_dowell_prima.py` | 303 | 0 | Dowell Factor vs PRIMA Analysis |
# | 7 | `examples/peec_integration/analysis/analyze_tet_ordering.py` | 112 | 0 | Analyze Netgen tetrahedral vertex ordering to determine correct mapping to Gmsh. |
# | 8 | `examples/peec_integration/analysis/compare_symmetrized_solve.py` | 321 | 0 | compare_symmetrized_solve.py |
# | 9 | `examples/peec_integration/analysis/demo_analysis_framework.py` | 310 | 0 | Demonstration of the Unified Analysis Framework |
# | 10 | `examples/peec_integration/analysis/evaluate_peec_formula_accuracy.py` | 531 | 0 | evaluate_peec_formula_accuracy.py |
# | 11 | `examples/peec_integration/analysis/generate_paper_figures.py` | 584 | 0 | Paper Figures Generation for PEEC/PRIMA Implementation |
# | 12 | `examples/peec_integration/analysis/measure_msc_asymmetry.py` | 393 | 0 | measure_msc_asymmetry.py |
# | 13 | `examples/peec_integration/applications/demo_circular_coil_4cases.py` | 516 | 0 | demo_circular_coil_4cases.py |
# | 14 | `examples/peec_integration/applications/demo_dielectric.py` | 620 | 0 | Demonstration of Dielectric Solver with Loop-Star Integration |
# | 15 | `examples/peec_integration/applications/demo_fasthenry_core_eddy.py` | 284 | 0 | demo_fasthenry_core_eddy.py |
# | 16 | `examples/peec_integration/applications/demo_fasthenry_magnetic_core.py` | 389 | 0 | demo_fasthenry_magnetic_core.py |
# | 17 | `examples/peec_integration/applications/demo_induction_heating.py` | 401 | 0 | Induction Heating Analysis with PEEC and Surface Impedance |
# | 18 | `examples/peec_integration/applications/demo_nmr_magnet.py` | 454 | 0 | NMR Magnet Homogeneity Analysis with Spherical Harmonics |
# | 19 | `examples/peec_integration/basic_peec/demo_frequency_response.py` | 328 | 0 | Demonstration of Frequency Response Analysis |
# | 20 | `examples/peec_integration/basic_peec/demo_loop_star.py` | 380 | 0 | Demonstration of Loop-Star Decomposition for PEEC Analysis |
# | 21 | `examples/peec_integration/basic_peec/demo_peec_dc.py` | 264 | 0 | Corrected DC PEEC Analysis with Neumann Integral |
# | 22 | `examples/peec_integration/basic_peec/demo_peec_from_1d_mesh.py` | 263 | 0 | PEEC Analysis from 1D Line Mesh (GMSH) |
# | 23 | `examples/peec_integration/basic_peec/demo_peec_from_dual_mesh.py` | 224 | 0 | PEEC Analysis from Dual Mesh (Filament + Panel) |
# | 24 | `examples/peec_integration/basic_peec/demo_peec_from_gmsh.py` | 244 | 0 | PEEC Analysis from GMSH Mesh |
# | 25 | `examples/peec_integration/basic_peec/demo_peec_simple_loop.py` | 129 | 0 | Simple PEEC Analysis for Circular Coil |
# | 26 | `examples/peec_integration/basic_peec/demo_port_extraction.py` | 199 | 0 | Demonstrate Port Extraction from GMSH Mesh for PEEC Analysis |
# | 27 | `examples/peec_integration/benchmarks/benchmark_panel_vs_ngbem.py` | 451 | 0 | benchmark_panel_vs_ngbem.py |
# | 28 | `examples/peec_integration/benchmarks/vf_benchmark_same_data.py` | 561 | 0 | Vector Fitting Benchmark on Same Test Cases as URN |
# | 29 | `examples/peec_integration/coil/coil_impedance_peec.py` | 689 | 0 | Coil Impedance Analysis using PEEC Method |
# | 30 | `examples/peec_integration/coil/coil_on_magnetic_core_analysis.py` | 392 | 0 | Coil wound on magnetic core - Frequency-dependent characteristics analysis. |
# | 31 | `examples/peec_integration/coil/coil_on_magnetic_core_peec.py` | 389 | 0 | Coil on Magnetic Core - CplMag Solver Analysis |
# | 32 | `examples/peec_integration/coil/demo_circular_coil_gmsh.py` | 130 | 0 | Circular coil boundary-surface demo for PEEC-style workflows. |
# | 33 | `examples/peec_integration/coupled/convergence_delta_L.py` | 281 | 0 | convergence_delta_L.py |
# | 34 | `examples/peec_integration/coupled/demo_coupled_frequency_sweep.py` | 387 | 0 | demo_coupled_frequency_sweep.py |
# | 35 | `examples/peec_integration/coupled/demo_coupled_inductance.py` | 353 | 0 | demo_coupled_inductance.py |
# | 36 | `examples/peec_integration/coupled/demo_eddy_inductance_reduction.py` | 545 | 0 | demo_eddy_inductance_reduction.py |
# | 37 | `examples/peec_integration/coupled/demo_schur_complement.py` | 285 | 0 | demo_schur_complement.py |
# | 38 | `examples/peec_integration/coupled/test_delta_L_robustness.py` | 309 | 0 | test_delta_L_robustness.py |
# | 39 | `examples/peec_integration/coupled/validate_fem_back_reaction.py` | 501 | 0 | validate_fem_back_reaction.py |
# | 40 | `examples/peec_integration/coupled/verify_multielement_msc.py` | 241 | 0 | verify_multielement_msc.py |
# | 41 | `examples/peec_integration/filament_coil/cad_sweep_smoke.py` | 169 | 0 | cad_sweep_smoke.py |
# | 42 | `examples/peec_integration/filament_coil/circle_and_crosstype_smoke.py` | 184 | 0 | circle_and_crosstype_smoke.py |
# | 43 | `examples/peec_integration/filament_coil/compare_filament_vs_centerline.py` | 168 | 0 | compare_filament_vs_centerline.py |
# | 44 | `examples/peec_integration/filament_coil/compare_ihbem_peec_vs_tiera.py` | 330 | 0 | compare_ihbem_peec_vs_tiera.py |
# | 45 | `examples/peec_integration/filament_coil/compare_peec_vs_tier_a.py` | 226 | 0 | compare_peec_vs_tier_a.py |
# | 46 | `examples/peec_integration/filament_coil/compare_tier_a_vs_ngbem.py` | 338 | 0 | compare_tier_a_vs_ngbem.py |
# | 47 | `examples/peec_integration/filament_coil/from_step_smoke.py` | 231 | 0 | Sprint 1 smoke test for coil_from_step.extract_centerline. |
# | 48 | `examples/peec_integration/filament_coil/ih_cad_first_demo.py` | 151 | 0 | ih_cad_first_demo.py |
# | 49 | `examples/peec_integration/filament_coil/ih_parametric_sweep_demo.py` | 111 | 0 | ih_parametric_sweep_demo.py |
# | 50 | `examples/peec_integration/filament_coil/loft_demo.py` | 177 | 0 | loft_demo.py |
# | 51 | `examples/peec_integration/filament_coil/loft_taper_smoke.py` | 163 | 0 | loft_taper_smoke.py |
# | 52 | `examples/peec_integration/filament_coil/loop_bundle_verify.py` | 87 | 0 | Verify the Loop-form bundle reduction matches full nodal MNA. |
# | 53 | `examples/peec_integration/filament_coil/optimize_round_torus_claude.py` | 99 | 0 | optimize_round_torus_claude.py |
# | 54 | `examples/peec_integration/filament_coil/optimize_round_torus_random.py` | 82 | 0 | optimize_round_torus_random.py |
# | 55 | `examples/peec_integration/filament_coil/peec_bundle_bem_sibc_demo.py` | 227 | 0 | peec_bundle_bem_sibc_demo.py |
# | 56 | `examples/peec_integration/filament_coil/polygon_and_b123d_smoke.py` | 195 | 0 | polygon_and_b123d_smoke.py |
# | 57 | `examples/peec_integration/filament_coil/smoke_racetrack_tier_a.py` | 115 | 0 | smoke_racetrack_tier_a.py |
# | 58 | `examples/peec_integration/gmsh_models/demo_gmsh_ports_peec.py` | 317 | 0 | PEEC Analysis with Port-Defined GMSH Mesh |
# | 59 | `examples/peec_integration/gmsh_models/demo_gmsh_surface_mesh.py` | 95 | 0 | PEEC conductor boundary surface from a Netgen .vol mesh. |
# | 60 | `examples/peec_integration/gmsh_models/demo_gmsh_to_peec.py` | 238 | 0 | PEEC Analysis from GMSH Mesh |
# | 61 | `examples/peec_integration/gmsh_models/generate_1d_coil_mesh.py` | 128 | 0 | Generate 1D Line Mesh for PEEC Analysis using Coreform Cubit |
# | 62 | `examples/peec_integration/gmsh_models/generate_coil_cubit.py` | 120 | 0 | Generate Circular Coil Mesh using Coreform Cubit |
# | 63 | `examples/peec_integration/gmsh_models/generate_coil_with_ports.py` | 169 | 0 | Generate Circular Coil Mesh with PORT DEFINITIONS using Coreform Cubit |
# | 64 | `examples/peec_integration/gmsh_models/generate_dual_mesh_filament_panel.py` | 185 | 0 | Generate Dual Mesh for PEEC: Filament (1D) + Panel (2D) |
# | 65 | `examples/peec_integration/gmsh_models/gmsh_ascii_reader.py` | 170 | 0 | Small GMSH ASCII reader for PEEC examples. |
# | 66 | `examples/peec_integration/ngbem/demo_ngbem_coupled.py` | 394 | 0 | demo_ngbem_coupled.py |
# | 67 | `examples/peec_integration/ngbem/demo_ngbem_eddy.py` | 339 | 0 | demo_ngbem_eddy.py |
# | 68 | `examples/peec_integration/ngbem/demo_ngbem_peec.py` | 272 | 0 | demo_ngbem_peec.py |
# | 69 | `examples/peec_integration/ngsbem_peec_demo/benchmark_4case.py` | 356 | 0 | 4-case material coupling benchmark: ngbem surface BEM vs PEEC filament. |
# | 70 | `examples/peec_integration/ngsbem_peec_demo/compute_L_final.py` | 163 | 0 | Compute loop inductance of rectangular frame using ngsbem EFIE. |
# | 71 | `examples/peec_integration/ngsbem_peec_demo/fasthenry-like/demo_impedance_sweep.py` | 172 | 0 | FastHenry-like PEEC: Impedance sweep on a rectangular plate. |
# | 72 | `examples/peec_integration/ngsbem_peec_demo/fasthenry-like/demo_material_coupling.py` | 192 | 0 | FastHenry-like PEEC: Material coupling (ferrite + shield) on a flat plate. |
# | 73 | `examples/peec_integration/ngsbem_peec_demo/fasthenry-like/experiment_busbar_comparison.py` | 242 | 0 | Bus bar Dowell comparison: ngbem PEEC vs FastHenry PEEC |
# | 74 | `examples/peec_integration/ngsbem_peec_demo/fasthenry-like/experiment_dowell_comparison.py` | 291 | 0 | test_dowell_comparison.py |
# | 75 | `examples/peec_integration/ngsbem_peec_demo/ngbem/1_turn_coil.py` | 586 | 0 | 1_turn_coil.py |
# | 76 | `examples/peec_integration/ngsbem_peec_demo/ngbem/demo_impedance_sweep.py` | 128 | 0 | ngbem PEEC: Impedance sweep on a flat-plate conductor. |
# | 77 | `examples/peec_integration/ngsbem_peec_demo/ngbem/demo_material_coupling.py` | 172 | 0 | ngbem PEEC: Material coupling (ferrite + shield) on a flat-plate conductor. |
# | 78 | `examples/peec_integration/ngsbem_peec_demo/ngbem_coupled.py` | 697 | 0 | ngbem_coupled.py |
# | 79 | `examples/peec_integration/ngsbem_peec_demo/ngbem_eddy.py` | 2485 | 0 | ngbem_eddy.py |
# | 80 | `examples/peec_integration/ngsbem_peec_demo/ngbem_interface.py` | 780 | 0 | ngbem_interface.py |
# | 81 | `examples/peec_integration/ngsbem_peec_demo/ngbem_peec.py` | 987 | 0 | ngbem_peec.py |
# | 82 | `examples/peec_integration/ngsbem_peec_demo/verify_loop_peec_vs_ngsbem.py` | 227 | 0 | verify_loop_peec_vs_ngsbem.py |
# | 83 | `examples/peec_integration/ngsbem_peec_demo/verify_peec_vs_ngsbem.py` | 367 | 0 | verify_peec_vs_ngsbem.py |
# | 84 | `examples/peec_integration/spice/demo_dowell_spice.py` | 263 | 0 | Dowell表皮効果モデルのSPICE化 |
# | 85 | `examples/peec_integration/spice/demo_peec_prima_reduction.py` | 992 | 0 | DC PEEC Model Reduction using Lanczos-based PRIMA Transform |
# | 86 | `examples/peec_integration/spice/demo_prima_spice_export.py` | 955 | 0 | PRIMA to SPICE Export Demo |
# | 87 | `examples/peec_integration/spice/demo_veriloga_export.py` | 371 | 0 | Verilog-A Export Demo for PEEC Models |
# | 88 | `examples/peec_integration/spice/dowell_to_prima.py` | 264 | 0 | Dowell式をPRIMA形式で表現 |
# | 89 | `examples/peec_integration/spice/prima_with_dowell_correction.py` | 211 | 0 | PRIMA + Dowell補正の検証 |
# | 90 | `examples/peec_integration/verification/check_funcs.py` | 8 | 0 |  |
# | 91 | `examples/peec_integration/verification/check_mmm_elements.py` | 74 | 0 | Check MMM element count and geometry. |
# | 92 | `examples/peec_integration/verification/cubit_mesh_generation/generate_circular_coil.py` | 144 | 0 | Cubit: Generate Circular Coil Centerline Mesh for PEEC Validation |
# | 93 | `examples/peec_integration/verification/cubit_mesh_generation/generate_circular_wire.py` | 137 | 0 | Cubit: Generate Circular Wire Centerline Mesh for PEEC Validation |
# | 94 | `examples/peec_integration/verification/experiment_fem_convergence.py` | 126 | 0 | Quick FEM convergence study for L_air. |
# | 95 | `examples/peec_integration/verification/experiment_loop_star_modes.py` | 205 | 0 | test_loop_star_modes.py |
# | 96 | `examples/peec_integration/verification/gmsh_centerline_reader.py` | 163 | 0 | GMSH v2.2 Centerline Reader for PEEC |
# | 97 | `examples/peec_integration/verification/validate_bemsibc.py` | 394 | 0 | validate_bemsibc.py |
# | 98 | `examples/peec_integration/verification/validate_bessel_sibc.py` | 398 | 0 | PEEC SIBC Validation: Bessel Function (Circular Wire) vs Dowell (Rectangular) |
# | 99 | `examples/peec_integration/verification/validate_circular_coil_sibc.py` | 314 | 0 | PEEC SIBC Validation: Circular Coil vs Analytical Solution |
# | 100 | `examples/peec_integration/verification/validate_circular_wire_sibc.py` | 348 | 0 | PEEC SIBC Validation: Circular Wire vs Bessel Function Analytical Solution |
# | 101 | `examples/peec_integration/verification/validate_coupled.py` | 473 | 0 | validate_coupled.py |
# | 102 | `examples/peec_integration/verification/validate_coupling.py` | 379 | 0 | Validation: PEEC Multi-Port Z-Matrix and Coupling Coefficient |
# | 103 | `examples/peec_integration/verification/validate_fasthenry.py` | 495 | 0 | validate_fasthenry.py |
# | 104 | `examples/peec_integration/verification/validate_loop_star.py` | 581 | 0 | validate_loop_star.py |
# | 105 | `examples/peec_integration/verification/validate_multifilament.py` | 381 | 0 | validate_multifilament.py |
# | 106 | `examples/peec_integration/verification/validate_ngbem_bridge.py` | 404 | 0 | validate_ngbem_bridge.py |
# | 107 | `examples/peec_integration/verification/validate_panel_resonance.py` | 276 | 0 | Validation: PEEC Panel + Resonance (Phase A-D Integration Test) |
# | 108 | `examples/peec_integration/verification/validate_shield_delta_r.py` | 282 | 0 | validate_shield_delta_r.py |
# | 109 | `examples/peec_integration/verification/validate_stabilized_bem.py` | 685 | 0 | validate_stabilized_bem.py |
# | 110 | `examples/peec_integration/verification/validate_topology.py` | 439 | 0 | validate_topology.py |
# | 111 | `examples/peec_integration/verification/verify_circle_area_2nd_order.py` | 125 | 0 | Verify curved Netgen/NGSolve area convergence on a circular disk. |
# | 112 | `examples/peec_integration/verification/verify_dowell_diffusion.py` | 265 | 0 | Dowell式と1D拡散式の直接比較 |
# | 113 | `examples/peec_integration/verification/verify_frequency_response_85khz.py` | 388 | 0 | Frequency Response Verification at 85 kHz |
# | 114 | `examples/peec_integration/verification/verify_lanczos_uv_equality.py` | 196 | 0 | Verify U = V for symmetric Lanczos transformation |
# | 115 | `examples/peec_integration/verification/verify_loop_star.py` | 331 | 0 | Loop-Star Decomposition Verification |
# | 116 | `examples/peec_integration/verification/verify_ngsolve_inductance.py` | 788 | 0 | verify_ngsolve_inductance.py |
# | 117 | `examples/peec_integration/verification/verify_peec_prima_dowell.py` | 295 | 0 | PEEC + Dowell vs PRIMA + F_R/F_L の一致検証 |
# | 118 | `examples/peec_integration/verification/verify_prima_dowell_correct.py` | 257 | 0 | PRIMA vs Dowell 正しい比較 |
# | 119 | `examples/peec_integration/verification/verify_prima_dowell_form.py` | 245 | 0 | PRIMAインピーダンスをDowell形式に変換して比較 |
# | 120 | `examples/peec_integration/verification/verify_prima_frequency_response.py` | 432 | 0 | Verify PRIMA I frequency response matches original PEEC Loop impedance |
# | 121 | `examples/peec_integration/verification/verify_prima_loop_star.py` | 428 | 0 | PRIMA変換後のLoop-Star相互作用の周波数特性検証 |
# | 122 | `examples/peec_integration/verification/verify_symmetrization.py` | 284 | 0 | Verify that matrix symmetrization produces identical results. |
# | 123 | `examples/peec_integration/wpt/demo_wpt.py` | 636 | 0 | Demonstration of Multi-Port WPT (Wireless Power Transfer) Analysis |
# | 124 | `examples/peec_integration/wpt/wpt_85khz_cubit_mesh.py` | 324 | 0 | WPT 85 kHz System with Cubit Mesh Generation |
# | 125 | `examples/peec_integration/wpt/wpt_85khz_with_shield.py` | 490 | 0 | WPT System at 85 kHz with Ferrite Core and Aluminum Shield |

# %% [markdown]
# ## Integrity Checks

# %%
assert counts['python_scripts'] == len(data['records'])
assert all(len(rec['sha256']) == 64 for rec in data['records'])
assert all(rec.get('source') for rec in data['records'])
print('archive integrity: ok')
# Out:
# archive integrity: ok

# %% [markdown]
# ## Result Payloads and Media

# %%
rows = data.get('topic_json_files', [])
if rows:
    header = '| # | json | sha256 | keys |\n|---:|---|---|---|'
    body = []
    for i, row in enumerate(rows, 1):
        payload = row.get('payload')
        keys = ', '.join(list(payload.keys())[:8]) if isinstance(payload, dict) else type(payload).__name__
        body.append(f"| {i} | `{row['path']}` | `{row['sha256'][:12]}` | {keys.replace('|', '\\|')} |")
    display(Markdown('\n'.join([header] + body)))
else:
    print('no existing JSON payloads found')

media = data.get('media_files', [])
print(f"media artifacts indexed: {len(media)}")
# Out:
# no existing JSON payloads found
# media artifacts indexed: 53
