# %% [markdown]
# # Maglev Examples Archive
#
# This notebook is a result-saved promotion archive for `examples/maglev`.
# It keeps theory, source inventory, result payloads, and placement policy in one
# human-readable surface while the adjacent JSON remains the durable debug record.
#
# ## Theory and Scope
#
# - This notebook is the topic-specific source/result archive for examples/maglev.
# - It preserves full source, hashes, adjacent JSON payloads, and result media hashes before any pruning decision.
# - Validation-class scripts remain executable in examples until explicit validation_test gates or reusable src APIs exist.
#
# ## Placement Policy
#
# Docs-first topic archive for examples/maglev. Keep scripts until protected docs, panel, package, and validation_test references have been migrated to docs, src, panels, or validation_test.
#
# ## Synchronization
#
# The durable archive is `maglev_examples_archive_results.json`. It stores full source, SHA-256 hashes,
# existing result JSON payloads, media hashes, runtime metadata, and the promotion
# lane for every script in this batch.

# %%
from pathlib import Path
import json
from IPython.display import Markdown, display

archive_path = Path('maglev_examples_archive_results.json')
if not archive_path.exists():
    archive_path = Path('docs/maglev/maglev_examples_archive_results.json')
data = json.loads(archive_path.read_text(encoding='utf-8'))
counts = data['counts']
print(f"topic={data['topic']}")
print(f"python_scripts={counts['python_scripts']}")
print(f"topic_json_files={counts['topic_json_files']}")
print(f"media_files={counts['media_files']}")
print(f"promotion_lane={data['promotion_lane']}")
# Out:
# topic=maglev
# python_scripts=166
# topic_json_files=115
# media_files=22
# promotion_lane=topic_docs_first_archive

# %% [markdown]
# ## Script Inventory
# Generated from the synchronized JSON archive.

# %%
header = '| # | script | lines | json refs | docstring |\n|---:|---|---:|---:|---|'
body = []
for i, rec in enumerate(data['records'], 1):
    doc = (rec.get('docstring_first_line') or '').replace('|', '\\|')
    body.append(f"| {i} | `{rec['path']}` | {rec['line_count']} | {len(rec.get('attached_json', []))} | {doc} |")
display(Markdown('\n'.join([header] + body)))
# Out:
# | # | script | lines | json refs | docstring |
# |---:|---|---:|---:|---|
# | 1 | `examples/maglev/cube_alpha_sweep.py` | 71 | 0 | cube_alpha_sweep.py -- Generate a 5mm Cu cube .vol and sweep alpha(s). |
# | 2 | `examples/maglev/cube_alpha_sweep_figure.py` | 152 | 0 | cube_alpha_sweep_figure.py -- paper figure: Cu cube polarizability alpha(s). |
# | 3 | `examples/maglev/cube_alpha_tensor.py` | 155 | 0 | cube_alpha_tensor.py -- multi-port (matrix) Mixed-Galerkin admittance Y(s). |
# | 4 | `examples/maglev/cuboid/cln_sibc_cuboid_3d.py` | 128 | 0 | cln_sibc_cuboid_3d.py -- Python port of the lab CLN-SIBC (rank-(1,1) Mixed Galerkin) |
# | 5 | `examples/maglev/cuboid_vector_bulk.py` | 96 | 0 | cuboid_vector_bulk.py -- vector (HCurl) eddy-current Foster spectrum. |
# | 6 | `examples/maglev/ellipsoid/ellipsoid_alpha_omega_axisym.py` | 237 | 0 | ellipsoid_alpha_omega_axisym.py -- full-frequency AXIAL eddy-current |
# | 7 | `examples/maglev/ellipsoid/ellipsoid_alpha_tensor.py` | 236 | 0 | ellipsoid_alpha_tensor.py -- SHAPE-anisotropic eddy-current polarizability |
# | 8 | `examples/maglev/ellipsoid/ellipsoid_alpha_tensor_3d.py` | 250 | 0 | ellipsoid_alpha_tensor_3d.py -- TRANSVERSE (m=1) component of the |
# | 9 | `examples/maglev/physical_tensor_rom.py` | 181 | 0 | physical_tensor_rom.py -- the EXTERIOR-MATCHED physical polarizability tensor |
# | 10 | `examples/maglev/research_cln/A1_sibc_unified_compare.py` | 536 | 0 | A1 cuboid (17.72×17.72×2 mm Cu) Cauer→SIBC unified Y(jω) comparison. |
# | 11 | `examples/maglev/research_cln/axifem/axifem_core.py` | 311 | 0 | axifem_core.py — Phase 1 prototype: FEMM-style axisymmetric magnetostatic solver. |
# | 12 | `examples/maglev/research_cln/axifem/axifem_p2_triangle.py` | 372 | 0 | axifem_p2_triangle.py — P2 Henrotte triangle reference (Python). |
# | 13 | `examples/maglev/research_cln/axifem/axifem_quad.py` | 436 | 0 | axifem_quad.py — Phase 1b: FEMM/Henrotte Q1 axisymmetric on axis-aligned rectangles. |
# | 14 | `examples/maglev/research_cln/axifem/axifem_quad_q2.py` | 214 | 0 | axifem_quad_q2.py — Phase 2-F (axifem Q2 prototype) |
# | 15 | `examples/maglev/research_cln/axifem/axifem_quad_q2_curved.py` | 346 | 0 | axifem_quad_q2_curved.py — historical curved Q2 Henrotte Python prototype. |
# | 16 | `examples/maglev/research_cln/axifem/disk_convergence_sweep.py` | 128 | 0 | disk_convergence_sweep.py — Probe axifem convergence to v22b (208.32 us). |
# | 17 | `examples/maglev/research_cln/axifem/nmr_validate.py` | 234 | 0 | nmr_validate.py — Reproduce the FEMM NMR axisymmetric problem with axifem_core |
# | 18 | `examples/maglev/research_cln/axifem/sigma_mass.py` | 150 | 0 | sigma_mass.py — Sigma mass matrix for axifem (V-form, FEMM-style basis). |
# | 19 | `examples/maglev/research_cln/axifem/test_element_matrices.py` | 117 | 0 | Unit tests for axifem_core element matrices. |
# | 20 | `examples/maglev/research_cln/axifem/test_p2_cpp_sphere.py` | 251 | 0 | test_p2_cpp_sphere.py — Phase B2 sphere benchmark via NGSolve. |
# | 21 | `examples/maglev/research_cln/axifem/test_p2_cpp_vs_python.py` | 109 | 0 | test_p2_cpp_vs_python.py — Phase B2 build smoke test. |
# | 22 | `examples/maglev/research_cln/axifem/test_p2_curved_sphere.py` | 155 | 0 | Curved-P2 sphere benchmark: OCC sphere half (axisym half-disk in (r,z)) |
# | 23 | `examples/maglev/research_cln/axifem/test_p2_curved_sphere_pec.py` | 127 | 0 | Curved P2 sphere PEC benchmark. |
# | 24 | `examples/maglev/research_cln/axifem/test_p2_disk_convergence.py` | 251 | 0 | test_p2_disk_convergence.py — Phase B1b Item 2 |
# | 25 | `examples/maglev/research_cln/axifem/test_p2_disk_cpp.py` | 135 | 0 | test_p2_disk_cpp.py — C++ P2 disk benchmark (no air, no Schur). |
# | 26 | `examples/maglev/research_cln/axifem/test_p2_kelvin_sphere.py` | 231 | 0 | Phase B3 axifem + Kelvin transformation sphere benchmark. |
# | 27 | `examples/maglev/research_cln/axifem/test_p2_single_element.py` | 144 | 0 | test_p2_single_element.py — Phase B1b Item 1 |
# | 28 | `examples/maglev/research_cln/axifem/test_p2_sphere_stoll.py` | 318 | 0 | test_p2_sphere_stoll.py — Phase B1b Item 3 |
# | 29 | `examples/maglev/research_cln/axifem/test_p2_two_tri_share.py` | 216 | 0 | Compare global K, M for a 2-triangle mesh sharing an edge. |
# | 30 | `examples/maglev/research_cln/axifem/test_p2_vandermonde_cond.py` | 68 | 0 | Report condition number distribution of P2 Vandermonde across sphere mesh. |
# | 31 | `examples/maglev/research_cln/axifem/test_periodic_h1henrotte.py` | 177 | 0 | Smoke test: does Periodic(H1Henrotte(...)) work? |
# | 32 | `examples/maglev/research_cln/axifem/test_q2_curved_reduction.py` | 269 | 0 | test_q2_curved_reduction.py — historical Phase B5 reduction tests. |
# | 33 | `examples/maglev/research_cln/bem_cln_ngsolve_2cuboid_v4_dirichlet.py` | 209 | 0 | bem_cln_ngsolve_2cuboid_v4_dirichlet.py |
# | 34 | `examples/maglev/research_cln/multiconn_loop_method/include/HtoOmega.py` | 27 | 0 |  |
# | 35 | `examples/maglev/research_cln/multiconn_loop_method/include/LoopField.py` | 147 | 0 |  |
# | 36 | `examples/maglev/research_cln/multiconn_loop_method/include/MatrixSolver.py` | 398 | 0 |  |
# | 37 | `examples/maglev/research_cln/ngsolve_validation/A1_AC_sweep.py` | 211 | 0 | A1_AC_sweep.py — Direct NGSolve eddy-current AC sweep on A1 cuboid. |
# | 38 | `examples/maglev/research_cln/ngsolve_validation/axifem_disk_kameari_v2.py` | 242 | 0 | axifem_disk_kameari_v2.py — axifem cylinder Cauer-I in Kameari convention. |
# | 39 | `examples/maglev/research_cln/ngsolve_validation/axifem_sphere_kameari.py` | 422 | 0 | axifem_sphere_kameari.py — axifem Cu sphere Cauer-I in Kameari convention. |
# | 40 | `examples/maglev/research_cln/ngsolve_validation/bem_foster_alpha2.py` | 155 | 0 | BEM-Foster Phase 2: alpha_2 validation on Cartesian hex grid (Python). |
# | 41 | `examples/maglev/research_cln/ngsolve_validation/bem_foster_cauer.py` | 348 | 0 | BEM-Foster Phase 4: CLN-I (s=0) ladder extraction. |
# | 42 | `examples/maglev/research_cln/ngsolve_validation/bem_foster_convergence.py` | 202 | 0 | BEM-Foster mesh convergence study. |
# | 43 | `examples/maglev/research_cln/ngsolve_validation/bem_foster_freq_response.py` | 333 | 1 | BEM-Foster Phase 5: frequency response comparison. |
# | 44 | `examples/maglev/research_cln/ngsolve_validation/bem_foster_phase3.py` | 211 | 0 | BEM-Foster Phase 3: full Foster eigendecomposition (Python). |
# | 45 | `examples/maglev/research_cln/ngsolve_validation/bem_foster_phase6_mesh.py` | 257 | 0 | BEM-Foster Phase 6: mesh refinement effect on Cauer & freq response. |
# | 46 | `examples/maglev/research_cln/ngsolve_validation/bem_foster_spectral_v5.py` | 353 | 0 | Spectral BEM v5 — Python production version (mpmath dps=50). |
# | 47 | `examples/maglev/research_cln/ngsolve_validation/bem_foster_spectral_v6_hybrid.py` | 215 | 0 | Spectral BEM v6 — Hybrid Mathematica + Python (mpmath dps=50). |
# | 48 | `examples/maglev/research_cln/ngsolve_validation/bem_to_kameari_cauer.py` | 273 | 0 | bem_to_kameari_cauer.py — Convert BEM-Foster spectrum to Kameari Cauer-I. |
# | 49 | `examples/maglev/research_cln/ngsolve_validation/cauer_depth_test.py` | 189 | 0 | Cauer depth test using v6 hybrid 18-digit alpha_n. |
# | 50 | `examples/maglev/research_cln/ngsolve_validation/cln_team28_axisym.py` | 225 | 0 | cln_team28_axisym.py — COMSOL TEAM 28 CLN algorithm in axisymmetric NGSolve. |
# | 51 | `examples/maglev/research_cln/ngsolve_validation/cln_team28_axisym_kelvin.py` | 360 | 0 | cln_team28_axisym_kelvin.py — COMSOL TEAM 28 CLN with Kelvin two-half-disc |
# | 52 | `examples/maglev/research_cln/ngsolve_validation/cln_team28_kelvin.py` | 490 | 0 | cln_team28_kelvin.py — Sugahara TEAM 28 axisymmetric CLN ported to |
# | 53 | `examples/maglev/research_cln/ngsolve_validation/cross_val_4way_cylinder.py` | 227 | 0 | 4-way Cauer ladder cross-validation, Cu disk cylinder R=10mm t=2mm. |
# | 54 | `examples/maglev/research_cln/ngsolve_validation/cuboid521_order4_compare.py` | 122 | 0 | cuboid521_order4_compare.py — Compare BEM order=3 vs order=4 + NGSolve high-mesh + ELF |
# | 55 | `examples/maglev/research_cln/ngsolve_validation/cuboid521_RL_compare.py` | 198 | 0 | cuboid521_RL_compare.py — Compare R_2n, L_{2n+1}, tau_pair across methods |
# | 56 | `examples/maglev/research_cln/ngsolve_validation/cuboid_521_3dir_eigsh.py` | 198 | 0 | 5x2x1 mm Cu cuboid - 3-direction Foster via scipy eigsh shift-invert. |
# | 57 | `examples/maglev/research_cln/ngsolve_validation/cuboid_521_3dir_foster.py` | 232 | 0 | 5x2x1 mm Cu cuboid - 3-direction independent Foster (B_x, B_y, B_z). |
# | 58 | `examples/maglev/research_cln/ngsolve_validation/cuboid_521_3dir_full_foster.py` | 288 | 0 | 5x2x1 mm Cu cuboid - full Foster series per direction (25-30 modes each). |
# | 59 | `examples/maglev/research_cln/ngsolve_validation/cuboid_521_Bz_convergence.py` | 203 | 0 | 5x2x1 mm Cu cuboid - B_z mesh convergence study (verification finalization). |
# | 60 | `examples/maglev/research_cln/ngsolve_validation/cuboid_521_gauge_CLN_v4_ebecg.py` | 240 | 0 | 5x2x1 mm Cu cuboid CLN — v4: EBE+CG instead of direct sparse Cholesky. |
# | 61 | `examples/maglev/research_cln/ngsolve_validation/cuboid_521_kameari_breakdown_v2.py` | 217 | 1 | Robust sudden-breakdown hunt: project J_cf and Apot to GridFunction |
# | 62 | `examples/maglev/research_cln/ngsolve_validation/cuboid_521_kameari_kelvin.py` | 233 | 1 | Kameari iteration on cuboid 5x2x1 vacuum problem, |
# | 63 | `examples/maglev/research_cln/ngsolve_validation/cuboid_521_kameari_kelvin_v15_canonical.py` | 329 | 1 | Kameari + Kelvin v15: HCurl Kameari iteration breakdown demo (2026-05-05). |
# | 64 | `examples/maglev/research_cln/ngsolve_validation/cuboid_521_kameari_kelvin_v21_T_formulation.py` | 598 | 1 | Kameari + Kelvin v21: T-formulation source projection (2026-05-05). |
# | 65 | `examples/maglev/research_cln/ngsolve_validation/cuboid_521_kameari_kelvin_v22h_correct_B2.py` | 402 | 1 | Kameari + Kelvin v22: Axisymmetric Cu disk Kameari-CLN proof of concept (2026-05-05). |
# | 66 | `examples/maglev/research_cln/ngsolve_validation/cuboid_521_kameari_kelvin_v9_AT.py` | 288 | 1 | Kameari + Kelvin v9: Tanimoto A-T formulation adapted for radiation BC. |
# | 67 | `examples/maglev/research_cln/ngsolve_validation/cuboid_521_kameari_order3_diagnose.py` | 222 | 0 | Diagnose why my order=3 Kameari shows drift jumping to 1e-5 at stage 2. |
# | 68 | `examples/maglev/research_cln/ngsolve_validation/cuboid_521_kameari_orthogonality_PEC.py` | 257 | 1 | Where does Schmidt orthogonality break in 3D Kameari? |
# | 69 | `examples/maglev/research_cln/ngsolve_validation/cuboid_521_kameari_sudden_breakdown.py` | 226 | 1 | Find the SUDDEN breakdown stage of 3D Kameari (closed PEC). |
# | 70 | `examples/maglev/research_cln/ngsolve_validation/cuboid_521_kameari_vacuum_v2.py` | 242 | 1 | 3D Kameari iteration on the VACUUM problem (uniform applied B_z, A-method). |
# | 71 | `examples/maglev/research_cln/ngsolve_validation/cuboid_521_kameari_vs_freqsweep_PEC.py` | 306 | 1 | ISOLATION TEST: Is Kameari iteration itself healthy in 3D? |
# | 72 | `examples/maglev/research_cln/ngsolve_validation/cuboid_521_mpmath_RnLn.py` | 259 | 0 | mpmath Cauer-I extraction of R_n, L_n for cuboid 5x2x1 vacuum problem. |
# | 73 | `examples/maglev/research_cln/ngsolve_validation/cuboid_521_mpmath_RnLn_v2.py` | 169 | 1 | mpmath Cauer-II extraction R_n, L_n for cuboid 5x2x1 vacuum. |
# | 74 | `examples/maglev/research_cln/ngsolve_validation/cuboid_521_NG_minus_mimp_foster.py` | 142 | 1 | Subtract impressed contribution m_imp from NG freq sweep data, |
# | 75 | `examples/maglev/research_cln/ngsolve_validation/cuboid_521_PINVIT_caseA.py` | 324 | 0 | 5x2x1 mm Cu cuboid CLN — PINVIT eigenvalue extraction (Case A). |
# | 76 | `examples/maglev/research_cln/ngsolve_validation/cuboid_521_step0a_airbox_no_kelvin.py` | 234 | 0 | Step 0a: A-formulation Kameari Cauer ladder for cuboid 5x2x1 + uniform B_z, |
# | 77 | `examples/maglev/research_cln/ngsolve_validation/cuboid_521_step0a_v2_HH_corrected.py` | 242 | 0 | Step 0a v2: A-formulation Kameari Cauer ladder with Tanimoto-canonical |
# | 78 | `examples/maglev/research_cln/ngsolve_validation/cuboid_521_step0a_v3_Bsquared.py` | 228 | 0 | Step 0a v3: A-form Kameari with Tanimoto canonical L = Integrate(B^2/mu dx) |
# | 79 | `examples/maglev/research_cln/ngsolve_validation/cuboid_521_vacuum_caseB.py` | 259 | 0 | 3D cuboid in VACUUM with uniform applied B_z — true infinite domain problem. |
# | 80 | `examples/maglev/research_cln/ngsolve_validation/cuboid_521_vacuum_chi_sweep.py` | 206 | 0 | 3D cuboid in vacuum, frequency sweep of chi(s) for Stage 4 (beta') validation. |
# | 81 | `examples/maglev/research_cln/ngsolve_validation/cuboid_521_vacuum_freq_sweep_complex.py` | 273 | 0 | NGSolve complex frequency sweep on cuboid 5x2x1 vacuum (air-box AIR_SCALE=5). |
# | 82 | `examples/maglev/research_cln/ngsolve_validation/cuboid_521_vacuum_kameari_airscale_sweep.py` | 147 | 1 | Air-box scale dependence of Kameari Stage 0 tau. |
# | 83 | `examples/maglev/research_cln/ngsolve_validation/cuboid_521_vacuum_kameari_breakdown.py` | 315 | 1 | Kameari iteration breakdown analysis on cuboid 5x2x1 vacuum problem. |
# | 84 | `examples/maglev/research_cln/ngsolve_validation/cuboid_thin_Bz_convergence.py` | 229 | 0 | z-thin cuboid Bz convergence study: 5x2xc Cu, c sweep, B_z only. |
# | 85 | `examples/maglev/research_cln/ngsolve_validation/cuboid_vacuum_coupled_PINVIT.py` | 190 | 0 | 5x2x1 mm Cu cuboid IN VACUUM - full FEM eigenvalue (CASE_VAC). |
# | 86 | `examples/maglev/research_cln/ngsolve_validation/cuboid_vacuum_eigsh.py` | 170 | 0 | 5x2x1 mm Cu cuboid IN VACUUM - scipy eigsh with shift-invert. |
# | 87 | `examples/maglev/research_cln/ngsolve_validation/cylinder_vim_axisym.py` | 245 | 0 | cylinder_vim_axisym.py — Axisymmetric Volume Integral Method for Cu disk. |
# | 88 | `examples/maglev/research_cln/ngsolve_validation/cylinder_vim_axisym_cupy.py` | 239 | 0 | cylinder_vim_axisym_cupy.py — GPU-accelerated axisym VIM for Cu disk. |
# | 89 | `examples/maglev/research_cln/ngsolve_validation/cylinder_vim_axisym_linear.py` | 273 | 0 | cylinder_vim_axisym_linear.py — Cylinder axisym VIM with LINEAR (bilinear) J_phi basis. |
# | 90 | `examples/maglev/research_cln/ngsolve_validation/cylinder_vim_axisym_q1_selfsub_gpu.py` | 513 | 1 | cylinder_vim_axisym_q1_selfsub_gpu.py — Cu disk Q1 linear VIM + self-cell |
# | 91 | `examples/maglev/research_cln/ngsolve_validation/dd_arithmetic.py` | 265 | 0 | dd_arithmetic.py — Double-double (DD) arithmetic primitives in NumPy/CuPy. |
# | 92 | `examples/maglev/research_cln/ngsolve_validation/dd_axisym_kernel.py` | 113 | 0 | dd_axisym_kernel.py — DD axisymmetric Green's function evaluation. |
# | 93 | `examples/maglev/research_cln/ngsolve_validation/dd_basis.py` | 226 | 0 | dd_basis.py — Double-double evaluation of HDiv div-free hex basis. |
# | 94 | `examples/maglev/research_cln/ngsolve_validation/dd_cylinder_axisym.py` | 275 | 0 | dd_cylinder_axisym.py — DD axisymmetric VIM for Cu cylinder. |
# | 95 | `examples/maglev/research_cln/ngsolve_validation/dd_cylinder_axisym_mp.py` | 317 | 0 | dd_cylinder_axisym_mp.py — DD axisym VIM cylinder, multiprocessing K assembly. |
# | 96 | `examples/maglev/research_cln/ngsolve_validation/dd_full_pipeline.py` | 267 | 0 | dd_full_pipeline.py — Phase 3: full DD K, M, b → mpmath eigh → Cauer. |
# | 97 | `examples/maglev/research_cln/ngsolve_validation/dd_gl_nodes.py` | 93 | 0 | dd_gl_nodes.py — High-precision Gauss-Legendre nodes/weights for DD pipeline. |
# | 98 | `examples/maglev/research_cln/ngsolve_validation/dd_k_assembly.py` | 346 | 0 | dd_k_assembly.py — Vectorized GPU DD K matrix assembly for hex VIM. |
# | 99 | `examples/maglev/research_cln/ngsolve_validation/dd_k_assembly_gpu.py` | 245 | 0 | dd_k_assembly_gpu.py — GPU-vectorized DD K matrix assembly. |
# | 100 | `examples/maglev/research_cln/ngsolve_validation/dd_k_entry_proof.py` | 280 | 0 | dd_k_entry_proof.py — Proof-of-concept DD computation of single K[i,j] entry. |
# | 101 | `examples/maglev/research_cln/ngsolve_validation/dd_legendre.py` | 208 | 0 | dd_legendre.py — Double-double Legendre polynomials for HDiv basis evaluation. |
# | 102 | `examples/maglev/research_cln/ngsolve_validation/dd_M_b_assembly.py` | 290 | 0 | dd_M_b_assembly.py — DD mass matrix M and excitation vector b for hex VIM. |
# | 103 | `examples/maglev/research_cln/ngsolve_validation/dd_production_A1.py` | 183 | 0 | dd_production_A1.py — DD Cauer extraction for A1 square prism (17.72×17.72×2 mm). |
# | 104 | `examples/maglev/research_cln/ngsolve_validation/dd_production_cuboid521.py` | 211 | 0 | dd_production_cuboid521.py — Production DD Cauer extraction for cuboid 5×2×1. |
# | 105 | `examples/maglev/research_cln/ngsolve_validation/dd_sphere_axisym.py` | 257 | 0 | dd_sphere_axisym.py — DD axisymmetric VIM for Cu sphere. |
# | 106 | `examples/maglev/research_cln/ngsolve_validation/dd_sphere_axisym_mp.py` | 338 | 0 | dd_sphere_axisym_mp.py — DD axisym VIM sphere, multiprocessing K assembly. |
# | 107 | `examples/maglev/research_cln/ngsolve_validation/dd_spherical_duffy.py` | 246 | 0 | dd_spherical_duffy.py — Double-double Spherical Duffy K matrix assembly. |
# | 108 | `examples/maglev/research_cln/ngsolve_validation/disk_bem_cauer.py` | 194 | 0 | disk_bem_cauer.py -- Cauer-I CFE from BEM Foster moments, Nagamine pipeline. |
# | 109 | `examples/maglev/research_cln/ngsolve_validation/disk_bem_cauer_highprec.py` | 134 | 0 | disk_bem_cauer_highprec.py -- Cauer-I CFE on the high-precision BEM moments. |
# | 110 | `examples/maglev/research_cln/ngsolve_validation/foster_cln_hex.py` | 149 | 0 | Foster-CLN library for arbitrary 8-node hexahedron (Phase 12). |
# | 111 | `examples/maglev/research_cln/ngsolve_validation/foster_cln_hex_banerjee_gupta.py` | 144 | 0 | Phase 12.2: Banerjee-Gupta (1977) closed form for cuboid Newton potential. |
# | 112 | `examples/maglev/research_cln/ngsolve_validation/foster_cln_hex_mesh.py` | 231 | 0 | Phase 12.3: Multi-hex BEM K matrix + Foster eigenvalues. |
# | 113 | `examples/maglev/research_cln/ngsolve_validation/foster_cln_hex_tet.py` | 363 | 0 | Phase 12.2b: Arbitrary 8-node hex Newton potential via tetrahedral decomposition. |
# | 114 | `examples/maglev/research_cln/ngsolve_validation/foster_cln_hex_v2.py` | 189 | 0 | Phase 12.1: Arbitrary 8-node hexahedron CLN-type BEM element. |
# | 115 | `examples/maglev/research_cln/ngsolve_validation/foster_cln_python_pure.py` | 293 | 0 | Python pure Foster-CLN library (no Mathematica dependency). |
# | 116 | `examples/maglev/research_cln/ngsolve_validation/foster_cln_python_pure_p6.py` | 293 | 0 | Python pure Foster-CLN library (no Mathematica dependency). |
# | 117 | `examples/maglev/research_cln/ngsolve_validation/interior_PEC_eig_diagnostic.py` | 167 | 0 | interior_PEC_eig_diagnostic.py — Direct eigenvalue computation for |
# | 118 | `examples/maglev/research_cln/ngsolve_validation/kameari_axisym_dg_p2.py` | 213 | 0 | kameari_axisym_dg_p2.py — Kameari accumulation in P2 DG (FreeFEM P2DC analog). |
# | 119 | `examples/maglev/research_cln/ngsolve_validation/kameari_mesh_sweep.py` | 159 | 0 | kameari_mesh_sweep.py — Mesh refinement sweep for Kameari + air-box axisym. |
# | 120 | `examples/maglev/research_cln/ngsolve_validation/legacy_fp64/hex_vim_cauer_interval.py` | 218 | 0 | hex_vim_cauer_interval.py — Verified-interval Cauer-I extraction (Nagamine手法). |
# | 121 | `examples/maglev/research_cln/ngsolve_validation/legacy_fp64/hex_vim_cupy.py` | 267 | 0 | hex_vim_cupy.py — GPU-accelerated K matrix assembly for radia-vim hex VIM. |
# | 122 | `examples/maglev/research_cln/ngsolve_validation/legacy_fp64/hex_vim_cupy_kassembly.py` | 332 | 0 | hex_vim_cupy_kassembly.py — GPU K matrix assembly via Spherical Duffy. |
# | 123 | `examples/maglev/research_cln/ngsolve_validation/legacy_fp64/hex_vim_gpu_order_sweep.py` | 293 | 0 | hex_vim_gpu_order_sweep.py — GPU K assembly + Foster + Cauer |
# | 124 | `examples/maglev/research_cln/ngsolve_validation/legacy_fp64/hex_vim_hiruma_arnoldi.py` | 252 | 0 | hex_vim_hiruma_arnoldi.py — Hiruma 3-term Lanczos + Arnoldi reorthogonalization |
# | 125 | `examples/maglev/research_cln/ngsolve_validation/legacy_fp64/hex_vim_kameari_from_foster.py` | 91 | 0 | hex_vim_kameari_from_foster.py — apply Kameari Hankel-Padé to a Foster |
# | 126 | `examples/maglev/research_cln/ngsolve_validation/legacy_fp64/hex_vim_lanczos_arnoldi.py` | 296 | 0 | hex_vim_lanczos_arnoldi.py — VIM-native Lanczos+Arnoldi Cauer extraction. |
# | 127 | `examples/maglev/research_cln/ngsolve_validation/legacy_fp64/hex_vim_modified_chebyshev.py` | 325 | 0 | hex_vim_modified_chebyshev.py — Gautschi's Modified Chebyshev algorithm |
# | 128 | `examples/maglev/research_cln/ngsolve_validation/legacy_fp64/hex_vim_stieltjes_cauer.py` | 230 | 0 | hex_vim_stieltjes_cauer.py — VIM-native Cauer extraction via Stieltjes |
# | 129 | `examples/maglev/research_cln/ngsolve_validation/mcp_hcurl_bem_server.py` | 313 | 0 | MCP server exposing HCurl BEM + closed-form Newton potential tools. |
# | 130 | `examples/maglev/research_cln/ngsolve_validation/mcp_kameari_kelvin_server.py` | 460 | 0 | MCP server: Hiruma 3-term Cauer Ladder Network with Kelvin truncation. |
# | 131 | `examples/maglev/research_cln/ngsolve_validation/plot_RL_comparison.py` | 103 | 0 | Compare R_n, L_n between NGSolve Kameari (tree-cotree+GS) and Mathematica Cauer-I. |
# | 132 | `examples/maglev/research_cln/ngsolve_validation/rect_2D_caseB_kameari.py` | 199 | 0 | 2D rect Case B (uniform H_0 applied) — INDEPENDENT NGSolve implementation. |
# | 133 | `examples/maglev/research_cln/ngsolve_validation/rect_2D_caseB_via_duality.py` | 228 | 0 | 2D rect Case B (uniform H_0 applied) via DUALITY from Case A. |
# | 134 | `examples/maglev/research_cln/ngsolve_validation/rect_2D_kameari.py` | 137 | 0 | 2D rectangular bar (a x b) — Kameari CLN extraction (Tanimoto pattern). |
# | 135 | `examples/maglev/research_cln/ngsolve_validation/rect_2D_kameari_explicit_tree.py` | 155 | 0 | 2D Kameari with EXPLICIT tree-cotree-style gauge masking on H1. |
# | 136 | `examples/maglev/research_cln/ngsolve_validation/rect_2D_kameari_treecotree.py` | 190 | 0 | 2D rectangular bar via 3D thin slab + HCurl + tree-cotree gauge. |
# | 137 | `examples/maglev/research_cln/ngsolve_validation/render_mesh_png.py` | 90 | 0 | Render the cuboid mesh as a PNG using a standalone GMSH executable. |
# | 138 | `examples/maglev/research_cln/ngsolve_validation/save_mesh_and_view.py` | 53 | 0 | Generate the cuboid mesh used in tree-cotree validation, save as .vol and .msh, |
# | 139 | `examples/maglev/research_cln/ngsolve_validation/sphere_axisym_kelvin.py` | 349 | 0 | sphere_axisym_kelvin.py — Sphere in uniform B_z field, axisymmetric NGSolve. |
# | 140 | `examples/maglev/research_cln/ngsolve_validation/sphere_vim_axisym.py` | 256 | 0 | sphere_vim_axisym.py — Axisymmetric VIM for Cu sphere. |
# | 141 | `examples/maglev/research_cln/ngsolve_validation/sphere_vim_axisym_cupy.py` | 322 | 0 | sphere_vim_axisym_cupy.py — GPU-accelerated axisym VIM for Cu sphere. |
# | 142 | `examples/maglev/research_cln/ngsolve_validation/sphere_vim_axisym_foster_modes.py` | 109 | 1 | sphere_vim_axisym_foster_modes.py — Extract top Foster (τ_n, g_n²) |
# | 143 | `examples/maglev/research_cln/ngsolve_validation/sphere_vim_axisym_ir.py` | 245 | 0 | sphere_vim_axisym_ir.py — Sphere VIM Foster moments via direct |
# | 144 | `examples/maglev/research_cln/ngsolve_validation/sphere_vim_axisym_linear.py` | 346 | 0 | sphere_vim_axisym_linear.py — Sphere axisym VIM with LINEAR (bilinear) J_phi basis. |
# | 145 | `examples/maglev/research_cln/ngsolve_validation/sphere_vim_axisym_linear_gpu.py` | 443 | 0 | sphere_vim_axisym_linear_gpu.py — GPU-native linear-basis sphere VIM. |
# | 146 | `examples/maglev/research_cln/ngsolve_validation/sphere_vim_axisym_linear_gpu_v3.py` | 375 | 1 | sphere_vim_axisym_linear_gpu_v3.py — GPU linear VIM v3. |
# | 147 | `examples/maglev/research_cln/ngsolve_validation/sphere_vim_axisym_linear_scaling.py` | 225 | 1 | sphere_vim_axisym_linear_scaling.py — Push linear-basis sphere VIM |
# | 148 | `examples/maglev/research_cln/ngsolve_validation/sphere_vim_axisym_q1_selfsub_gpu.py` | 516 | 1 | sphere_vim_axisym_q1_selfsub_gpu.py — Q1 linear sphere VIM with self-cell |
# | 149 | `examples/maglev/research_cln/ngsolve_validation/sphere_vim_axisym_q2_gpu.py` | 430 | 1 | sphere_vim_axisym_q2_gpu.py — Biquadratic Q2 basis sphere VIM on GPU. |
# | 150 | `examples/maglev/research_cln/ngsolve_validation/sphere_vim_axisym_quadsweep.py` | 216 | 0 | sphere_vim_axisym_quadsweep.py — Probe quadrature-order sensitivity. |
# | 151 | `examples/maglev/research_cln/ngsolve_validation/sphere_vim_axisym_RL_extract.py` | 115 | 0 | sphere_vim_axisym_RL_extract.py — One-shot extraction of full Cauer R, L |
# | 152 | `examples/maglev/research_cln/ngsolve_validation/sphere_vim_axisym_subdiv.py` | 292 | 0 | sphere_vim_axisym_subdiv.py — Self-cell subdivision for VIM K_ii. |
# | 153 | `examples/maglev/research_cln/ngsolve_validation/sphere_vim_axisym_subdiv_meshsweep.py` | 191 | 1 | sphere_vim_axisym_subdiv_meshsweep.py — Mesh-convergence study with |
# | 154 | `examples/maglev/research_cln/ngsolve_validation/sphere_vim_axisym_sweep.py` | 220 | 1 | sphere_vim_axisym_sweep.py — Mesh-convergence sweep of axisym sphere VIM. |
# | 155 | `examples/maglev/research_cln/ngsolve_validation/tanimoto_AT_geom_sweep.py` | 362 | 0 | tanimoto_AT_geom_sweep.py -- Tanimoto A-T alternating Poisson CLN |
# | 156 | `examples/maglev/research_cln/ngsolve_validation/tanimoto_AT_kelvin.py` | 425 | 0 | tanimoto_AT_kelvin.py — Tanimoto A-T with Kelvin two-sphere domain. |
# | 157 | `examples/maglev/research_cln/ngsolve_validation/v24_interior_pec_disk_analytical_check.py` | 192 | 0 | v24: Interior-PEC disk verification of Hiruma analytical formulas. |
# | 158 | `examples/maglev/rotating_magnet_eddy.py` | 279 | 0 | rotating_magnet_eddy.py -- moving-magnet eddy current: when is a per-step |
# | 159 | `examples/maglev/sphere/coil_maglev_equilibrium.py` | 377 | 0 | coil_maglev_equilibrium.py -- AC magnetic levitation equilibrium of a |
# | 160 | `examples/maglev/sphere/coil_sphere_eddy_force.py` | 492 | 0 | coil_sphere_eddy_force.py -- quantify the POINT-DIPOLE approximation error |
# | 161 | `examples/maglev/sphere/maglev_sphere_force.py` | 230 | 0 | maglev_sphere_force.py -- induced-dipole AC levitation force on a |
# | 162 | `examples/maglev/sphere/maxwell_surface_force_xcheck.py` | 155 | 0 | End-to-end validation of the Maxwell-SURFACE-STRESS force -- the methodology |
# | 163 | `examples/maglev/team28/team28_axisym_fem.py` | 127 | 0 | team28_axisym_fem.py -- repo-clean port of the lab TEAM 28 axisymmetric |
# | 164 | `examples/maglev/team28/team28_cln_force.py` | 167 | 0 | team28_cln_force.py -- CLN-reduced TEAM 28 levitation force (coil-driven). |
# | 165 | `examples/maglev/team28/team28_cln_sweep.py` | 101 | 0 | team28_cln_sweep.py -- CLN-reduced TEAM 28 levitation force vs height. |
# | 166 | `examples/maglev/team28/team28_cln_sweep_full.py` | 155 | 0 | team28_cln_sweep_full.py -- full 25-point TEAM 28 CLN force-vs-height |

# %% [markdown]
# ## Integrity Checks

# %%
assert counts['python_scripts'] == len(data['records'])
assert all(len(rec['sha256']) == 64 for rec in data['records'])
assert all(rec.get('source') for rec in data['records'])
print('archive integrity: ok')
# Out:
# archive integrity: ok

# %% [markdown]
# ## Result Payloads and Media

# %%
rows = data.get('topic_json_files', [])
if rows:
    header = '| # | json | sha256 | keys |\n|---:|---|---|---|'
    body = []
    for i, row in enumerate(rows, 1):
        payload = row.get('payload')
        keys = ', '.join(list(payload.keys())[:8]) if isinstance(payload, dict) else type(payload).__name__
        body.append(f"| {i} | `{row['path']}` | `{row['sha256'][:12]}` | {keys.replace('|', '\\|')} |")
    display(Markdown('\n'.join([header] + body)))
else:
    print('no existing JSON payloads found')

media = data.get('media_files', [])
print(f"media artifacts indexed: {len(media)}")
# Out:
# | # | json | sha256 | keys |
# |---:|---|---|---|
# | 1 | `examples/maglev/cube_alpha_sweep_results.json` | `01fa2855de25` | f_hz, re_alpha_over_V, im_alpha_over_V, a_over_delta, params, meta |
# | 2 | `examples/maglev/cube_alpha_tensor_results.json` | `82a2b40a5dd9` | geometry, L_m, sigma, mu, V_m3, S_m2, n_foster, ports |
# | 3 | `examples/maglev/cuboid_vector_bulk_results.json` | `5d251194c3d0` | geometry, sigma, mu, dims_m, analytic_tau_te_us, runs, scope_note |
# | 4 | `examples/maglev/ellipsoid/ellipsoid_alpha_omega_axisym_results.json` | `b5c56a344cb1` | sigma, a_eq_m, B0, sphere_validation_worst_relerr, hf_anchor, freqs_Hz, alpha_c_re_m3, alpha_c_im_m3 |
# | 5 | `examples/maglev/ellipsoid/ellipsoid_alpha_tensor_3d_results.json` | `4cbc1cadf49e` | status, solver, key_fix, sigma, order, sphere_worst_relerr, sphere_isotropy_worst, triaxial_semi_m |
# | 6 | `examples/maglev/ellipsoid/ellipsoid_alpha_tensor_results.json` | `1761cfeb58d5` | note, triaxial_semi_axes_m, demag_N, kappa_hf_m3, anisotropy_kappaz_over_kappax, lift_factor_inv_1_minus_N, cases_demag |
# | 7 | `examples/maglev/physical_tensor_rom_fem.json` | `8b85a4eaaada` | geometry, semi_m, sigma, ne, V_m3, N_demag, freqs_Hz, alpha_re_m3 |
# | 8 | `examples/maglev/physical_tensor_rom_sphere.json` | `d503b298d7a4` | mode, geometry, sigma, rom, analytic_stoll_tau_us, mimo_n_states, scope_note |
# | 9 | `examples/maglev/research_cln/axifem/quad_q2_henrotte_matrices.json` | `523bfd454e56` | monomials_general, monomials_axis, node_order_general, node_order_axis, K_phi_general_strings, M_sigma_phi_general_strings, K_phi_axis_strings, M_sigma_phi_axis_strings |
# | 10 | `examples/maglev/research_cln/axifem/quad_q2_henrotte_matrices_test.json` | `e5478a797388` | K_phi_general_test_flat, M_sigma_phi_general_test_flat, K_phi_axis_test_flat, M_sigma_phi_axis_test_flat |
# | 11 | `examples/maglev/research_cln/ngsolve_validation/2026-05-09-tanimoto_AT_conv_cub_p2_h015_results.json` | `c04c9a9acc47` | method, geometry, geom_params, params, Rn, Ln, stages |
# | 12 | `examples/maglev/research_cln/ngsolve_validation/2026-05-09-tanimoto_AT_conv_cyl_p2_h050_6stage_results.json` | `e80e81fa5134` | method, geometry, geom_params, params, Rn, Ln, stages |
# | 13 | `examples/maglev/research_cln/ngsolve_validation/2026-05-09-tanimoto_AT_conv_cyl_p2_h050_results.json` | `96f9a1e57a27` | method, geometry, geom_params, params, Rn, Ln, stages |
# | 14 | `examples/maglev/research_cln/ngsolve_validation/2026-05-09-tanimoto_AT_conv_cyl_p3_h100_6stage_results.json` | `bd1f3e9fbdb9` | method, geometry, geom_params, params, Rn, Ln, stages |
# | 15 | `examples/maglev/research_cln/ngsolve_validation/2026-05-09-tanimoto_AT_conv_cyl_p3_h100_results.json` | `07f32f121008` | method, geometry, geom_params, params, Rn, Ln, stages |
# | 16 | `examples/maglev/research_cln/ngsolve_validation/2026-05-09_paper_validation_table.json` | `f13f43674683` | study, date, session, summary, geometries, material, leading_tau_us_validation, Tanimoto_convergence_study_2026_05_09 |
# | 17 | `examples/maglev/research_cln/ngsolve_validation/2026-05-10-tanimoto_AT_cyl_kelvin_COMSOL_results.json` | `be62fd5bf3c1` | method, geometry, params, Rn, Ln, stages |
# | 18 | `examples/maglev/research_cln/ngsolve_validation/A1_AC_sweep_p3_h05_v3_dirichlet_results.json` | `4d2bbedbe1e6` | method, geometry_mm, params, A_ext_norm2_L2, results |
# | 19 | `examples/maglev/research_cln/ngsolve_validation/axifem_disk_kameari_v2_results.json` | `a73bcc528c85` | medium, fine |
# | 20 | `examples/maglev/research_cln/ngsolve_validation/axifem_sphere_kameari_results.json` | `1aeca6c4df8c` | medium |
# | 21 | `examples/maglev/research_cln/ngsolve_validation/bem_disk_axisym_cauer.json` | `335a0ee3f3b6` | method, params, bem_tau_us, bem_eigvals_lambda, foster_amplitudes_g, alphas, element_r, element_z |
# | 22 | `examples/maglev/research_cln/ngsolve_validation/bem_disk_axisym_cauer_highprec.json` | `df87656ba53c` | method, params, bem_tau_us, bem_eigvals_lambda, foster_amplitudes_g, alphas, element_r, element_z |
# | 23 | `examples/maglev/research_cln/ngsolve_validation/bem_disk_axisym_cauer_highprec_python_results.json` | `daf934c689ad` | method, n_moments, n_pairs, first_negative_k, p_cauer, R_2k, L_2k_plus_1, tau_pair_us |
# | 24 | `examples/maglev/research_cln/ngsolve_validation/bem_disk_axisym_cauer_python_results.json` | `658e0fecc004` | method, reference, n_moments, n_pairs, naming_convention, p_cauer, R_2k, L_2k_plus_1 |
# | 25 | `examples/maglev/research_cln/ngsolve_validation/bem_disk_axisym_foster.json` | `dbdd7e86f2fa` | method, params, tau_us, v22b_tau_B2_us_for_compare |
# | 26 | `examples/maglev/research_cln/ngsolve_validation/bem_foster_alpha2_results.json` | `1af6878f4c08` | alpha2Closed, results |
# | 27 | `examples/maglev/research_cln/ngsolve_validation/bem_foster_alpha2_results_py.json` | `a0c2fbe1d3af` | alpha2_closed, results |
# | 28 | `examples/maglev/research_cln/ngsolve_validation/bem_foster_cauer_results.json` | `82fc8d5d8f02` | grid, moments, p_cauer, residuals, foster_taus_top10, foster_a_top10 |
# | 29 | `examples/maglev/research_cln/ngsolve_validation/bem_foster_convergence_results.json` | `d3bc6cc05787` | alpha1_closed, alpha2_closed, alpha3_MC, tau1_closed, results |
# | 30 | `examples/maglev/research_cln/ngsolve_validation/bem_foster_freq_response.json` | `512e49e62b32` | omegas, chi_foster_re, chi_foster_im, Ks, chi_cauer_re, chi_cauer_im, chi_pade11_re, chi_pade11_im |
# | 31 | `examples/maglev/research_cln/ngsolve_validation/bem_foster_K_export_P4.json` | `061a934ae840` | P_max, WP, a, b, c, x_block, y_block |
# | 32 | `examples/maglev/research_cln/ngsolve_validation/bem_foster_phase3_results.json` | `98e9acb7f1d1` | _load_error |
# | 33 | `examples/maglev/research_cln/ngsolve_validation/bem_foster_phase3_results_py.json` | `e69244748603` | grid, taus, gx, gy, alphas, alpha1_closed, alpha2_closed, alpha3_MC |
# | 34 | `examples/maglev/research_cln/ngsolve_validation/bem_foster_phase6_mesh_results.json` | `002193eb934c` | configs, data, tau1_closed, alpha1_closed, alpha2_closed |
# | 35 | `examples/maglev/research_cln/ngsolve_validation/bem_foster_spectral_v5_python_results.json` | `94cdf26f34f5` | P_max, alpha_n, tau_1_us, alpha_2_ref, tau_1_ref_us, runtime_s, dps |
# | 36 | `examples/maglev/research_cln/ngsolve_validation/bem_foster_spectral_v6_hybrid_results.json` | `ba24218fcf39` | method, P_max, dps, alpha_n, tau_1_us, alpha_2_ref_new, tau_1_ref_us, alpha_2_err |
# | 37 | `examples/maglev/research_cln/ngsolve_validation/cuboid_521_kameari_breakdown_v2.json` | `40eb527bb862` | reference_tau_us, h_cond_mm, order, ne, stages_completed, breakdown_stage, max_tau_us, stages |
# | 38 | `examples/maglev/research_cln/ngsolve_validation/cuboid_521_kameari_kelvin.json` | `e7cbe15aedcc` | method, geometry_mm, R_K_mm, OFFSET_mm, h_cond_mm, h_air_mm, h_kelvin_mm, order |
# | 39 | `examples/maglev/research_cln/ngsolve_validation/cuboid_521_kameari_kelvin_v15_canonical.json` | `48e3f1d6b09e` | method, purpose, R_K_mm, h_cond_mm, h_air_mm, order, ne, rel_err_gfA_s_cond |
# | 40 | `examples/maglev/research_cln/ngsolve_validation/cuboid_521_kameari_kelvin_v21_T_formulation.json` | `736947c9ad2f` | method, L_n_formula, gauge_recipe, R_K_mm, h_cond_mm, h_air_mm, order, ne |
# | 41 | `examples/maglev/research_cln/ngsolve_validation/cuboid_521_kameari_kelvin_v22h_correct_B2.json` | `e1d92d5069d3` | method, geometry, params, stages, R0_anal, tau_inf_cylinder_us, sign_flip_first_n |
# | 42 | `examples/maglev/research_cln/ngsolve_validation/cuboid_521_kameari_kelvin_v9_AT.json` | `660fdda8ba35` | method, R_K_mm, h_cond_mm, h_air_mm, order, ne, stages, R0_analytic |
# | 43 | `examples/maglev/research_cln/ngsolve_validation/cuboid_521_kameari_orthogonality_PEC.json` | `ebeed6df1dd5` | reference, configurations |
# | 44 | `examples/maglev/research_cln/ngsolve_validation/cuboid_521_kameari_sudden_breakdown.json` | `625f6be2c09c` | reference_tau_us, setup, results |
# | 45 | `examples/maglev/research_cln/ngsolve_validation/cuboid_521_kameari_vacuum_v2.json` | `0979d890e88e` | reference_R0_Parseval, elf_foster_tau_lead_us, AIR_SCALE, h_cond_mm, h_air_mm, order, ne, stages_completed |
# | 46 | `examples/maglev/research_cln/ngsolve_validation/cuboid_521_kameari_vs_freqsweep_PEC.json` | `7520766de8c9` | method, h_cond_mm, order, ne, tau_TE_110_analytical_us, kameari_stages, freq_sweep_results, foster_fits |
# | 47 | `examples/maglev/research_cln/ngsolve_validation/cuboid_521_mpmath_RnLn_v2.json` | `32cc5483d106` | method, convention, M_moments_50dps, rl_pairs |
# | 48 | `examples/maglev/research_cln/ngsolve_validation/cuboid_521_NG_minus_mimp_foster.json` | `578e3c750c59` | method, AIR_SCALE, N_stages, NG_4stage, ELF_4stage, Kameari_stage0_tau_us, comparison |
# | 49 | `examples/maglev/research_cln/ngsolve_validation/cuboid_521_PINVIT_caseA_results.json` | `0ed37b0d64be` | method, geometry_mm, h_mm, order, ne, n_eigen_used, n_modes_after_filter, Y0_numerical_30modes |
# | 50 | `examples/maglev/research_cln/ngsolve_validation/cuboid_521_vacuum_caseB_results.json` | `06e638221330` | method, geometry_mm, air_scale, h_cond_mm, h_air_mm, order, ne, R0_analytic |
# | 51 | `examples/maglev/research_cln/ngsolve_validation/cuboid_521_vacuum_chi_sweep_results.json` | `ddb66fd91df4` | method, geometry_mm, R_eff_mm, alpha_LF_cub, air_scale, h_cond_mm, h_air_mm, order |
# | 52 | `examples/maglev/research_cln/ngsolve_validation/cuboid_521_vacuum_kameari_airscale_sweep.json` | `045674e86e37` | method, elf_foster_tau_lead_us, results |
# | 53 | `examples/maglev/research_cln/ngsolve_validation/cuboid_521_vacuum_kameari_breakdown.json` | `1e8cdb07974b` | method, geometry_mm, air_scale, h_cond_mm, h_air_mm, order, ne, R0_analytic |
# | 54 | `examples/maglev/research_cln/ngsolve_validation/cylinder_vim_axisym_cupy_results.json` | `d3a0e572c6c6` | 576 cells (baseline), 2304 cells (4x), 5184 cells (9x) |
# | 55 | `examples/maglev/research_cln/ngsolve_validation/cylinder_vim_axisym_linear_results.json` | `b22d796e0545` | 576 cells, n_quad=3, 2304 cells, n_quad=3 |
# | 56 | `examples/maglev/research_cln/ngsolve_validation/cylinder_vim_axisym_q1_selfsub_gpu_96x24_ns1.json` | `abfa06449493` | N_rho, N_z, n_cells, n_dofs, n_quad, n_sub, t_assemble_s, t_eigh_s |
# | 57 | `examples/maglev/research_cln/ngsolve_validation/cylinder_vim_axisym_q1_selfsub_gpu_96x24_ns2.json` | `521deec62bfc` | N_rho, N_z, n_cells, n_dofs, n_quad, n_sub, t_assemble_s, t_eigh_s |
# | 58 | `examples/maglev/research_cln/ngsolve_validation/cylinder_vim_axisym_q1_selfsub_gpu_96x24_ns4.json` | `67ae14f6117d` | N_rho, N_z, n_cells, n_dofs, n_quad, n_sub, t_assemble_s, t_eigh_s |
# | 59 | `examples/maglev/research_cln/ngsolve_validation/cylinder_vim_axisym_q1_selfsub_gpu_summary.json` | `67fc42ee2e86` | bem_foster_cauer_tau_us, results |
# | 60 | `examples/maglev/research_cln/ngsolve_validation/cylinder_vim_axisym_results.json` | `08afecbd91ef` | method, params, leading_tau_us, top_modes_by_g2, Cauer_rungs_Kameari |
# | 61 | `examples/maglev/research_cln/ngsolve_validation/dd_cylinder_axisym_Nr24_Nz6_results.json` | `1b890b64a1a1` | shape, Nr, Nz, n_quad, Cauer_rungs |
# | 62 | `examples/maglev/research_cln/ngsolve_validation/dd_production_A1_order3_results.json` | `af7a8937d4d3` | shape, p, n_dofs, quad, top_foster, Cauer_rungs_verified |
# | 63 | `examples/maglev/research_cln/ngsolve_validation/dd_production_cuboid521_order3_results.json` | `ed637e0d28d8` | shape, p, n_dofs, quad, n_q, K_assembly_s, M_b_assembly_s, DD_floor_K_lo_hi |
# | 64 | `examples/maglev/research_cln/ngsolve_validation/dd_sphere_axisym_mp_Nrho15_Nth18_nq2_results.json` | `32e5546b8971` | shape, N_rho, N_theta, n_quad, workers, eigh_dps, Cauer_rungs |
# | 65 | `examples/maglev/research_cln/ngsolve_validation/dd_sphere_axisym_mp_Nrho20_Nth27_nq2_results.json` | `0e7bc95b43ce` | shape, N_rho, N_theta, n_quad, workers, eigh_dps, Cauer_rungs |
# | 66 | `examples/maglev/research_cln/ngsolve_validation/foster_cln_python_pure_results.json` | `3753e444f778` | P_max, dps, alpha_n, alpha_0, tau_1_us, tau_1_err, p_cauer |
# | 67 | `examples/maglev/research_cln/ngsolve_validation/hex_bem_hdiv_order3_export.json` | `1ba936398852` | method, params, bem_tau_us, bem_eigvals_lambda, foster_amplitudes_g, leading_tau_us |
# | 68 | `examples/maglev/research_cln/ngsolve_validation/hex_vim_hiruma_arnoldi_cuboid521_results.json` | `e18f6bbee73c` | order, n_dofs, lanczos_plain, arnoldi, R_0 |
# | 69 | `examples/maglev/research_cln/ngsolve_validation/hex_vim_lanczos_arnoldi_cuboid521_results.json` | `7be23b9db799` | order, n_dofs, plain_lanczos, arnoldi |
# | 70 | `examples/maglev/research_cln/ngsolve_validation/mcp_server_config_example.json` | `b75880abe0da` | _comment, _paths, mcpServers |
# | 71 | `examples/maglev/research_cln/ngsolve_validation/rect_2D_caseB_kameari_results.json` | `46b1aff2942e` | method, geometry_mm, h_mm, order, ne, n_moments, M_B, R_B |
# | 72 | `examples/maglev/research_cln/ngsolve_validation/rect_2D_caseB_via_duality_results.json` | `dee90b30f4ee` | method, source, h_mm, order, ne, M_A_reconstructed, M_B_shifted, R_B |
# | 73 | `examples/maglev/research_cln/ngsolve_validation/rect_2D_kameari_explicit_tree_results.json` | `09e7d6d45355` | method, geometry_mm, h_mm, order, ne, R_DC_analytic, R, L |
# | 74 | `examples/maglev/research_cln/ngsolve_validation/rect_2D_kameari_results.json` | `92d3115eef1b` | method, geometry_mm, h_mm, order, ne, R_DC_analytic, R, L |
# | 75 | `examples/maglev/research_cln/ngsolve_validation/rect_2D_kameari_treecotree_results.json` | `0ed473cdbd12` | method, geometry_mm, h_mm, order, ne, R_DC_analytic, R_per_length, L_per_length |
# | 76 | `examples/maglev/research_cln/ngsolve_validation/rect_2D_mathematica_reference.json` | `f6319ee504bd` | method, geometry_mm, Mmax_higher_Sk, WorkingPrecision, S1_residual_truncation_M1bar, M_0_closed_form, L0_predicted_R0_squared_M1_nH_per_m, comments |
# | 77 | `examples/maglev/research_cln/ngsolve_validation/sphere_analytical_cln_highstage.json` | `ecaec4ccef49` | params, R0, n_reliable, stoll_tau_us, stoll_a_n, alpha_taylor, cauer_R, cauer_L_inv |
# | 78 | `examples/maglev/research_cln/ngsolve_validation/sphere_vim_axisym_cupy_results.json` | `40df63853999` | fine (1080 cells, baseline), extra (2430 cells), very fine (4320 cells) |
# | 79 | `examples/maglev/research_cln/ngsolve_validation/sphere_vim_axisym_foster_modes.json` | `f94daca70f2d` | stoll_tau_us, stoll_a_n, vim_results |
# | 80 | `examples/maglev/research_cln/ngsolve_validation/sphere_vim_axisym_ir_results.json` | `c2e929a67d8b` | method, n_cells, N_rho, N_theta, mp_dps, n_alphas_physical, alphas_physical_str, cauer_rungs |
# | 81 | `examples/maglev/research_cln/ngsolve_validation/sphere_vim_axisym_linear_gpu_45x54.json` | `e7848faaa39a` | N_rho, N_theta, n_cells, n_dofs, t_assemble_s, t_eigh_s, leading_tau_us, top_modes |
# | 82 | `examples/maglev/research_cln/ngsolve_validation/sphere_vim_axisym_linear_gpu_v3_45x54.json` | `cb92b09c618e` | N_rho, N_theta, n_cells, n_dofs, t_assemble_s, t_eigh_s, leading_tau_us, top_modes |
# | 83 | `examples/maglev/research_cln/ngsolve_validation/sphere_vim_axisym_linear_gpu_v3_summary.json` | `34ecd28930c8` | stoll_tau_us, stoll_cauer_tau_us, results |
# | 84 | `examples/maglev/research_cln/ngsolve_validation/sphere_vim_axisym_linear_results.json` | `05281ca0e1f7` | 1080 cells, n_quad=2, 1080 cells, n_quad=3 (exact M), 1080 cells, n_quad=4, 2430 cells, n_quad=3 |
# | 85 | `examples/maglev/research_cln/ngsolve_validation/sphere_vim_axisym_linear_scaling_45x54.json` | `a9ca5c533b2c` | N_rho, N_theta, n_cells, n_dofs, K_mem_GB, t_assemble_s, t_eigh_s, leading_tau_us |
# | 86 | `examples/maglev/research_cln/ngsolve_validation/sphere_vim_axisym_linear_scaling_60x72.json` | `476cc878fd87` | N_rho, N_theta, n_cells, n_dofs, K_mem_GB, t_assemble_s, t_eigh_s, leading_tau_us |
# | 87 | `examples/maglev/research_cln/ngsolve_validation/sphere_vim_axisym_linear_scaling_75x90.json` | `2826ad910fe4` | N_rho, N_theta, n_cells, n_dofs, K_mem_GB, t_assemble_s, t_eigh_s, leading_tau_us |
# | 88 | `examples/maglev/research_cln/ngsolve_validation/sphere_vim_axisym_linear_scaling_summary.json` | `b008dc1e7e0d` | stoll_tau_us, stoll_a_n, stoll_cauer_tau_us, results |
# | 89 | `examples/maglev/research_cln/ngsolve_validation/sphere_vim_axisym_q1_selfsub_gpu_45x54_ns1.json` | `23b2850144db` | N_rho, N_theta, n_cells, n_dofs, n_quad, n_sub, t_assemble_s, t_eigh_s |
# | 90 | `examples/maglev/research_cln/ngsolve_validation/sphere_vim_axisym_q1_selfsub_gpu_45x54_ns2.json` | `4c14ce5fb0eb` | N_rho, N_theta, n_cells, n_dofs, n_quad, n_sub, t_assemble_s, t_eigh_s |
# | 91 | `examples/maglev/research_cln/ngsolve_validation/sphere_vim_axisym_q1_selfsub_gpu_45x54_ns4.json` | `16310079ed89` | N_rho, N_theta, n_cells, n_dofs, n_quad, n_sub, t_assemble_s, t_eigh_s |
# | 92 | `examples/maglev/research_cln/ngsolve_validation/sphere_vim_axisym_q1_selfsub_gpu_summary.json` | `98160fd1750e` | stoll_tau_us, stoll_cauer_tau_us, results |
# | 93 | `examples/maglev/research_cln/ngsolve_validation/sphere_vim_axisym_q2_gpu_15x18.json` | `681b26e9b9fa` | basis, N_rho, N_theta, n_cells, n_dofs, t_assemble_s, t_eigh_s, leading_tau_us |
# | 94 | `examples/maglev/research_cln/ngsolve_validation/sphere_vim_axisym_q2_gpu_30x36.json` | `9378fb1967bd` | basis, N_rho, N_theta, n_cells, n_dofs, t_assemble_s, t_eigh_s, leading_tau_us |
# | 95 | `examples/maglev/research_cln/ngsolve_validation/sphere_vim_axisym_q2_gpu_45x54.json` | `57b873acb4d5` | basis, N_rho, N_theta, n_cells, n_dofs, t_assemble_s, t_eigh_s, leading_tau_us |
# | 96 | `examples/maglev/research_cln/ngsolve_validation/sphere_vim_axisym_q2_gpu_summary.json` | `002afe8f261f` | stoll_tau_us, stoll_cauer_tau_us, basis, results |
# | 97 | `examples/maglev/research_cln/ngsolve_validation/sphere_vim_axisym_quadsweep_results.json` | `46a123830bc4` | N_rho, N_theta, n_cells, analytical, by_nq |
# | 98 | `examples/maglev/research_cln/ngsolve_validation/sphere_vim_axisym_results.json` | `c337e277fb38` | method, params, stoll_analytical_tau_us, leading_tau_us, top_modes_by_g2, Cauer_rungs_Kameari |
# | 99 | `examples/maglev/research_cln/ngsolve_validation/sphere_vim_axisym_RL_extract_1080.json` | `bad0e2fbb68c` | n_cells, N_rho, N_theta, n_sub_self, leading_tau_us, cauer_rungs |
# | 100 | `examples/maglev/research_cln/ngsolve_validation/sphere_vim_axisym_subdiv_meshsweep_20x24.json` | `4687ce09ce79` | N_rho, N_theta, n_cells, t_assemble_s, leading_tau_us, cauer_rungs |
# | 101 | `examples/maglev/research_cln/ngsolve_validation/sphere_vim_axisym_subdiv_meshsweep_30x36.json` | `e4f0bcaa8b65` | N_rho, N_theta, n_cells, t_assemble_s, leading_tau_us, cauer_rungs |
# | 102 | `examples/maglev/research_cln/ngsolve_validation/sphere_vim_axisym_subdiv_meshsweep_40x48.json` | `42fb491ae6f9` | N_rho, N_theta, n_cells, t_assemble_s, leading_tau_us, cauer_rungs |
# | 103 | `examples/maglev/research_cln/ngsolve_validation/sphere_vim_axisym_subdiv_meshsweep_48x60.json` | `6bb46f96ea4d` | N_rho, N_theta, n_cells, t_assemble_s, leading_tau_us, cauer_rungs |
# | 104 | `examples/maglev/research_cln/ngsolve_validation/sphere_vim_axisym_subdiv_meshsweep_summary.json` | `287241067c8a` | stoll_tau1_us, stoll_cauer_tau_us, n_sub_self, n_quad, by_mesh |
# | 105 | `examples/maglev/research_cln/ngsolve_validation/sphere_vim_axisym_subdiv_results.json` | `4d51d268b851` | N_rho, N_theta, n_cells, stoll_tau1_us, stoll_cauer_tau_us, by_n_sub |
# | 106 | `examples/maglev/research_cln/ngsolve_validation/sphere_vim_axisym_sweep_20x24.json` | `13f337ed255f` | N_rho, N_theta, n_cells, n_quad, t_assemble_s, t_eig_s, leading_tau_us, cauer_rungs |
# | 107 | `examples/maglev/research_cln/ngsolve_validation/sphere_vim_axisym_sweep_30x36.json` | `ae71bd3cbef9` | N_rho, N_theta, n_cells, n_quad, t_assemble_s, t_eig_s, leading_tau_us, cauer_rungs |
# | 108 | `examples/maglev/research_cln/ngsolve_validation/sphere_vim_axisym_sweep_40x48.json` | `b25ac4e3f934` | N_rho, N_theta, n_cells, n_quad, t_assemble_s, t_eig_s, leading_tau_us, cauer_rungs |
# | 109 | `examples/maglev/research_cln/ngsolve_validation/sphere_vim_axisym_sweep_48x60.json` | `1ec729eb95c8` | N_rho, N_theta, n_cells, n_quad, t_assemble_s, t_eig_s, leading_tau_us, cauer_rungs |
# | 110 | `examples/maglev/research_cln/ngsolve_validation/sphere_vim_axisym_sweep_summary.json` | `7cbdd48f8fa0` | analytical, mesh_results |
# | 111 | `examples/maglev/rotating_magnet_eddy_results.json` | `f1ba81424616` | ndof, ncfg, maxh, Vc, rows, yano |
# | 112 | `examples/maglev/sphere/coil_maglev_equilibrium_results.json` | `9686c7c69c76` | description, force_formula, sphere, coil, frequency, sphere_response, field_check, equilibrium |
# | 113 | `examples/maglev/sphere/coil_sphere_eddy_force_results.json` | `37ef115c2a65` | description, force_formula_full, force_formula_dipole, coil, frequency, sphere, fe, case_5mm |
# | 114 | `examples/maglev/sphere/maglev_sphere_force_results.json` | `72772113913e` | sphere, field, perfect_conductor_lift_N, force_formula, sweep_lift_N, freq_Hz, lift_N |
# | 115 | `examples/maglev/team28/team28_cln_sweep_results.json` | `a75907ac4534` | geometry, cln_stages, disk_weight_N, force_note, dZ_mm, fz_full_N, fz_cln_N, fz_lab_N |
# media artifacts indexed: 22
