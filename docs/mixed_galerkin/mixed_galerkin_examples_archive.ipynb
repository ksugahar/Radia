# %% [markdown]
# # Mixed Galerkin Examples Archive
#
# This notebook is a result-saved promotion archive for `examples/mixed_galerkin`.
# It keeps theory, source inventory, result payloads, and placement policy in one
# human-readable surface while the adjacent JSON remains the durable debug record.
#
# ## Theory and Scope
#
# - This notebook is the topic-specific source/result archive for examples/mixed_galerkin.
# - It preserves full source, hashes, adjacent JSON payloads, and result media hashes before any pruning decision.
# - Validation-class scripts remain executable in examples until explicit validation_test gates or reusable src APIs exist.
#
# ## Placement Policy
#
# Docs-first topic archive for examples/mixed_galerkin. Keep scripts until protected docs, panel, package, and validation_test references have been migrated to docs, src, panels, or validation_test.
#
# ## Synchronization
#
# The durable archive is `mixed_galerkin_examples_archive_results.json`. It stores full source, SHA-256 hashes,
# existing result JSON payloads, media hashes, runtime metadata, and the promotion
# lane for every script in this batch.

# %%
from pathlib import Path
import json
from IPython.display import Markdown, display

archive_path = Path('mixed_galerkin_examples_archive_results.json')
if not archive_path.exists():
    archive_path = Path('docs/mixed_galerkin/mixed_galerkin_examples_archive_results.json')
data = json.loads(archive_path.read_text(encoding='utf-8'))
counts = data['counts']
print(f"topic={data['topic']}")
print(f"python_scripts={counts['python_scripts']}")
print(f"topic_json_files={counts['topic_json_files']}")
print(f"media_files={counts['media_files']}")
print(f"promotion_lane={data['promotion_lane']}")
# Out:
# topic=mixed_galerkin
# python_scripts=23
# topic_json_files=0
# media_files=0
# promotion_lane=topic_docs_first_archive

# %% [markdown]
# ## Script Inventory
# Generated from the synchronized JSON archive.

# %%
header = '| # | script | lines | json refs | docstring |\n|---:|---|---:|---:|---|'
body = []
for i, rec in enumerate(data['records'], 1):
    doc = (rec.get('docstring_first_line') or '').replace('|', '\\|')
    body.append(f"| {i} | `{rec['path']}` | {rec['line_count']} | {len(rec.get('attached_json', []))} | {doc} |")
display(Markdown('\n'.join([header] + body)))
# Out:
# | # | script | lines | json refs | docstring |
# |---:|---|---:|---:|---|
# | 1 | `examples/mixed_galerkin/_references/cube3d_foster.py` | 192 | 0 | Reference Y_exact for a solid conducting cube of side L (scalar PDE form). |
# | 2 | `examples/mixed_galerkin/_references/cylinder_bessel.py` | 191 | 0 | Reference Y_exact for an infinite-z conducting cylinder of radius a. |
# | 3 | `examples/mixed_galerkin/_references/sphere_bessel.py` | 155 | 0 | Reference Y_exact for a conducting sphere of radius a. |
# | 4 | `examples/mixed_galerkin/_references/square2d_foster.py` | 174 | 0 | Reference Y_exact for an infinite-z conducting bar of square cross-section L x L. |
# | 5 | `examples/mixed_galerkin/cube3d/01_corner_envelope_uncertain.py` | 144 | 0 | 3D cube mixed Galerkin: rank-N Foster bulk + corner-aware envelope. |
# | 6 | `examples/mixed_galerkin/cube3d/02_sibc_tail_diagnostic.py` | 123 | 0 | Diagnostic for the 3D cube mixed Galerkin SIBC-tail overshoot. |
# | 7 | `examples/mixed_galerkin/cube3d/03_exact_closed_form_Kss.py` | 157 | 0 | 3D cube mixed Galerkin with EXACT closed-form K_ss (no sine truncation). |
# | 8 | `examples/mixed_galerkin/cube3d/04_rank_N_bulk_sweep.py` | 157 | 0 | 3D cube rank-N bulk + closed-form K_ss surface envelope. |
# | 9 | `examples/mixed_galerkin/cube3d/05_midf_Foster_Aitken.py` | 140 | 0 | 3D cube mixed Galerkin verification at MID frequency. |
# | 10 | `examples/mixed_galerkin/cube3d/06_ngsolve_ground_truth.py` | 130 | 0 | NGSolve FEM ground truth for 3D cube scalar diffusion. |
# | 11 | `examples/mixed_galerkin/cube3d/07_ngsolve_freq_sweep.py` | 102 | 0 | NGSolve cube FEM frequency sweep.  Now that we've established convergence |
# | 12 | `examples/mixed_galerkin/cylinder/01_no_d_baseline.py` | 170 | 0 | Cylinder mixed Galerkin, rank-1 bulk + 1-DOF surface, NO free parameter. |
# | 13 | `examples/mixed_galerkin/cylinder/02_senior_tower_truncation.py` | 183 | 0 | Cylinder mixed Galerkin, rank-1 bulk + N-DOF Senior tower surface. |
# | 14 | `examples/mixed_galerkin/cylinder/03_rank_N_bulk_sweep.py` | 182 | 0 | Cylinder mixed Galerkin: rank-N bulk Krylov + 1-DOF surface envelope. |
# | 15 | `examples/mixed_galerkin/lshape3d_ngsolve_mellin.py` | 126 | 0 | NGSolve FEM scalar diffusion on a 3D L-shape. |
# | 16 | `examples/mixed_galerkin/ngsolve_validation/ngsolve_cube_minimal.py` | 197 | 0 | Minimal NGSolve FEM eddy-current solve on a Cu cube. |
# | 17 | `examples/mixed_galerkin/ngsolve_validation/ngsolve_cuboid_Y.py` | 169 | 0 | NGSolve FEM verification of cuboid admittance Y(s). |
# | 18 | `examples/mixed_galerkin/sphere/01_no_d_baseline.py` | 144 | 0 | Sphere mixed Galerkin, rank-1 bulk + 1-DOF surface, NO free parameter. |
# | 19 | `examples/mixed_galerkin/sphere/02_hoibc_gamma1.py` | 174 | 0 | Sphere mixed Galerkin with HOIBC gamma_1 = -1/a curvature correction. |
# | 20 | `examples/mixed_galerkin/square2d/01_corner_envelope.py` | 141 | 0 | 2D square cross-section mixed Galerkin: rank-1 bulk + corner-aware envelope. |
# | 21 | `examples/mixed_galerkin/square2d/02_foster_reference_audit.py` | 76 | 0 | Foster sum reference audit for the 2D square cross-section. |
# | 22 | `examples/mixed_galerkin/square2d/_broken_simple_envelope.py` | 111 | 0 | 2D square mixed Galerkin v1 — DELIBERATELY BROKEN, kept as negative result. |
# | 23 | `examples/mixed_galerkin/time_domain/01_cube_aaa_step_response.py` | 199 | 0 | Time-domain mixed Galerkin cube — clean summary script. |

# %% [markdown]
# ## Integrity Checks

# %%
assert counts['python_scripts'] == len(data['records'])
assert all(len(rec['sha256']) == 64 for rec in data['records'])
assert all(rec.get('source') for rec in data['records'])
print('archive integrity: ok')
# Out:
# archive integrity: ok

# %% [markdown]
# ## Result Payloads and Media

# %%
rows = data.get('topic_json_files', [])
if rows:
    header = '| # | json | sha256 | keys |\n|---:|---|---|---|'
    body = []
    for i, row in enumerate(rows, 1):
        payload = row.get('payload')
        keys = ', '.join(list(payload.keys())[:8]) if isinstance(payload, dict) else type(payload).__name__
        body.append(f"| {i} | `{row['path']}` | `{row['sha256'][:12]}` | {keys.replace('|', '\\|')} |")
    display(Markdown('\n'.join([header] + body)))
else:
    print('no existing JSON payloads found')

media = data.get('media_files', [])
print(f"media artifacts indexed: {len(media)}")
# Out:
# no existing JSON payloads found
# media artifacts indexed: 0
