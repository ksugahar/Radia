# %% [markdown]
# # Radia Cubit Export Toolbar Status
#
# Source panel: `src/radia/panels/radia_export_menu.py`.
#
# The Cubit-embedded Radia Export toolbar is an export surface only. Mesh p-convergence evaluation is documented as a docs demonstration at `docs/cubit_mesh_export/netgen/p_convergence_demo.ipynb`, not as a panel workflow.

# %%
# Version stamp for promoted panel notebooks
import json, platform, sys
try:
    import radia
    radia_version = getattr(radia, '__version__', 'unknown')
except Exception as exc:
    radia_version = f'not-importable: {exc}'
version_stamp = {
    'generated_at_utc': '2026-06-25T10:51:07Z',
    'runtime_python': sys.version.split()[0],
    'runtime_platform': platform.platform(),
    'runtime_radia_version': radia_version,
}
print(json.dumps(version_stamp, indent=2, ensure_ascii=False))

# %% [markdown]
# ## Migration Contract
#
# - Source panel: `src/radia/panels/radia_export_menu.py`
# - State: `active-cubit-toolbar`
# - Notebook target: `src/radia/panels/notebooks/radia_export_menu.ipynb`
# - Rule: this Cubit toolbar exposes export commands only.
# - Rule: mesh p-convergence is a docs demo, not an engineering design panel.
# - Rule: notebook code cells must not import desktop Qt bindings.

# %% [markdown]
# ## Toolbar Notes
#
# - The Cubit menu calls C++ APREPRO export commands through PySide6 dialogs owned by Cubit.
# - Normal Radia Python analysis panels remain notebook/headless and do not depend on PySide6.
# - Export consistency checks may still use headless helper code, but p-convergence demonstration belongs in `docs/cubit_mesh_export`.

# %% [markdown]
# ## Headless Helper
#
# - `src/radia/panels/check_vol_consistency.py`

# %%
# Cubit toolbar status: this remains a Cubit-embedded export surface.
panel_status = {
    'source_panel': 'src/radia/panels/radia_export_menu.py',
    'state': 'active-cubit-toolbar',
    'menu_scope': 'export-only',
    'docs_demo': 'docs/cubit_mesh_export/netgen/p_convergence_demo.ipynb',
    'headless_helpers': ['src/radia/panels/check_vol_consistency.py'],
}
panel_status
